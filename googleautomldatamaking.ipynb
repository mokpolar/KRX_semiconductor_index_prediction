# %%
import pandas as pd

# %%
a = pd.read_csv('new_automl_260_0318.csv', index_col = 0)

# %%
a['date'] = pd.to_datetime(a['date'], format='%Y-%m-%d', errors='ignore')

# %%
a
# Out:
#            date  GDPCQOQIndex  GDPCYOYIndex  GDPCTOTIndex  GPDITOCIndex  \
# 0    2006-01-02      5.400000      3.400000      4.500000      6.100000
# 1    2006-01-03      5.400000      3.400000      4.500000      6.100000
# 2    2006-01-04      5.400000      3.400000      4.500000      6.100000
# 3    2006-01-05      5.400000      3.400000      4.500000      6.100000
# 4    2006-01-06      5.400000      3.400000      4.500000      6.100000
# ...         ...           ...           ...           ...           ...
# 4786 2019-02-09      1.880467      2.556215      0.799713      3.786639
# 4787 2019-02-10      1.909043      2.559721      0.791809      3.858273
# 4788 2019-02-11      1.937775      2.563271      0.784353      3.930814
# 4789 2019-02-12      1.966642      2.566858      0.777355      4.004145
# 4790 2019-02-13      1.995625      2.570480      0.770822      4.078151
#
#       GPGSTOCIndex  RGCDCIPIIndex  GDPCUR$Index  GDPCURYIndex  GDPPIQQIndex  \
# ...

# %%
a.set_index('date', inplace = True)

# %%
a.to_csv('automl_260_200318.csv')

# %%
# Out:
#             GDPCQOQIndex  GDPCYOYIndex  GDPCTOTIndex  GPDITOCIndex  \
# date
# 2006-01-02      5.400000      3.400000      4.500000      6.100000
# 2006-01-03      5.400000      3.400000      4.500000      6.100000
# 2006-01-04      5.400000      3.400000      4.500000      6.100000
# 2006-01-05      5.400000      3.400000      4.500000      6.100000
# 2006-01-06      5.400000      3.400000      4.500000      6.100000
# ...                  ...           ...           ...           ...
# 2019-02-09      1.880467      2.556215      0.799713      3.786639
# 2019-02-10      1.909043      2.559721      0.791809      3.858273
# 2019-02-11      1.937775      2.563271      0.784353      3.930814
# 2019-02-12      1.966642      2.566858      0.777355      4.004145
# 2019-02-13      1.995625      2.570480      0.770822      4.078151
#
#             GPGSTOCIndex  RGCDCIPIIndex  GDPCUR$Index  GDPCURYIndex  \
# date
# 2006-01-02      5.200000     102.700000  13603.930000      6.600000
# ...

# %%
len(a.loc[4546:])
# Out:
# 245

# %%
b = a.loc[4546:]

# %%
b.reset_index(inplace = True, drop = True)

# %%
b.head()
# Out:
#         date  GDPCQOQIndex  GDPCYOYIndex  GDPCTOTIndex  GPDITOCIndex  \
# 0 2018-06-14      3.317091      3.151277      3.546236     -2.055321
# 1 2018-06-15      3.330223      3.154642      3.579007     -2.083733
# 2 2018-06-16      3.343172      3.157972      3.611313     -2.106808
# 3 2018-06-17      3.355929      3.161263      3.643129     -2.124422
# 4 2018-06-18      3.368484      3.164516      3.674427     -2.136452
#
#    GPGSTOCIndex  RGCDCIPIIndex  GDPCURIndex  GDPCURYIndex  GDPPIQQIndex  ...  \
# 0      2.423474     -26.558691  20450.95632      5.872843      3.152974  ...
# 1      2.435273     -26.953685  20454.79069      5.882098      3.159286  ...
# 2      2.447004     -27.312258  20458.61005      5.891201      3.165196  ...
# 3      2.458662     -27.633503  20462.41383      5.900148      3.170696  ...
# 4      2.470237     -27.916512  20466.20144      5.908934      3.175774  ...
#
#    Nvidia_product  Philadelphia_product  QCOM_product  \
# ...

# %%
#b.drop('date', axis = 1, inplace = True)

# %%
b.reset_index(inplace = True, drop = True)

# %%
b.set_index('date', inplace = True)

# %%
b.head()
# Out:
#             GDPCQOQIndex  GDPCYOYIndex  GDPCTOTIndex  GPDITOCIndex  \
# date
# 2018-06-14      3.317091      3.151277      3.546236     -2.055321
# 2018-06-15      3.330223      3.154642      3.579007     -2.083733
# 2018-06-16      3.343172      3.157972      3.611313     -2.106808
# 2018-06-17      3.355929      3.161263      3.643129     -2.124422
# 2018-06-18      3.368484      3.164516      3.674427     -2.136452
#
#             GPGSTOCIndex  RGCDCIPIIndex  GDPCURIndex  GDPCURYIndex  \
# date
# 2018-06-14      2.423474     -26.558691  20450.95632      5.872843
# 2018-06-15      2.435273     -26.953685  20454.79069      5.882098
# 2018-06-16      2.447004     -27.312258  20458.61005      5.891201
# 2018-06-17      2.458662     -27.633503  20462.41383      5.900148
# 2018-06-18      2.470237     -27.916512  20466.20144      5.908934
#
#             GDPPIQQIndex  GDPCPCECIndex  ...  Nvidia_product  \
# date                                     ...
# ...

# %%
b.to_csv('automltest_5.csv')
