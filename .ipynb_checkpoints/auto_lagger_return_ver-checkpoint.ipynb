# %% [markdown]
# # 대상 데이터프레임과 타겟컬럼을 지정하면 1일, 7일, 30일, 90일, 180일, 365일 단위로 return 뱉는 function

# %% [markdown]
# ## EX : 1day return = nextday close / base day close

# %%
import pandas as pd

# %%
df = pd.read_csv('semiconductor_bloomberg_raw_20200109.csv', index_col = 0)

# %%
df.head()
# Out:
#          date  GDPCQOQIndex  GDPCYOYIndex  GDPCTOT%Index  GPDITOC%Index  \
# 0  1981-01-01           NaN           NaN            NaN            NaN
# 1  1981-01-02           NaN           NaN            NaN            NaN
# 2  1981-01-05           NaN           NaN            NaN            NaN
# 3  1981-01-06           NaN           NaN            NaN            NaN
# 4  1981-01-07           NaN           NaN            NaN            NaN
#
#    GPGSTOC%Index  RGCDCIPIIndex  GDPCUR$Index  GDPCURYIndex  GDPPIQQIndex  \
# 0            NaN            NaN           NaN           NaN           NaN
# 1            NaN            NaN           NaN           NaN           NaN
# 2            NaN            NaN           NaN           NaN           NaN
# 3            NaN            NaN           NaN           NaN           NaN
# 4            NaN            NaN           NaN           NaN           NaN
#
#    ...  KOMSLYIndex  KOMSM1FYIndex  KOFETOTIndex  KOFETOT%Index  KORP7DIndex  \
# 0  ...          NaN            NaN           NaN            NaN          NaN
# 1  ...          NaN            NaN           NaN            NaN          NaN
# 2  ...          NaN            NaN           NaN            NaN          NaN
# 3  ...          NaN            NaN           NaN            NaN          NaN
# 4  ...          NaN            NaN           NaN            NaN          NaN
#
#    KOCICOBAIndex  KOCICONFIndex  KRBO3MIndex  KWCDCCurncy  GVSK10YRIndex
# 0            NaN            NaN          NaN          NaN            NaN
# 1            NaN            NaN          NaN          NaN            NaN
# 2            NaN            NaN          NaN          NaN            NaN
# 3            NaN            NaN          NaN          NaN            NaN
# 4            NaN            NaN          NaN          NaN            NaN
#
# [5 rows x 291 columns]

# %%
df.set_index('date', inplace = True)

# %%
# df should involve datetime index
# target column example = 'SKhynix_close'
def make_return_columns(df, target_column):
    # lagging day list
    lag_days = [1, 7, 30, 90, 180, 365]
    
    col_name =  []
    # creating new column name
    for i in lag_days:
        col_name.append(target_column + str(i))
    # appending lagged columns
    for i, j in enumerate(lag_days):
        df[locals()['col_name'][i]] = df[target_column]/df[target_column].shift(periods = j, axis = 0)
    return df

# %%
df['USGG10YRIndex']
# Out:
# date
# 1981-01-01        NaN
# 1981-01-02    12.4220
# 1981-01-05    12.1520
# 1981-01-06    12.1120
# 1981-01-07    12.3820
#                ...
# 2019-10-27        NaN
# 2019-10-28     1.8420
# 2019-10-29     1.8385
# 2019-10-30     1.7715
# 2019-10-31     1.6910
# Name: USGG10YRIndex, Length: 11682, dtype: float64

# %%
new_df = df[['USGG10YRIndex', 'GPGSTOC%Index']]

# %%
new_df
# Out:
#             USGG10YRIndex  GPGSTOC%Index
# date
# 1981-01-01            NaN            NaN
# 1981-01-02        12.4220            NaN
# 1981-01-05        12.1520            NaN
# 1981-01-06        12.1120            NaN
# 1981-01-07        12.3820            NaN
# ...                   ...            ...
# 2019-10-27            NaN            NaN
# 2019-10-28         1.8420            NaN
# 2019-10-29         1.8385            NaN
# 2019-10-30         1.7715            NaN
# 2019-10-31         1.6910            NaN
#
# [11682 rows x 2 columns]

# %%
make_return_columns(new_df, 'USGG10YRIndex')
# Out:
# /Users/mokpolar/opt/anaconda3/envs/tf-py36/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
#             USGG10YRIndex  GPGSTOC%Index  USGG10YRIndex1  USGG10YRIndex7  \
# date
# 1981-01-01            NaN            NaN             NaN             NaN
# 1981-01-02        12.4220            NaN             NaN             NaN
# 1981-01-05        12.1520            NaN        0.978264             NaN
# 1981-01-06        12.1120            NaN        0.996708             NaN
# 1981-01-07        12.3820            NaN        1.022292             NaN
# ...                   ...            ...             ...             ...
# 2019-10-27            NaN            NaN             NaN             NaN
# 2019-10-28         1.8420            NaN             NaN             NaN
# 2019-10-29         1.8385            NaN        0.998100        1.021786
# 2019-10-30         1.7715            NaN        0.963557        1.006134
# 2019-10-31         1.6910            NaN        0.954558        0.958508
#
#             USGG10YRIndex30  USGG10YRIndex90  USGG10YRIndex180  \
# date
# 1981-01-01              NaN              NaN               NaN
# 1981-01-02              NaN              NaN               NaN
# 1981-01-05              NaN              NaN               NaN
# 1981-01-06              NaN              NaN               NaN
# 1981-01-07              NaN              NaN               NaN
# ...                     ...              ...               ...
# 2019-10-27              NaN              NaN               NaN
# 2019-10-28         1.066775         0.876058          0.744513
# 2019-10-29         1.117222         0.898978          0.728378
# 2019-10-30         1.019744         0.875161          0.704346
# 2019-10-31         0.999350         0.822791          0.677647
#
#             USGG10YRIndex365
# date
# 1981-01-01               NaN
# 1981-01-02               NaN
# 1981-01-05               NaN
# 1981-01-06               NaN
# 1981-01-07               NaN
# ...                      ...
# 2019-10-27               NaN
# 2019-10-28          0.638696
# 2019-10-29          0.643958
# 2019-10-30          0.619319
# 2019-10-31               NaN
#
# [11682 rows x 8 columns]

# %%
new_df.head(50)
# Out:
#             USGG10YRIndex  GPGSTOC%Index  USGG10YRIndex1  USGG10YRIndex7  \
# date
# 1981-01-01            NaN            NaN             NaN             NaN
# 1981-01-02         12.422            NaN             NaN             NaN
# 1981-01-05         12.152            NaN        0.978264             NaN
# 1981-01-06         12.112            NaN        0.996708             NaN
# 1981-01-07         12.382            NaN        1.022292             NaN
# 1981-01-08         12.352            NaN        0.997577             NaN
# 1981-01-09         12.572            NaN        1.017811             NaN
# 1981-01-12         12.452            NaN        0.990455             NaN
# 1981-01-13         12.532            NaN        1.006425        1.008855
# 1981-01-14         12.532            NaN        1.000000        1.031271
# 1981-01-15         12.622            NaN        1.007182        1.042107
