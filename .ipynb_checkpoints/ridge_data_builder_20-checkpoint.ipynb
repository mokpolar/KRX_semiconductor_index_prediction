# %%
## Library Import

# Basic
import re
import warnings
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)
pd.set_option('display.width', 100)
warnings.filterwarnings('ignore')
# %config InlineBackend.figure_format = 'retina'

# Preprocessing
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Scaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PowerTransformer

# for VIF
from patsy import dmatrices
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# data load
df = pd.read_csv('original_full_data_20200325.csv', index_col = 0)
mmdf = pd.read_csv('bloomberg_map_index_20200324.csv', index_col = 0)



TARGET_DAY = 60

# %%
target = df[['date', 'KRXsemiconductor_close']]

# %%
df.drop('KRXsemiconductor_close', axis = 1, inplace = True)

# %%
len(target)
# Out:
# 5051

# %%
# target preprocessing

target['date'] = pd.to_datetime(target['date'])
target.set_index('date', inplace = True)

# %%
target.isna().sum()
# Out:
# KRXsemiconductor_close    1632
# dtype: int64

# %%
target = target.dropna()

# %%
len(target)
# Out:
# 3419

# %%
target = (np.log1p(target) - np.log1p(target).shift(periods = TARGET_DAY, axis = 0))

# %%
target = target.shift(-1 * TARGET_DAY)

# %%
target = target[:-1 * TARGET_DAY]

# %%
target
# Out:
#             KRXsemiconductor_close
# date
# 2006-01-02               -0.088455
# 2006-01-03               -0.091590
# 2006-01-04               -0.071684
# 2006-01-05               -0.037013
# 2006-01-06               -0.033750
# ...                            ...
# 2019-07-26                0.092139
# 2019-07-29                0.141737
# 2019-07-30                0.124408
# 2019-07-31                0.111455
# 2019-08-01                0.143452
#
# [3359 rows x 1 columns]

# %%
len(target)
# Out:
# 3359

# %%
# Class generates derived variables & shifting target variable

class Builder:

    def __init__(self, input_df, map_df, target_day):
        self.df = input_df
        self.mdf = map_df
        self.target_day = target_day # just target
        self.lag_days = [20, 60, 120] # lagging for prediction

    # not Bloomberg Economic
    
    def noteco(self, target_column):      

        col_name =  []
        # creating new column name
        for i in self.lag_days:
            col_name.append(target_column + str(i))
            
        # appending lagged columns
        for i, j in enumerate(self.lag_days):
            self.df[locals()['col_name'][i]] = np.log1p(self.df[target_column]) - np.log1p(self.df[target_column]).shift(periods = j, axis = 0) # 여기에 1을 뺀걸 추가하면 되는거아닌가? 1.얼만에서 1이 빠진거니까

        return self.df 

    # for Bloomberg Economic
    
    def eco(self, target_column):

        col_name = []
        for i in self.lag_days:
            col_name.append(target_column + str(i))
            
        for i, j in enumerate(self.lag_days):
            self.df[locals()['col_name'][i]] = np.log1p(self.df[target_column]) - np.log1p(self.df[target_column].shift(periods = self.target_day, axis = 0))
        return self.df

    # executing functions
    
    def execution(self):
        for i, j in enumerate(self.mdf['ticker']): # mdf에서 ticker 확인
            if j in self.df.columns:
                    
                if self.mdf.loc[i, :][1] == 'eco':
                    self.eco(j)

                elif self.mdf.loc[i, :][1] == 'noteco':
                    self.noteco(j)
                    self.df.drop(j, axis = 1, inplace = True)

                else:
                    pass
            else:
                pass
                            
        return self.df

# %%
len(df.columns)
# Out:
# 345

# %%
# date preprocessing

df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace = True)

# %%
# fillna cubic -> ffill -> bfill

#df = df.interpolate(method = 'cubic', limit_area = 'inside')
df = df.fillna(method = 'ffill')
df = df.fillna(method = 'bfill')

# %%
# check na value

df.isna().sum().sum()
# Out:
# 0

# %%
# class load

cla = Builder(df, mmdf, TARGET_DAY)

# %%
# execution function
# 새로운 데이터프레임 생성 
cla.execution()
# Out:
#             GDPCQOQIndex  GDPCYOYIndex  GDPCTOT%Index  GPDITOC%Index  GPGSTOC%Index  \
# date
# 2006-01-02           5.4           3.4            4.5            6.1            5.2
# 2006-01-03           5.4           3.4            4.5            6.1            5.2
# 2006-01-04           5.4           3.4            4.5            6.1            5.2
# 2006-01-05           5.4           3.4            4.5            6.1            5.2
# 2006-01-06           5.4           3.4            4.5            6.1            5.2
# ...                  ...           ...            ...            ...            ...
# 2019-10-27           2.0           2.3            4.6           -6.3            4.8
# 2019-10-28           2.0           2.3            4.6           -6.3            4.8
# 2019-10-29           2.0           2.3            4.6           -6.3            4.8
# 2019-10-30           2.0           2.3            4.6           -6.3            4.8
# 2019-10-31           2.0           2.3            4.6           -6.3            4.8
#
#             RGCDCIPIIndex  GDPCUR$Index  GDPCURYIndex  GDPPIQQIndex  GDPCPCECIndex  CPIYOYIndex  \
# date
# 2006-01-02          102.7      13603.93           6.6           2.8            2.3          4.0
# 2006-01-03          102.7      13603.93           6.6           2.8            2.3          4.0
# 2006-01-04          102.7      13603.93           6.6           2.8            2.3          4.0
# 2006-01-05          102.7      13603.93           6.6           2.8            2.3          4.0
# 2006-01-06          102.7      13603.93           6.6           2.8            2.3          4.0
# ...                   ...           ...           ...           ...            ...          ...
# 2019-10-27           69.4      21340.27           4.0           2.4            1.9          1.7
# 2019-10-28           69.4      21340.27           4.0           2.4            1.9          1.7
# 2019-10-29           69.4      21340.27           4.0           2.4            1.9          1.7
# 2019-10-30           69.4      21340.27           4.0           2.4            1.9          1.7
# 2019-10-31           69.4      21340.27           4.0           2.4            1.9          1.7
#
#             CPIXYOYIndex  PCEDEFYIndex  PCECYOYIndex  CPICHNGIndex  CPUPXCHGIndex  FDIDFDMOIndex  \
# date
# 2006-01-02           2.1           3.2       2.06622           0.6            0.2            0.1
# 2006-01-03           2.1           3.2       2.06622           0.6            0.2            0.1
# 2006-01-04           2.1           3.2       2.06622           0.6            0.2            0.1
# 2006-01-05           2.1           3.2       2.06622           0.6            0.2            0.1
# 2006-01-06           2.1           3.2       2.06622           0.6            0.2            0.1
# ...                  ...           ...           ...           ...            ...            ...
# 2019-10-27           2.4           1.4       1.77407           0.1            0.3            0.1
# 2019-10-28           2.4           1.4       1.77407           0.1            0.3            0.1
# 2019-10-29           2.4           1.4       1.77407           0.1            0.3            0.1
# 2019-10-30           2.4           1.4       1.77407           0.1            0.3            0.1
# 2019-10-31           2.4           1.4       1.77407           0.1            0.3            0.1
#
#             FDIDSGMOIndex  FDIUFDYOIndex  FDIUSGYOIndex  USURTOTIndex  USUDMAERIndex  INJCJCIndex  \
# date
# 2006-01-02            0.3            2.6            2.2           4.7            8.4        326.0
# 2006-01-03            0.3            2.6            2.2           4.7            8.4        326.0
# 2006-01-04            0.3            2.6            2.2           4.7            8.4        326.0
# 2006-01-05            0.3            2.6            2.2           4.7            8.4        326.0
# 2006-01-06            0.3            2.6            2.2           4.7            8.4        326.0
# ...                   ...            ...            ...           ...            ...          ...
# 2019-10-27            0.3            1.8            2.3           3.7            7.2        210.0
# 2019-10-28            0.3            1.8            2.3           3.7            7.2        210.0
# 2019-10-29            0.3            1.8            2.3           3.7            7.2        210.0
# 2019-10-30            0.3            1.8            2.3           3.7            7.2        215.0
# 2019-10-31            0.3            1.8            2.3           3.7            7.2        215.0
#
#             INJCSPIndex  NFPTCHIndex  ...  QCOM_close120  SamsungElectronics_close20  \
# date                                  ...
# 2006-01-02       2561.0        278.0  ...            NaN                         NaN
# 2006-01-03       2561.0        278.0  ...            NaN                         NaN
# 2006-01-04       2561.0        278.0  ...            NaN                         NaN
# 2006-01-05       2561.0        278.0  ...            NaN                         NaN
# 2006-01-06       2561.0        278.0  ...            NaN                         NaN
# ...                 ...          ...  ...            ...                         ...
# 2019-10-27       1656.0        219.0  ...       0.051832                    0.063883
# 2019-10-28       1656.0        219.0  ...       0.086698                    0.047912
# 2019-10-29       1656.0        219.0  ...       0.051382                    0.044006
# 2019-10-30       1655.0        219.0  ...       0.055234                    0.037396
# 2019-10-31       1655.0        219.0  ...       0.047913                    0.025114
#
#             SamsungElectronics_close60  SamsungElectronics_close120  ShinEtsuChemical_close20  \
# date
# 2006-01-02                         NaN                          NaN                       NaN
# 2006-01-03                         NaN                          NaN                       NaN
# 2006-01-04                         NaN                          NaN                       NaN
# 2006-01-05                         NaN                          NaN                       NaN
# 2006-01-06                         NaN                          NaN                       NaN
# ...                                ...                          ...                       ...
# 2019-10-27                    0.142267                     0.079714                  0.066249
# 2019-10-28                    0.167228                     0.087541                  0.075930
# 2019-10-29                    0.149592                     0.092182                  0.073813
# 2019-10-30                    0.135799                     0.085928                  0.038874
# 2019-10-31                    0.135799                     0.104477                  0.019302
#
#             ShinEtsuChemical_close60  ShinEtsuChemical_close120  Siltronic_close20  \
# date
# 2006-01-02                       NaN                        NaN                NaN
# 2006-01-03                       NaN                        NaN                NaN
# 2006-01-04                       NaN                        NaN                NaN
# 2006-01-05                       NaN                        NaN                NaN
# 2006-01-06                       NaN                        NaN                NaN
# ...                              ...                        ...                ...
# 2019-10-27                  0.123778                   0.174040           0.184395
# 2019-10-28                  0.085888                   0.154798           0.268355
# 2019-10-29                  0.093916                   0.145008           0.301446
# 2019-10-30                  0.100175                   0.172869           0.263901
# 2019-10-31                  0.097398                   0.161477           0.192949
#
#             Siltronic_close60  Siltronic_close120  SKhynix_close20  SKhynix_close60  \
# date
# 2006-01-02                NaN                 NaN              NaN              NaN
# 2006-01-03                NaN                 NaN              NaN              NaN
# 2006-01-04                NaN                 NaN              NaN              NaN
# 2006-01-05                NaN                 NaN              NaN              NaN
# 2006-01-06                NaN                 NaN              NaN              NaN
# ...                       ...                 ...              ...              ...
# 2019-10-27           0.359567            0.243316         0.031865         0.123073
# 2019-10-28           0.407947            0.286738         0.024421         0.123073
# 2019-10-29           0.387078            0.261677         0.025626         0.069853
# 2019-10-30           0.386620            0.279844         0.031155         0.051616
# 2019-10-31           0.362025            0.297360         0.024692         0.057732
#
#             SKhynix_close120  Sumco_close20  Sumco_close60  Sumco_close120  TokyoElectron_close20  \
# date
# 2006-01-02               NaN            NaN            NaN             NaN                    NaN
# 2006-01-03               NaN            NaN            NaN             NaN                    NaN
# 2006-01-04               NaN            NaN            NaN             NaN                    NaN
# 2006-01-05               NaN            NaN            NaN             NaN                    NaN
# 2006-01-06               NaN            NaN            NaN             NaN                    NaN
# ...                      ...            ...            ...             ...                    ...
# 2019-10-27          0.176306       0.150061       0.179048        0.000000               0.041847
# 2019-10-28          0.176306       0.141203       0.174941       -0.004107               0.032854
# 2019-10-29          0.170343       0.145310       0.169292       -0.012220               0.041978
# 2019-10-30          0.132303       0.132939       0.156921       -0.028632               0.054224
# 2019-10-31          0.171162       0.107727       0.131709       -0.029352               0.029016
#
#             TokyoElectron_close60  TokyoElectron_close120  TSMC_close20  TSMC_close60  \
# date
# 2006-01-02                    NaN                     NaN           NaN           NaN
# 2006-01-03                    NaN                     NaN           NaN           NaN
# 2006-01-04                    NaN                     NaN           NaN           NaN
# 2006-01-05                    NaN                     NaN           NaN           NaN
# 2006-01-06                    NaN                     NaN           NaN           NaN
# ...                           ...                     ...           ...           ...
# 2019-10-27               0.105682                0.091316      0.058440      0.160807
# 2019-10-28               0.103058                0.090834      0.032243      0.154521
# 2019-10-29               0.098902                0.095215      0.059338      0.151037
# 2019-10-30               0.113140                0.116841      0.065146      0.156846
# 2019-10-31               0.084942                0.074444      0.060200      0.151900
#
#             TSMC_close120  UMC_close20  UMC_close60  UMC_close120
# date
# 2006-01-02            NaN          NaN          NaN           NaN
# 2006-01-03            NaN          NaN          NaN           NaN
# 2006-01-04            NaN          NaN          NaN           NaN
# 2006-01-05            NaN          NaN          NaN           NaN
# 2006-01-06            NaN          NaN          NaN           NaN
# ...                   ...          ...          ...           ...
# 2019-10-27       0.195714     0.064135     0.088666      0.033902
# 2019-10-28       0.199265     0.068993     0.080093      0.033902
# 2019-10-29       0.180153     0.073413     0.068563      0.018238
# 2019-10-30       0.183377     0.057693     0.062520      0.021440
# 2019-10-31       0.203798     0.031253     0.047253      0.012384
#
# [5051 rows x 1308 columns]

# %%
len(df.columns)
# Out:
# 1308

# %%
df.columns
# Out:
# Index(['GDPCQOQIndex', 'GDPCYOYIndex', 'GDPCTOT%Index', 'GPDITOC%Index', 'GPGSTOC%Index',
#        'RGCDCIPIIndex', 'GDPCUR$Index', 'GDPCURYIndex', 'GDPPIQQIndex', 'GDPCPCECIndex',
#        ...
#        'Sumco_close120', 'TokyoElectron_close20', 'TokyoElectron_close60',
#        'TokyoElectron_close120', 'TSMC_close20', 'TSMC_close60', 'TSMC_close120', 'UMC_close20',
#        'UMC_close60', 'UMC_close120'],
#       dtype='object', length=1308)

# %%
df.isna().sum().sum()
# Out:
# 565984

# %%
# shifting 한 값 날리기

df = df[TARGET_DAY:]

# %%
len(df)
# Out:
# 4991

# %%
len(df)
# Out:
# 4991

# %%
# nan값이 500을 넘으면 제거 
drop_columns = df.isna().sum().sort_values(ascending = False)[df.isna().sum().sort_values(ascending = False).values>500].index

# %%
df.drop(drop_columns, axis = 1, inplace = True)

# %%
len(df.columns)
# Out:
# 1053

# %%
# fill na for shifted data

#df = df.interpolate(method = 'cubic', limit_area = 'inside')
df = df.fillna(method = 'ffill')
df = df.fillna(method = 'bfill')

# %%
# check na

df.isna().sum().sum()
# Out:
# 0

# %%
len(df)
# Out:
# 4991

# %%
# features

len(df.columns)
# Out:
# 1053

# %% [markdown]
# ### 이 시점에서 target과 merge

# %%
target
# Out:
#             KRXsemiconductor_close
# date
# 2006-01-02               -0.088455
# 2006-01-03               -0.091590
# 2006-01-04               -0.071684
# 2006-01-05               -0.037013
# 2006-01-06               -0.033750
# ...                            ...
# 2019-07-26                0.092139
# 2019-07-29                0.141737
# 2019-07-30                0.124408
# 2019-07-31                0.111455
# 2019-08-01                0.143452
#
# [3359 rows x 1 columns]

# %%
merged_df = pd.merge(target, df, how = 'left', on = 'date')

# %%
len(merged_df)
# Out:
# 3359

# %%
df = merged_df.dropna()

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
print('{:.0f}'.format(len(df)/5051*100), '% 만큼 데이터 살았다')
# Out:
# 66 % 만큼 데이터 살았다

# %%
df
# Out:
#             KRXsemiconductor_close  GDPCQOQIndex  GDPCYOYIndex  GDPCTOT%Index  GPDITOC%Index  \
# date
# 2006-03-03                0.014408           5.4           3.4            4.5            6.1
# 2006-03-06               -0.007438           5.4           3.4            4.5            6.1
# 2006-03-07                0.020200           5.4           3.4            4.5            6.1
# 2006-03-08                0.010531           5.4           3.4            4.5            6.1
# 2006-03-09               -0.024153           5.4           3.4            4.5            6.1
# ...                            ...           ...           ...            ...            ...
# 2019-07-26                0.092139           3.1           2.7            1.1            6.2
# 2019-07-29                0.141737           3.1           2.7            1.1            6.2
# 2019-07-30                0.124408           3.1           2.7            1.1            6.2
# 2019-07-31                0.111455           3.1           2.7            1.1            6.2
# 2019-08-01                0.143452           3.1           2.7            1.1            6.2
#
#             GPGSTOC%Index  RGCDCIPIIndex  GDPCUR$Index  GDPCURYIndex  GDPPIQQIndex  GDPCPCECIndex  \
# date
# 2006-03-03            5.2          102.7      13603.93           6.6           2.8            2.3
# 2006-03-06            5.2          102.7      13603.93           6.6           2.8            2.3
# 2006-03-07            5.2          102.7      13603.93           6.6           2.8            2.3
# 2006-03-08            5.2          102.7      13603.93           6.6           2.8            2.3
# 2006-03-09            5.2          102.7      13603.93           6.6           2.8            2.3
# ...                   ...            ...           ...           ...           ...            ...
# 2019-07-26            2.9          116.0      21098.83           4.6           1.1            1.1
# 2019-07-29            2.9          116.0      21098.83           4.6           1.1            1.1
# 2019-07-30            2.9          116.0      21098.83           4.6           1.1            1.1
# 2019-07-31            2.9          116.0      21098.83           4.6           1.1            1.1
# 2019-08-01            2.9          116.0      21098.83           4.6           1.1            1.1
#
#             CPIYOYIndex  CPIXYOYIndex  PCEDEFYIndex  PCECYOYIndex  CPICHNGIndex  CPUPXCHGIndex  \
# date
# 2006-03-03          4.0           2.1           3.2       2.06622           0.6            0.2
# 2006-03-06          4.0           2.1           3.2       2.06622           0.6            0.2
# 2006-03-07          4.0           2.1           3.2       2.06622           0.6            0.2
# 2006-03-08          4.0           2.1           3.2       2.06622           0.6            0.2
# 2006-03-09          4.0           2.1           3.2       2.06622           0.6            0.2
# ...                 ...           ...           ...           ...           ...            ...
# 2019-07-26          1.8           2.0           1.4       1.48266           0.1            0.1
# 2019-07-29          1.8           2.0           1.4       1.48266           0.1            0.1
# 2019-07-30          1.8           2.0           1.4       1.48266           0.1            0.1
# 2019-07-31          1.8           2.0           1.4       1.48266           0.1            0.1
# 2019-08-01          1.8           2.0           1.4       1.48266           0.1            0.1
#
#             FDIDFDMOIndex  FDIDSGMOIndex  FDIUFDYOIndex  FDIUSGYOIndex  USURTOTIndex  \
# date
# 2006-03-03            0.1            0.3            2.6            2.2           4.7
# 2006-03-06            0.1            0.3            2.6            2.2           4.7
# 2006-03-07            0.1            0.3            2.6            2.2           4.7
# 2006-03-08            0.1            0.3            2.6            2.2           4.7
# 2006-03-09            0.1            0.3            2.6            2.2           4.7
# ...                   ...            ...            ...            ...           ...
# 2019-07-26            0.2            0.3            2.1            2.4           3.6
# 2019-07-29            0.2            0.3            2.1            2.4           3.6
# 2019-07-30            0.2            0.3            2.1            2.4           3.6
# 2019-07-31            0.2            0.3            2.1            2.4           3.6
# 2019-08-01            0.2            0.3            2.1            2.4           3.6
#
#             USUDMAERIndex  INJCJCIndex  INJCSPIndex  ...  QCOM_close120  \
# date                                                 ...
# 2006-03-03            8.4        290.0       2516.0  ...       0.145734
# 2006-03-06            8.4        290.0       2516.0  ...       0.145734
# 2006-03-07            8.4        290.0       2516.0  ...       0.145734
# 2006-03-08            8.4        282.0       2565.0  ...       0.145734
# 2006-03-09            8.4        282.0       2565.0  ...       0.145734
# ...                   ...          ...          ...  ...            ...
# 2019-07-26            7.1        217.0       1694.0  ...       0.280970
# 2019-07-29            7.1        217.0       1694.0  ...       0.269378
# 2019-07-30            7.1        217.0       1694.0  ...       0.253918
# 2019-07-31            7.1        229.0       1696.0  ...       0.227163
# 2019-08-01            7.1        229.0       1696.0  ...       0.207341
#
#             SamsungElectronics_close20  SamsungElectronics_close60  SamsungElectronics_close120  \
# date
# 2006-03-03                   -0.052290                   -0.010679                    -0.015291
# 2006-03-06                   -0.022540                   -0.031416                    -0.015291
# 2006-03-07                   -0.038976                   -0.088203                    -0.015291
# 2006-03-08                   -0.051614                   -0.097788                    -0.015291
# 2006-03-09                   -0.090123                   -0.110712                    -0.015291
# ...                                ...                         ...                          ...
# 2019-07-26                    0.032330                    0.100304                     0.050009
# 2019-07-29                    0.021930                    0.080131                     0.031958
# 2019-07-30                    0.021716                    0.091021                     0.032753
# 2019-07-31                   -0.018569                    0.064905                    -0.008781
# 2019-08-01                   -0.024044                    0.061592                    -0.030503
#
#             ShinEtsuChemical_close20  ShinEtsuChemical_close60  ShinEtsuChemical_close120  \
# date
# 2006-03-03                  0.000000                  0.000000                   0.000000
# 2006-03-06                  0.000000                  0.000000                   0.000000
# 2006-03-07                  0.000000                  0.000000                   0.000000
# 2006-03-08                  0.000000                  0.000000                   0.000000
# 2006-03-09                  0.000000                  0.000000                   0.000000
# ...                              ...                       ...                        ...
# 2019-07-26                  0.083216                  0.178526                   0.185368
# 2019-07-29                  0.119251                  0.186722                   0.187635
# 2019-07-30                  0.133804                  0.201053                   0.156763
# 2019-07-31                  0.126177                  0.206004                   0.143130
# 2019-08-01                  0.130000                  0.203341                   0.100926
#
#             Siltronic_close20  Siltronic_close60  Siltronic_close120  SKhynix_close20  \
# date
# 2006-03-03           0.000000           0.000000            0.000000        -0.120326
# 2006-03-06           0.000000           0.000000            0.000000        -0.062518
# 2006-03-07           0.000000           0.000000            0.000000         0.006884
# 2006-03-08           0.000000           0.000000            0.000000        -0.030102
# 2006-03-09           0.000000           0.000000            0.000000        -0.069678
# ...                       ...                ...                 ...              ...
# 2019-07-26           0.146879           0.056074           -0.058565         0.154149
# 2019-07-29           0.171937           0.124608           -0.074604         0.098170
# 2019-07-30           0.124260           0.118721           -0.155963         0.079092
# 2019-07-31           0.153817           0.128483           -0.178744         0.018373
# 2019-08-01           0.166517           0.143512           -0.199621         0.039375
#
#             SKhynix_close60  SKhynix_close120  Sumco_close20  Sumco_close60  Sumco_close120  \
# date
# 2006-03-03        -0.209271         -0.189791       0.000000       0.000000        0.000000
# 2006-03-06        -0.109863         -0.189791       0.000000       0.000000        0.000000
# 2006-03-07        -0.184315         -0.189791       0.000000       0.000000        0.000000
# 2006-03-08        -0.174076         -0.189791       0.000000       0.000000        0.000000
# 2006-03-09        -0.186032         -0.189791       0.000000       0.000000        0.000000
# ...                     ...               ...            ...            ...             ...
# 2019-07-26         0.176322          0.098698      -0.062914       0.124298        0.000000
# 2019-07-29         0.155665          0.037041      -0.055451       0.139060       -0.017392
# 2019-07-30         0.189187          0.029584      -0.018019       0.096311       -0.070204
# 2019-07-31         0.163512          0.006523      -0.004494       0.105361       -0.065383
# 2019-08-01         0.173861         -0.027920       0.018265       0.100846       -0.074108
#
#             TokyoElectron_close20  TokyoElectron_close60  TokyoElectron_close120  TSMC_close20  \
# date
# 2006-03-03              -0.041514              -0.027867               -0.020827     -0.011055
# 2006-03-06               0.025217              -0.041803               -0.020827     -0.018160
# 2006-03-07              -0.038792              -0.095931               -0.020827     -0.016093
# 2006-03-08              -0.025127              -0.106777               -0.020827     -0.038413
# 2006-03-09              -0.021576              -0.106777               -0.020827     -0.022756
# ...                           ...                    ...                     ...           ...
# 2019-07-26               0.011696               0.082700                0.112237      0.066828
# 2019-07-29               0.018934               0.106678                0.133390      0.069707
# 2019-07-30               0.036259               0.124513                0.142351      0.044579
# 2019-07-31               0.035950               0.119133                0.116925      0.030911
# 2019-08-01               0.014844               0.117660                0.108859      0.018677
#
#             TSMC_close60  TSMC_close120  UMC_close20  UMC_close60  UMC_close120
# date
# 2006-03-03     -0.006599       0.060755     0.023089     0.023089      0.139448
# 2006-03-06     -0.041573       0.060755     0.062568     0.030795      0.139448
# 2006-03-07     -0.062502       0.060755     0.018395    -0.005167      0.139448
# 2006-03-08     -0.074387       0.060755    -0.025891    -0.010361      0.139448
# 2006-03-09     -0.065686       0.060755    -0.010307    -0.005167      0.139448
# ...                  ...            ...          ...          ...           ...
# 2019-07-26      0.119819       0.061826    -0.048163     0.013245      0.064539
# 2019-07-29      0.122413       0.047984    -0.028710     0.042982      0.077349
# 2019-07-30      0.101105       0.042895    -0.043621     0.057346      0.096904
# 2019-07-31      0.099438       0.040424    -0.055742     0.057346      0.096904
# 2019-08-01      0.087545       0.025462    -0.056619     0.041294      0.077349
#
# [3317 rows x 1054 columns]

# %%
df.describe().T.sort_values(by = 'min')[0:39]
# Out:
#                    count  mean  std  min       25%       50%       75%       max
# MBRXYOYWIndex60   3317.0  -inf  NaN -inf -0.372675  0.000000  0.108214  2.772589
# MWINCHNGIndex60   3317.0  -inf  NaN -inf -0.405465  0.000000  0.268264  2.639057
# MWINCHNGIndex120  3317.0  -inf  NaN -inf -0.405465  0.000000  0.268264  2.639057
# KOGCSTOQIndex60   3317.0   NaN  NaN -inf -0.095310  0.000000  0.182322       inf
# PITLCHNGIndex120  3317.0   NaN  NaN -inf -0.167054  0.000000  0.194156       inf
# LEICHNGIndex20    3317.0   NaN  NaN -inf -0.262364  0.000000  0.310155       inf
# LEICHNGIndex60    3317.0   NaN  NaN -inf -0.262364  0.000000  0.310155       inf
# LEICHNGIndex120   3317.0   NaN  NaN -inf -0.262364  0.000000  0.310155       inf
# PITLCHNGIndex60   3317.0   NaN  NaN -inf -0.167054  0.000000  0.194156       inf
# RSTAMOMIndex20    3317.0   NaN  NaN -inf -0.496437 -0.105361  0.435318       inf
# MWINCHNGIndex20   3317.0  -inf  NaN -inf -0.405465  0.000000  0.268264  2.639057
# RSTAMOMIndex60    3317.0   NaN  NaN -inf -0.496437 -0.105361  0.435318       inf
# PITLCHNGIndex20   3317.0   NaN  NaN -inf -0.167054  0.000000  0.194156       inf
# KOGCSTOQIndex20   3317.0   NaN  NaN -inf -0.095310  0.000000  0.182322       inf
# MBRXYOYWIndex120  3317.0  -inf  NaN -inf -0.372675  0.000000  0.108214  2.772589
# KOECSGVQIndex120  3317.0   NaN  NaN -inf -0.105361  0.000000  0.127833       inf
# RSTAXMOMIndex20   3317.0   NaN  NaN -inf -0.470004 -0.051293  0.405465       inf
# MBRXYOYWIndex20   3317.0  -inf  NaN -inf -0.372675  0.000000  0.108214  2.772589
# KOECEXPYIndex120  3317.0   NaN  NaN -inf -0.043172  0.000000  0.067441       inf
# KOECSGVQIndex20   3317.0   NaN  NaN -inf -0.105361  0.000000  0.127833       inf
# RSTAXMOMIndex120  3317.0   NaN  NaN -inf -0.470004 -0.051293  0.405465       inf
# RSTAMOMIndex120   3317.0   NaN  NaN -inf -0.496437 -0.105361  0.435318       inf
# KOECSGVQIndex60   3317.0   NaN  NaN -inf -0.105361  0.000000  0.127833       inf
# RSTAXMOMIndex60   3317.0   NaN  NaN -inf -0.470004 -0.051293  0.405465       inf
# KOPPIMOMIndex60   3317.0   NaN  NaN -inf -0.325422  0.000000  0.336472       inf
# KOHPTYOYIndex60   3317.0   NaN  NaN -inf -0.167054  0.000000  0.133531       inf
# KOECEXPYIndex60   3317.0   NaN  NaN -inf -0.043172  0.000000  0.067441       inf
# KOPPIMOMIndex20   3317.0   NaN  NaN -inf -0.325422  0.000000  0.336472       inf
# KOECEXPYIndex20   3317.0   NaN  NaN -inf -0.043172  0.000000  0.067441       inf
# KOMSM1FYIndex60   3317.0  -inf  NaN -inf -0.164875 -0.010811  0.095310  0.593064
# KOMSM1FYIndex20   3317.0  -inf  NaN -inf -0.164875 -0.010811  0.095310  0.593064
# KOGCSTOQIndex120  3317.0   NaN  NaN -inf -0.095310  0.000000  0.182322       inf
# FDIUFDYOIndex120  3317.0  -inf  NaN -inf -0.082238  0.000000  0.032790  0.916291
# FDIUFDYOIndex60   3317.0  -inf  NaN -inf -0.082238  0.000000  0.032790  0.916291
# FDIUFDYOIndex20   3317.0  -inf  NaN -inf -0.082238  0.000000  0.032790  0.916291
# KOHPTYOYIndex120  3317.0   NaN  NaN -inf -0.167054  0.000000  0.133531       inf
# KOPPIMOMIndex120  3317.0   NaN  NaN -inf -0.325422  0.000000  0.336472       inf
# KOHPTYOYIndex20   3317.0   NaN  NaN -inf -0.167054  0.000000  0.133531       inf
# KOMSM1FYIndex120  3317.0  -inf  NaN -inf -0.164875 -0.010811  0.095310  0.593064

# %%
nan_columns = df.describe().T.sort_values(by = 'min')[0:39].index

# %%
df.drop(nan_columns, axis = 1, inplace = True)

# %%
df.describe().T.sort_values(by = 'std', ascending = True)
# Out:
#                  count          mean            std           min           25%           50%  \
# KOHSTRIndex120  3317.0  5.026698e-04       0.001988 -6.872879e-03  0.000000e+00  0.000000e+00
# KOHSTRIndex60   3317.0  5.026698e-04       0.001988 -6.872879e-03  0.000000e+00  0.000000e+00
# KOHSTRIndex20   3317.0  5.026698e-04       0.001988 -6.872879e-03  0.000000e+00  0.000000e+00
# SKLILCIndex120  3317.0  5.622967e-03       0.002433 -7.371041e-03  4.750603e-03  5.899722e-03
# SKLILCIndex60   3317.0  5.622967e-03       0.002433 -7.371041e-03  4.750603e-03  5.899722e-03
# ...                ...           ...            ...           ...           ...           ...
# KOGFTRIndex     3317.0  1.714932e+05   96367.187729  2.186400e+04  8.937200e+04  1.630520e+05
# MTSLRL$Index    3317.0  1.322656e+06  100776.105426  1.126129e+06  1.260142e+06  1.310470e+06
# KOHHLIndex      3317.0  9.235600e+05  274459.406413  5.224090e+05  6.844116e+05  8.750175e+05
# KOHHDIndex      3317.0  9.770850e+05  291323.768834  5.503308e+05  7.235215e+05  9.285616e+05
# KOHOINCIndex    3317.0  3.941334e+06  556349.169246  2.965551e+06  3.449739e+06  4.040630e+06
#
#                          75%           max
# KOHSTRIndex120  0.000000e+00  1.087505e-02
# KOHSTRIndex60   0.000000e+00  1.087505e-02
# KOHSTRIndex20   0.000000e+00  1.087505e-02
# SKLILCIndex120  6.743114e-03  1.201938e-02
# SKLILCIndex60   6.743114e-03  1.201938e-02
# ...                      ...           ...
# KOGFTRIndex     2.360310e+05  4.382620e+05
# MTSLRL$Index    1.398649e+06  1.517565e+06
# KOHHLIndex      1.137953e+06  1.451722e+06
# KOHHDIndex      1.203099e+06  1.539900e+06
# KOHOINCIndex    4.387554e+06  4.917719e+06
#
# [1015 rows x 8 columns]

# %%
print('데이터 추출 전 최종 확인', 'shape: ', df.shape, 'nan값 수 :', df.isna().sum().sum())
# Out:
# 데이터 추출 전 최종 확인 shape:  (3317, 1015) nan값 수 : 0

# %%
df.to_csv('final_data_60_by_ffill_ver1.csv')
