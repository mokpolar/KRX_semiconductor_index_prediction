# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
import re
from sklearn.linear_model import Ridge
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 이제 3가지 유형으로 빈 자리를 채우고
# 1. 계단형
# 2. 직선형
# 3. spline
# 성능을 계산해보자

# %%
df = pd.read_csv('total_data.csv')

# %%
df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
df.head()
# Out:
#          date  Amazon_close  Amazon_volume  Amazon_change  AMD_close  \
# 0  2006-01-02           NaN            NaN            NaN        NaN
# 1  2006-01-03         46.25      7580000.0           0.91      32.40
# 2  2006-01-04         46.69      7440000.0          -0.69      32.56
# 3  2006-01-05         47.11      5420000.0           0.85      33.68
# 4  2006-01-06         47.32      6150000.0           0.46      33.78
#
#    AMD_volume  AMD_change  APPLE_close  APPLE_volume  APPLE_change  ...  \
# 0         NaN         NaN          NaN           NaN           NaN  ...
# 1  16649999.0        5.88        10.68   201850000.0          3.99  ...
# 2  11300000.0        0.49        10.71   155230000.0          0.28  ...
# 3  13810000.0        3.44        10.63   112400000.0         -0.75  ...
# 4  13310000.0        0.30        10.90   176140000.0          2.54  ...
#
#    TSMC_change  UMC_close  UMC_volume  UMC_change  USDollarIndex_close  \
# 0          NaN        NaN         NaN         NaN                  NaN
# 1       3.6518      4.266   5350000.0        2.24                89.84
# 2       1.7457      4.212   3150000.0       -1.87                89.14
# 3       1.9777      4.212   8760000.0       -0.33                89.33
# 4       1.7525      4.239  13450000.0        4.48                88.85
#
#    USDollarIndex_volume  USDollarIndex_change  USD_KRW_close  USD_KRW_volume  \
# 0                   NaN                   NaN        1012.82             0.0
# 1                   0.0                 -1.46        1004.50             0.0
# 2                   0.0                 -0.78         998.35             0.0
# 3                   0.0                  0.21         994.75             0.0
# 4                   0.0                 -0.54         989.30             0.0
#
#    USD_KRW_change
# 0            0.53
# 1           -0.82
# 2           -0.61
# 3           -0.36
# 4           -0.55
#
# [5 rows x 100 columns]

# %%
krx = df[['date', 'KRXsemiconductor_close']]

# %%
# 일단 2가지로 a
linear = pd.read_csv('bloomberg_total_index.csv')

# %%
# 필요 없는 column drop
linear.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
krx['date'] = pd.to_datetime(krx['date'])
linear['date'] = pd.to_datetime(linear['date'])
# Out:
# /Users/mokpolar/opt/anaconda3/envs/tf-py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df = pd.merge(krx, linear, how = 'left', on = 'date')

# %%
df.to_csv('bloomberg_for_linear_daily.csv')

# %%
df['KRXsemiconductor_close'] = df['KRXsemiconductor_close'].map(lambda x: '' if str(x) == 'nan' else x)

# %%
df['KRXsemiconductor_close'] = df['KRXsemiconductor_close'].map(lambda x: re.sub(",", "", str(x)))

# %%
df['KRXsemiconductor_close'] = pd.to_numeric(df['KRXsemiconductor_close'] )

# %%
# date 빼고 다 numeric type으로 만들자
for i in range(len(df.columns)):
    col_name = df.columns[i]
    if col_name == 'date':
        pass
    else:
        df[col_name] = pd.to_numeric(df[col_name])

# %%
# 이씨 nan은 왜 나온거지 전 코드에는 포함이 안되어 있었는데
# 어쨌거나 새로 저장하자
df.to_csv('bloomberg_for_linear_daily.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5051 entries, 0 to 5050
# Columns: 142 entries, date to KOGCSTOQIndex
# dtypes: datetime64[ns](1), float64(141)
# memory usage: 5.5 MB

# %%
df.head()
# Out:
#         date  KRXsemiconductor_close  FDTRIndex_x  FDTRIndex_y  USGG3MIndex  \
# 0 2006-01-02                 1000.00          NaN          NaN       4.0736
# 1 2006-01-03                 1012.36         4.25         4.25       4.1144
# 2 2006-01-04                 1007.17         4.25         4.25       4.1798
# 3 2006-01-05                  991.68         4.25         4.25       4.1793
# 4 2006-01-06                 1008.15         4.25         4.25       4.1985
#
#    USGG10YRIndex  USTW$Index  INJCJCIndex  INJCSPIndex  USEMNCHGIndex  ...  \
# 0         4.3911     86.0274          NaN          NaN            NaN  ...
# 1         4.3637     85.0983          NaN          NaN            NaN  ...
# 2         4.3422     84.5642          NaN          NaN            NaN  ...
# 3         4.3519     84.7247          NaN          NaN            NaN  ...
# 4         4.3733     84.3844        326.0       2561.0            NaN  ...
#
#    USCABALIndex  JNVNIYOYIndex  COSTNFR%Index  KOGNICNYIndex  KODFTOTYIndex  \
# 0           NaN            NaN            NaN            NaN            NaN
# 1           NaN            NaN            NaN            NaN            NaN
# 2           NaN            NaN            NaN            NaN            NaN
# 3           NaN            NaN            NaN            NaN            NaN
# 4           NaN            NaN            NaN            NaN            NaN
#
#    KOGNICUYIndex  EHCAUSIndex  KOGCGDPYIndex  PRODNFR%Index  KOGCSTOQIndex
# 0            NaN          NaN            NaN            NaN            NaN
# 1            NaN          NaN            NaN            NaN            NaN
# 2            NaN          NaN            NaN            NaN            NaN
# 3            NaN          NaN            NaN            NaN            NaN
# 4            NaN          NaN            NaN            NaN            NaN
#
# [5 rows x 142 columns]

# %% [markdown]
# 이 지점부터 daily에 비례해서 interpolation하자

# %%
df.reset_index(inplace = True)

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
# 다른 것과 다르게 이건 date를 기준으로 interpolation 하기 때문에 index화가 필요하다a
df.set_index('date', inplace = True)

# %%
df['INJCJCIndex'].isnull().sum()
# Out:
# 4330

# %%
df['INJCJCIndex'][0:50]
# Out:
# date
# 2006-01-02      NaN
# 2006-01-03      NaN
# 2006-01-04      NaN
# 2006-01-05      NaN
# 2006-01-06    326.0
# 2006-01-07      NaN
# 2006-01-08      NaN
# 2006-01-09      NaN
# 2006-01-10      NaN
# 2006-01-11      NaN
# 2006-01-12      NaN
# 2006-01-13    285.0
# 2006-01-14      NaN
# 2006-01-15      NaN
# 2006-01-16      NaN
# 2006-01-17      NaN
# 2006-01-18      NaN
# 2006-01-19      NaN
# 2006-01-20    290.0
# 2006-01-21      NaN
# 2006-01-22      NaN
# 2006-01-23      NaN
# 2006-01-24      NaN
# 2006-01-25      NaN
# 2006-01-26      NaN
# 2006-01-27    282.0
# 2006-01-28      NaN
# 2006-01-29      NaN
# 2006-01-30      NaN
# 2006-01-31      NaN
# 2006-02-01      NaN
# 2006-02-02      NaN
# 2006-02-03    289.0
# 2006-02-04      NaN
# 2006-02-05      NaN
# 2006-02-06      NaN
# 2006-02-07      NaN
# 2006-02-08      NaN
# 2006-02-09      NaN
# 2006-02-10    298.0
# 2006-02-11      NaN
# 2006-02-12      NaN
# 2006-02-13      NaN
# 2006-02-14      NaN
# 2006-02-15      NaN
# 2006-02-16      NaN
# 2006-02-17    283.0
# 2006-02-18      NaN
# 2006-02-19      NaN
# 2006-02-20      NaN
# Name: INJCJCIndex, dtype: float64

# %%
df['INJCJCIndex'].interpolate(method='time').isnull().sum()
# Out:
# 4

# %%
df['INJCJCIndex'].interpolate()[0:50]
# Out:
# date
# 2006-01-02           NaN
# 2006-01-03           NaN
# 2006-01-04           NaN
# 2006-01-05           NaN
# 2006-01-06    326.000000
# 2006-01-07    320.142857
# 2006-01-08    314.285714
# 2006-01-09    308.428571
# 2006-01-10    302.571429
# 2006-01-11    296.714286
# 2006-01-12    290.857143
# 2006-01-13    285.000000
# 2006-01-14    285.714286
# 2006-01-15    286.428571
# 2006-01-16    287.142857
# 2006-01-17    287.857143
# 2006-01-18    288.571429
# 2006-01-19    289.285714
# 2006-01-20    290.000000
# 2006-01-21    288.857143
# 2006-01-22    287.714286
# 2006-01-23    286.571429
# 2006-01-24    285.428571
# 2006-01-25    284.285714
# 2006-01-26    283.142857
# 2006-01-27    282.000000
# 2006-01-28    283.000000
# 2006-01-29    284.000000
# 2006-01-30    285.000000
# 2006-01-31    286.000000
# 2006-02-01    287.000000
# 2006-02-02    288.000000
# 2006-02-03    289.000000
# 2006-02-04    290.285714
# 2006-02-05    291.571429
# 2006-02-06    292.857143
# 2006-02-07    294.142857
# 2006-02-08    295.428571
# 2006-02-09    296.714286
# 2006-02-10    298.000000
# 2006-02-11    295.857143
# 2006-02-12    293.714286
# 2006-02-13    291.571429
# 2006-02-14    289.428571
# 2006-02-15    287.285714
# 2006-02-16    285.142857
# 2006-02-17    283.000000
# 2006-02-18    284.428571
# 2006-02-19    285.857143
# 2006-02-20    287.285714
# Name: INJCJCIndex, dtype: float64

# %%
df.isna().sum().sum()
# Out:
# 671094

# %%
df.interpolate().isna().sum().sum()
# Out:
# 5755

# %%
df = df.interpolate()

# %% [markdown]
# 근데 사잇값이 없는 경우는 어쩔 수 없이 bfill을 해야겠다.

# %%
df = df.fillna(method = 'bfill')

# %%
df.interpolate().isna().sum().sum()
# Out:
# 0

# %%
df.to_csv('bloomberg_for_linear.csv')

# %%
date = df['date']

# %%
df.drop('date', axis = 1, inplace = True)

# %%
y_target = df['KRXsemiconductor_close']

# %%
X_data = df.drop('KRXsemiconductor_close', axis = 1, inplace = False)

# %%
X_data.head()
# Out:
#    FDTRIndex_x  FDTRIndex_y  USGG3MIndex  USGG10YRIndex  USTW$Index  \
# 0         4.25         4.25       4.0736         4.3911     86.0274
# 1         4.25         4.25       4.1144         4.3637     85.0983
# 2         4.25         4.25       4.1798         4.3422     84.5642
# 3         4.25         4.25       4.1793         4.3519     84.7247
# 4         4.25         4.25       4.1985         4.3733     84.3844
#
#    INJCJCIndex  INJCSPIndex  USEMNCHGIndex  NFPPCHIndex  NFPTCHIndex  ...  \
# 0        326.0       2561.0          398.0        310.0        278.0  ...
# 1        326.0       2561.0          398.0        310.0        278.0  ...
# 2        326.0       2561.0          398.0        310.0        278.0  ...
# 3        326.0       2561.0          398.0        310.0        278.0  ...
# 4        326.0       2561.0          398.0        310.0        278.0  ...
#
#    USCABALIndex  JNVNIYOYIndex  COSTNFR%Index  KOGNICNYIndex  KODFTOTYIndex  \
# 0        -198.2           13.6            5.2            3.0           -0.7
# 1        -198.2           13.6            5.2            3.0           -0.7
# 2        -198.2           13.6            5.2            3.0           -0.7
# 3        -198.2           13.6            5.2            3.0           -0.7
# 4        -198.2           13.6            5.2            3.0           -0.7
#
#    KOGNICUYIndex  EHCAUSIndex  KOGCGDPYIndex  PRODNFR%Index  KOGCSTOQIndex
# 0            5.2        -5.67            5.6            2.9            0.6
# 1            5.2        -5.67            5.6            2.9            0.6
# 2            5.2        -5.67            5.6            2.9            0.6
# 3            5.2        -5.67            5.6            2.9            0.6
# 4            5.2        -5.67            5.6            2.9            0.6
#
# [5 rows x 140 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_data, y_target, test_size = 0.3, random_state = 156)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = lr.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

# %%
print('MSE: {0: .3f}, RMSE : {1:.3F}'.format(mse, rmse))
print('Variance Score : {0:3f}'.format(r2_score(y_test, y_pred)))
# Out:
# MSE:  1924.843, RMSE : 43.873
# Variance Score : 0.991646

# %%
# intercept, coefficients 확인
print('절편 값 :', lr.intercept_)
print('회귀 계수 값 :', np.round(lr.coef_, 1))
# Out:
# 절편 값 : -10568.408222977465
# 회귀 계수 값 : [ 5.56340802e+10 -5.56340803e+10  1.81000000e+01  1.09000000e+02
#  -7.80000000e+00  2.00000000e-01  0.00000000e+00  0.00000000e+00
#  -8.00000000e-01  4.00000000e-01  2.00000000e-01  2.40000000e+00
#  -2.80000000e+00 -3.80000000e+00 -3.00000000e-01 -8.30000000e+00
#   4.51000000e+01 -2.06200000e+02 -4.41000000e+01  2.16000000e+01
#   1.63200000e+02  1.93000000e+02  8.00000000e+00 -3.30000000e+00
#   1.50000000e+00 -3.01000000e+01 -8.00000000e-01  4.80000000e+00
#   3.40000000e+01  1.10000000e+00  4.52000000e+01 -2.77000000e+01
#  -4.70000000e+00  1.10000000e+00  1.20000000e+00  1.80000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   4.00000000e-01  1.50000000e+01 -2.38000000e+01  5.80000000e+00
#  -2.60000000e+01  9.80000000e+00 -4.90000000e+01 -1.40000000e+01
#   4.52000000e+01  3.00000000e-01 -5.04000000e+01 -4.62000000e+01
#   4.91000000e+01  4.80000000e+00 -2.07000000e+01  3.02000000e+01
#  -1.54000000e+01  1.60000000e+00  2.79000000e+01  1.19000000e+01
#   5.99000000e+01 -4.93000000e+01  4.60000000e+01  2.85000000e+01
#  -2.20000000e+00 -5.33000000e+01  2.21000000e+01  8.62000000e+01
#  -9.68000000e+01 -1.09100000e+02 -5.39700000e+02  3.17000000e+01
#  -1.02000000e+02  6.71000000e+01  4.65000000e+01 -3.81000000e+01
#   8.19000000e+01  9.69000000e+01  2.17000000e+01  6.00000000e+00
#  -3.18000000e+01  1.87700000e+02 -5.65000000e+01  7.54000000e+01
#   2.68000000e+01  6.03000000e+01 -1.45700000e+02  1.00000000e-01
#   5.00000000e-01 -8.00000000e-01  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -0.00000000e+00  0.00000000e+00
#   1.00000000e-01 -0.00000000e+00 -4.00000000e-01 -2.20000000e+00
#   1.40000000e+00 -9.90000000e+00 -1.36000000e+01 -7.43000000e+01
#  -6.81700000e+02 -2.51980000e+03 -1.02700000e+02  1.48100000e+02
#   0.00000000e+00 -8.20000000e+00 -4.00000000e-01 -1.92000000e+01
#   1.38000000e+01 -3.89000000e+01  7.07000000e+02  6.50200000e+02
#  -9.08500000e+02 -7.33000000e+02  2.53000000e+01  1.37900000e+02
#   7.60000000e+00 -3.20000000e+00  2.43600000e+02 -5.09000000e+01
#  -9.70000000e+00  1.39000000e+02  1.81300000e+02  6.36000000e+01
#   3.63000000e+01 -1.20000000e+00 -1.00000000e+00 -6.00000000e+00
#   4.40000000e+00  1.00000000e+01 -4.11000000e+01 -1.04000000e+01
#  -1.49200000e+02  7.56000000e+01 -6.27000000e+01  5.47000000e+01]

# %%
# 피쳐별 회귀 계수 값으로 정렬
coeff = pd.Series(data = np.round(lr.coef_, 1), index = X_data.columns)
coeff.sort_values(ascending = False)
# Out:
# FDTRIndex_x      5.563408e+10
# KOECPRCYIndex    7.070000e+02
# KOECSPRQIndex    6.502000e+02
# GDPCYOYIndex     2.436000e+02
# USURTOTIndex     1.930000e+02
#                      ...
# MGT2TBIndex     -6.817000e+02
# KOECFCOYIndex   -7.330000e+02
# KOECFCSYIndex   -9.085000e+02
# MGT2REIndex     -2.519800e+03
# FDTRIndex_y     -5.563408e+10
# Length: 140, dtype: float64

# %% [markdown]
# Standard Scaler를 써서 다시 해보기

# %%
y_target = step['KRXsemiconductor_close']

# %%
X_data = step.drop('KRXsemiconductor_close', axis = 1, inplace = False)

# %%
col_name = X_data.columns

# %%
X_data = StandardScaler().fit_transform(X_data)

# %%
X_data = pd.DataFrame(X_data, columns = col_name)

# %%
X_data.head()
# Out:
#    FDTRIndex_x  FDTRIndex_y  USGG3MIndex  USGG10YRIndex  USTW$Index  \
# 0     1.703673     1.703673     1.792661       1.546863    0.588171
# 1     1.703673     1.703673     1.817820       1.518711    0.469832
# 2     1.703673     1.703673     1.858149       1.496621    0.401804
# 3     1.703673     1.703673     1.857841       1.506587    0.422247
# 4     1.703673     1.703673     1.869681       1.528574    0.378903
#
#    INJCJCIndex  INJCSPIndex  USEMNCHGIndex  NFPPCHIndex  NFPTCHIndex  ...  \
# 0    -0.139985    -0.347859       1.036945     0.959475     0.781777  ...
# 1    -0.139985    -0.347859       1.036945     0.959475     0.781777  ...
# 2    -0.139985    -0.347859       1.036945     0.959475     0.781777  ...
# 3    -0.139985    -0.347859       1.036945     0.959475     0.781777  ...
# 4    -0.139985    -0.347859       1.036945     0.959475     0.781777  ...
#
#    USCABALIndex  JNVNIYOYIndex  COSTNFR%Index  KOGNICNYIndex  KODFTOTYIndex  \
# 0     -2.110325       1.356469       1.071675      -0.178421      -1.844127
# 1     -2.110325       1.356469       1.071675      -0.178421      -1.844127
# 2     -2.110325       1.356469       1.071675      -0.178421      -1.844127
# 3     -2.110325       1.356469       1.071675      -0.178421      -1.844127
# 4     -2.110325       1.356469       1.071675      -0.178421      -1.844127
#
#    KOGNICUYIndex  EHCAUSIndex  KOGCGDPYIndex  PRODNFR%Index  KOGCSTOQIndex
# 0      -0.049769    -2.043672       0.185815       0.743354      -0.709671
# 1      -0.049769    -2.043672       0.185815       0.743354      -0.709671
# 2      -0.049769    -2.043672       0.185815       0.743354      -0.709671
# 3      -0.049769    -2.043672       0.185815       0.743354      -0.709671
# 4      -0.049769    -2.043672       0.185815       0.743354      -0.709671
#
# [5 rows x 140 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_data, y_target, test_size = 0.3, random_state = 156)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = lr.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

# %%
print('MSE: {0: .3f}, RMSE : {1:.3F}'.format(mse, rmse))
print('Variance Score : {0:3f}'.format(r2_score(y_test, y_pred)))
# Out:
# MSE:  1926.117, RMSE : 43.888
# Variance Score : 0.991640

# %%
# intercept, coefficients 확인
print('절편 값 :', lr.intercept_)
print('회귀 계수 값 :', np.round(lr.coef_, 1))
# Out:
# 절편 값 : 1656.3022261366527
# 회귀 계수 값 : [-5.4200e+01 -5.4200e+01  2.9100e+01  1.0610e+02 -6.1100e+01  2.4900e+01
#   1.9000e+01  1.2400e+01 -1.7960e+02  9.0400e+01  1.0000e+01  3.5400e+01
#  -5.0800e+01 -3.4700e+01 -4.8000e+00 -2.5000e+00  8.3000e+00 -2.2900e+01
#  -5.4900e+01  2.1600e+01  1.2820e+02  3.9020e+02  4.9680e+02 -7.9000e+00
#   2.0400e+01 -2.3600e+02 -2.1500e+01  3.0300e+01  2.7050e+02  7.7000e+00
#   8.6000e+00 -1.2620e+02 -4.4900e+01  1.3800e+01  2.2000e+00  1.7770e+02
#   6.7800e+01  3.6600e+01  2.9330e+02 -1.8200e+02  1.0900e+01  1.2850e+02
#  -3.0360e+02  4.4900e+01 -1.9050e+02  6.3800e+01 -3.1000e+02 -9.4100e+01
#   2.0380e+02  6.0000e-01 -8.8700e+01 -9.1400e+01  9.1700e+01  9.3000e+00
#  -7.7500e+01  6.5100e+01 -1.7900e+01  4.2000e+00  2.3800e+01  6.9000e+00
#   2.0980e+02 -3.0300e+01  3.7200e+01  2.0300e+01 -1.9000e+00 -7.7300e+01
#   1.2200e+01  1.1470e+02 -2.6100e+01 -1.1000e+02 -3.4600e+01  1.3500e+01
#  -3.8200e+01  1.0280e+02  5.4860e+02 -4.4580e+02  1.1526e+03  1.2148e+03
#   2.5070e+02  5.9300e+01 -4.4650e+02  1.1610e+02 -3.4530e+02  4.0120e+02
#   2.6660e+02  5.0420e+02 -4.5930e+02  4.3800e+01  1.9390e+02 -8.6560e+02
#   9.9200e+01 -1.3190e+02  3.4000e+00  1.9000e+00 -1.8800e+01  2.2900e+01
#   7.5000e+00 -1.1000e+00 -7.4000e+00 -9.0000e+00  1.2500e+01 -5.6900e+01
#  -1.0360e+02 -3.8400e+01 -4.1200e+01 -1.3660e+02 -2.0930e+02  1.0507e+03
#   3.3700e+01 -9.5800e+01 -3.3000e+00 -1.4870e+02  5.6300e+01 -1.3270e+02
#   1.2989e+03  4.8290e+02 -5.2350e+02 -1.1046e+03  5.4300e+01  2.8860e+02
#   1.8500e+01 -1.8000e+01  3.8250e+02 -8.4200e+01 -1.8700e+01  8.9500e+01
#   2.6160e+02  5.2600e+01  1.8600e+01 -2.7564e+03 -3.7000e+01 -5.7400e+01
#   1.5400e+01  2.4300e+01 -5.3000e+01 -2.3200e+01 -1.8670e+02  1.6400e+02
#  -1.2370e+02  5.0400e+01]

# %%
# 피쳐별 회귀 계수 값으로 정렬
coeff = pd.Series(data = np.round(lr.coef_, 1), index = X_data.columns)
coeff.sort_values(ascending = False)
# Out:
# KOECPRCYIndex    1298.9
# SKLILCIndex      1214.8
# SKLILIIndex      1152.6
# OEUSKLARIndex    1050.7
# KOIPMSIndex       548.6
#                   ...
# CPTICHNGIndex    -459.3
# KOECFCSYIndex    -523.5
# PIDSPINXIndex    -865.6
# KOECFCOYIndex   -1104.6
# GDPCUR$Index    -2756.4
# Length: 140, dtype: float64

# %%
# Ridge regression, alpha = 10
ridge = Ridge(alpha = 10)
neg_mse_scores = cross_val_score(ridge, X_data, y_target, scoring = "neg_mean_squared_error", cv = 5)
rmse_scores = np.sqrt(-1 * neg_mse_scores)
avg_rmse = np.mean(rmse_scores)

# %%
print(' 5 folds의 개별 Negative MSE scores : ', np.round(neg_mse_scores, 3))
print(' 5 folds의 개별 RMSE scores : ', np.round(rmse_scores, 3))
print(' 5 folds의 평균 RMSE : {0:.3f}'.format(avg_rmse))
# Out:
#  5 folds의 개별 Negative MSE scores :  [ -34865.031 -135292.482 -166810.408 -117224.669 -150615.07 ]
#  5 folds의 개별 RMSE scores :  [186.722 367.821 408.424 342.381 388.092]
#  5 folds의 평균 RMSE : 338.688

# %%
# alpha 값 변경에 따른 RMSE 체크
alphas = [0, 0.1, 1, 10, 100]

# alpha list 값 변경해가며 평균 RMSE 측정
for alpha in alphas:
    ridge = Ridge(alpha = alpha)
    
    # cross validation score를 이용해서 5 fold 의 평균 RMSE 계산
    neg_mse_scores = cross_val_score(ridge, X_data, y_target, scoring = "neg_mean_squared_error", cv = 5)
    avg_rmse = np.mean(np.sqrt(-1 * neg_mse_scores))
    print('alpha {0}일 때 5 fold의 평균 RMSE : {1:.3f}'.format(alpha, avg_rmse))
# Out:
# /Users/mokpolar/opt/anaconda3/envs/tf-py36/lib/python3.6/site-packages/sklearn/linear_model/ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.08848e-19): result may not be accurate.
#   overwrite_a=True).T
# /Users/mokpolar/opt/anaconda3/envs/tf-py36/lib/python3.6/site-packages/sklearn/linear_model/ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=3.24512e-18): result may not be accurate.
#   overwrite_a=True).T
# alpha 0일 때 5 fold의 평균 RMSE : 3225198340495.704
# alpha 0.1일 때 5 fold의 평균 RMSE : 585.229
# alpha 1일 때 5 fold의 평균 RMSE : 487.247
# alpha 10일 때 5 fold의 평균 RMSE : 338.688
# alpha 100일 때 5 fold의 평균 RMSE : 343.372

# %%
# alpha 값의 변화에 따른 피쳐의 회귀 계수값을 시각화
# 5열 matplotlib 축 생성
fig, axs = plt.subplots(figsize = (20, 18), nrows = 1, ncols = 5)

# 각 alpha에 따른 회귀 계수 값을 데이터로 저장하기 위한 DataFrame 
coeff_df = pd.DataFrame()

# alpha 리스트 값을 차례로 입력해 회귀계수 값 시각화 및 데이터 저장
# pos는 axis 위치 지정
for pos, alpha in enumerate(alphas):
    ridge = Ridge(alpha = alpha)
    ridge.fit(X_data, y_target)
    # alpha 에 따른 피쳐별로 회귀 계수를 Series로 변환하고 이를 DataFrame 컬럼으로 추가
    coeff = pd.Series(data = ridge.coef_, index = X_data.columns)
    colname = 'alpha:' + str(alpha)
    coeff_df[colname] = coeff
    # 막대 그래프로 각 alpha 값에서의 회귀 계수를 시각화. sorting
    coeff = coeff.sort_values(ascending = False)
    axs[pos].set_title(colname)
    axs[pos].set_xlim(-3, 6)
    sns.barplot(x = coeff.values, y = coeff.index, ax = axs[pos])

plt.show()

# %%
# alpha값을 증가시킬 수록 회귀 계쑤값이 작아지는 것 확인
# DataFrame에 저장된 alpha값의 변화에 따른 Ridge 회귀계수값 확인
ridge_alphas = [0, 0.1, 1, 10, 100]
sort_column = 'alpha:' + str(ridge_alphas[0])
coeff_df.sort_values(by = sort_column, ascending = False)
# Out:
#                     alpha:0   alpha:0.1     alpha:1   alpha:10  alpha:100
# FDTRIndex_y    8.051227e+14  -57.046172  -54.350772 -27.673721  -7.533072
# SKLILCIndex    1.646651e+03  290.037722   99.968916  44.876057  24.753528
# KOECPRCYIndex  1.422231e+03  423.582415  153.553448  59.800085  22.982109
# OEUSKLARIndex  1.030702e+03  592.192225  177.616426  68.065669  33.584179
# SKLILIIndex    9.478201e+02  249.862716  145.203523  75.119379  38.660476
# ...                     ...         ...         ...        ...        ...
# CPTICHNGIndex -6.275013e+02  150.670536   35.456923 -29.981143 -20.790613
# PIDSPINXIndex -7.474418e+02 -553.619667 -202.848935 -10.325328  16.911871
# KOECFCOYIndex -1.215360e+03 -162.258601   58.199476  54.419129  27.569720
# GDPCUR$Index  -3.069804e+03 -585.151422 -107.913994   7.564465  18.218524
# FDTRIndex_x   -8.051227e+14  -57.046172  -54.350772 -27.673721  -7.533072
#
# [140 rows x 5 columns]

# %%
coeff_df['alpha:100'].sort_values(ascending = False)
# Out:
# GDPCQOQIndex     69.039559
# KOPPIYOYIndex    60.183941
# KODFTOTYIndex    51.308125
# LEICHNGIndex     50.421606
# SKLILYIndex      47.694632
#                    ...
# PRODNFR%Index   -37.226644
# KOECGCPYIndex   -37.379411
# JNVNIYOYIndex   -38.523854
# LEINWCNIndex    -50.230455
# KOIPMCYIndex    -98.504745
# Name: alpha:100, Length: 140, dtype: float64

# %%
coeff_df[coeff_df['alpha:100'] > 0]['alpha:100'].sort_values(ascending = False)
# Out:
# GDPCQOQIndex     69.039559
# KOPPIYOYIndex    60.183941
# KODFTOTYIndex    51.308125
# LEICHNGIndex     50.421606
# SKLILYIndex      47.694632
#                    ...
# NAPMPMIIndex      2.948283
# CICRTOTIndex      2.590004
# KOIMPTIYIndex     1.771330
# CFNAIMA3Index     1.394504
# USHETOT%Index     0.975507
# Name: alpha:100, Length: 79, dtype: float64

# %%
len(coeff_df[coeff_df['alpha:100'] > 0]['alpha:100'].sort_values(ascending = False))
# Out:
# 79

# %% [markdown]
# 그러니까 여기까지 정리하면 StandardScaler를 적용했을 때,
# 일단 분석에 유의미한 영향을 주는 회귀 계수 0이상의 변수만 봤을 때 그 갯수는 65개임

# %%
a = coeff_df[coeff_df['alpha:100'] > 0]['alpha:100']

# %%
a = a.index

# %%
a = list(a)

# %%
a
# Out:
# ['USGG3MIndex',
#  'USGG10YRIndex',
#  'INJCJCIndex',
#  'INJCSPIndex',
#  'OUTFGAFIndex',
#  'KOFETOT%Index',
#  'KOEXTOTYIndex',
#  'USHETOT%Index',
#  'USHEYOYIndex',
#  'USURTOTIndex',
#  'KOFETOTIndex',
#  'NAPMPRICIndex',
#  'KOCPIIndex',
#  'SKCITTLIndex',
#  'CHPMINDXIndex',
#  'USWHTOTIndex',
#  'NAPMPMIIndex',
#  'SKBSICIndex',
#  'CONSSENTIndex',
#  'LEIWKIJIndex',
#  'KOEXTOTIndex',
#  'NFPTIndex',
#  'USEMTOTIndex',
#  'KOIVCONYIndex',
#  'KOEXPTIYIndex',
#  'KOIMPTIYIndex',
#  'LEIYOYIndex',
#  'IPYOYIndex',
#  'KOIPIMOMIndex',
#  'TMNOCHNGIndex',
#  'KOIMPTIMIndex',
#  'LEIIRTEIndex',
#  'PITLYOYIndex',
#  'PITLCHNGIndex',
#  'KOPPIYOYIndex',
#  'CFNAIMA3Index',
#  'LEICHNGIndex',
#  'LEIACEIndex',
#  'SKLILYIndex',
#  'KOPPIMOMIndex',
#  'KOIPMSIndex',
#  'KOIPISAIndex',
#  'SKLILIIndex',
#  'SKLILCIndex',
#  'SKLICIIndex',
#  'LEIAVGWIndex',
#  'KOPPIIndex',
#  'LEITOTLIndex',
#  'KOEXPTIIndex',
#  'LEISTKPIndex',
#  'LEIBPIndex',
#  'PIDSPINXIndex',
#  'LEIMNOIndex',
#  'KOBPFINIndex',
#  'KOBPTBIndex',
#  'KODIBALIndex',
#  'FRNTTNETIndex',
#  'CICRTOTIndex',
#  'MGT2TBIndex',
#  'OEUSKLAPIndex',
#  'OEUSKLARIndex',
#  'OEKRN022Index',
#  'KOECIMPYIndex',
#  'KOECPRCYIndex',
#  'KOECFCOYIndex',
#  'KOECSEMQIndex',
#  'GDPCQOQIndex',
#  'GDPCYOYIndex',
#  'GDPCTOT%Index',
#  'GDPCURYIndex',
#  'KOECGVTYIndex',
#  'GDPCPCECIndex',
#  'GDPCUR$Index',
#  'USCABALIndex',
#  'KODFTOTYIndex',
#  'KOGNICUYIndex',
#  'EHCAUSIndex',
#  'KOGCGDPYIndex',
#  'KOGCSTOQIndex']

# %% [markdown]
# 이제 이 과정을 계단식이 아니라 선으로 이었을때도 동일한지를 봐야 한다
