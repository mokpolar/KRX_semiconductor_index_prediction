# %%
ls
# Out:
# 00. _wd - working day.txt
# 01. KRXworkingDay_from1980.csv
# CSV/
# Currency/
# Currency_describe_directory_list.ipynb
# KOR/
# KRX반도체_SK하이닉스_KOSPI200.xlsx
# Korean_stock_describe.ipynb
# README.md
# Ridge_baseline.ipynb
# Taiwan/
# Taiwan_describe_directory_list.ipynb
# US/
# US_stock_describe_list_final.ipynb
# _Rhistory
# bloomberg_dataprocessing-Copy1.ipynb
# bloomberg_dataprocessing.ipynb
# data_change_ver0.1.csv
# data_change_ver0.2.csv
# df_test.csv
# df_test2.csv
# economic_smc.csv
# eda.ipynb
# eda_from_change.ipynb
# lasso_baseline.ipynb
# list
# list.csv
# logistic_classifier_baseline.ipynb
# new/
# ols_baseline_regression.ipynb
# preprocessing.ipynb
# preprocessing.py
# semiconductor_bloomberg_preprocessing.ipynb
# semiconductor_feature_list_bloomberg.xlsx
# total_data.csv
# totaldata_preprocessing.ipynb
# tree_based_regressor_baseline.ipynb

# %%
pwd
# Out:
# '/Users/mokpolar/Documents/GitHub/KRX_semiconductor_index_prediction'

# %%
import pandas as pd
import re
# %matplotlib inline

# %%
eco = pd.read_csv('/Users/mokpolar/Downloads/bloomberg_raw/economic.csv')

# %%
eco.set_index('col0', inplace = True)

# %%
eco.head()
# Out:
#                 col1  col2        col3  col4
# col0
# GDP CQOQ Index     0     1  03/31/1981   8.1
# GDP CQOQ Index     0     1  06/30/1981  -2.9
# GDP CQOQ Index     0     1  09/30/1981   4.9
# GDP CQOQ Index     0     1  12/31/1981  -4.3
# GDP CQOQ Index     0     1  03/31/1982  -6.1

# %%
economic = eco.loc[['GDP CQOQ Index',
'GDP CYOY Index',
'GDPCTOT% Index',
'GPDITOC% Index',
'GPGSTOC% Index',
'RGCDCIPI Index',
'GDP CUR$ Index',
'GDP CURY Index',
'GDP PIQQ Index',
'GDPCPCEC Index',
'CPI YOY Index',
'CPI XYOY Index',
'PCE DEFY Index',
'PCE CYOY Index',
'CPI CHNG Index',
'CPUPXCHG Index',
'FDIDFDMO Index',
'FDIDSGMO Index',
'FDIUFDYO Index',
'FDIUSGYO Index',
'USURTOT Index',
'USUDMAER Index',
'INJCJC Index',
'INJCSP Index',
'NFP TCH Index',
'NFP PCH Index',
'USMMMNCH Index',
'AWH TOTL Index',
'USWHTOT Index',
'USEMTOT Index',
'USEMNCHG Index',
'USERTOT Index',
'EMDINP1M Index',
'JOLTOPEN Index',
'JOLTHIRS Index',
'JOLTSEPS Index',
'CHALYOY% Index',
'ADP CHNG Index',
'USHEYOY Index',
'USHETOT% Index',
'ECI YOY Index',
'COSTNFR% Index',
'PRODNFR% Index',
'IP  YOY Index',
'IP  CHNG Index',
'CPTICHNG Index',
'TMNOCHNG Index',
'DGNOYOY Index',
'DGNOCHNG Index',
'MTIBCHNG Index',
'MWINCHNG Index',
'MGT2TB Index',
'MGT2MA Index',
'MGT2WH Index',
'MGT2WHDU Index',
'MGT2RE Index',
'IP Index',
'MTSLRL$ Index',
'AGWHTOTL Index',
'NFP T Index',
'USEMTOT Index',
'PIDSPINX Index',
'NAPMPMI Index',
'NAPMNMI Index',
'NAPMPRIC Index',
'MPMIUSCA Index',
'MPMIUSMA Index',
'MPMIUSSA Index',
'CFNAI Index',
'CFNAIMA3 Index',
'OUTFGAF Index',
'EMPRGBCI Index',
'RCHSINDX Index',
'CHPMINDX Index',
'MAPMINDX Index',
'OEUSKLAR Index',
'OEUSKLAP Index',
'LEI TOTL Index',
'LEI YOY Index',
'LEI CHNG Index',
'LEI AVGW Index',
'LEI WKIJ Index',
'LEI NWCN Index',
'NAPMNEWO Index',
'LEI MNO Index',
'LEI BP Index',
'LEI STKP Index',
'LEI LCI Index',
'LEI IRTE Index',
'LEI ACE Index',
'RSTAMOM Index',
'RSTAXMOM Index',
'RSTAYOY Index',
'RSTAXYOY Index',
'MBRXYOYW Index',
'SAARTOTL Index',
'SAARDTOT Index',
'CONCCONF Index',
'CONSSENT Index',
'COMFCOMF Index',
'COMFBTWR Index',
'PITLYOY Index',
'PITLCHNG Index',
'PCE CHY% Index',
'PCE CHNC Index',
'PIDSDPS Index',
'CICRTOT Index',
'EHCAUS Index',
'USCABAL Index',
'USTBTOT Index',
'USTBEXP Index',
'USTBIMP Index',
'USTBEXPY Index',
'USTBIMPY Index',
'IMP1YOY% Index',
'IMP1CHNG Index',
'FRNTTOTL Index',
'FRNTTNET Index',
'FDTR Index',
'USGG3M Index',
'USGG10YR Index',
'USTW$ Index',
'JNVNYOYS Index',
'JNVNIYOY Index',
'MPMIJPCA Index',
'MPMIJPMA Index',
'MPMIJPSA Index',
'CNGDPYOY Index',
'GDPNTTLY Index',
'CHEFTYOY Index',
'CNPPIY Index',
'CPMINDX Index',
'CPMINORD Index',
'CPMINEXO Index',
'CNCILI Index',
'CNFREXPY Index',
'CNFRIMPY Index',
'KOGDPYOY Index',
'KOGDPQOQ Index',
'KOECPRCY Index',
'KOECGCPY Index',
'KOECGVTY Index',
'KOECEXPY Index',
'KOECIMPY Index',
'KOECSPRQ Index',
'KOECGCSY Index',
'KOECSGVQ Index',
'KOECSEMQ Index',
'KOECSIMQ Index',
'KOECFCOY Index',
'KOECFCSY Index',
'OEKRN022 Index',
'KOGNICNY Index',
'KOGNICUY Index',
'KOGCGDPY Index',
'KOGCSTOQ Index',
'KODFTOTY Index',
'KOCPI Index',
'KOCPIYOY Index',
'KOCPIMOM Index',
'SKCITTL Index',
'SKCIYOY Index',
'SKCIMOM Index',
'KOCLLNS Index',
'KOPPI Index',
'KOPPIYOY Index',
'KOPPIMOM Index',
'KOEAUERS Index',
'KOEAEMPY Index',
'KOUETTY Index',
'KOEAPY Index',
'KOEAEPR Index',
'KOQEEYOY Index',
'KOWDR Index',
'KOULMGF Index',
'KOULMGFY Index',
'KOLPI Index',
'KOLPIY Index',
'SKLIOTAR Index',
'KOIPISA Index',
'KOIPIY Index',
'KOIPIMOM Index',
'KOIPMS Index',
'KOIPMY Index',
'KOIPMSM Index',
'KOPSIY Index',
'KOPIIY Index',
'KOIPMC Index',
'KOIPMCY Index',
'KOIPOPSM Index',
'KOIVCPEY Index',
'KOIVCCY Index',
'KOIVCONY Index',
'KOCGCGY Index',
'KOCGCGSM Index',
'KOSVTOTY Index',
'KOSVTOTM Index',
'KOVMPROD Index',
'KOBSMC Index',
'KOBSNMC Index',
'SKBSIC Index',
'SKBSICSA Index',
'MPMIKRMA Index',
'OEKRKLAR Index',
'OEKRKLAP Index',
'SKLILI Index',
'SKLILY Index',
'SKLILC Index',
'SKLICI Index',
'SKLIINVC Index',
'SKLICONE Index',
'SKLIMORD Index',
'SKLICONT Index',
'SKLINBAR Index',
'SKLIOTAR Index',
'SKLISPRC Index',
'SKLIINTR Index',
'SKLIIPAL Index',
'SKLICNST Index',
'SKLISVCI Index',
'SKLIWNRS Index',
'SKLISHPP Index',
'SKLIIMPT Index',
'SKLIEMPP Index',
'SKLILAP Index',
'SKLILAI Index',
'SKLINE Index',
'SKLICPY Index',
'KOBONTL Index',
'KOHSTR Index',
'KOHPTTL Index',
'KOHPTYOY Index',
'KOHCTTL Index',
'KOHCTYOY Index',
'KOBLTHML Index',
'KOBLTHMY Index',
'KOUHTTL Index',
'KORST Index',
'KORSTY Index',
'KODSDEPT Index',
'KODSDISC Index',
'KOVMTOTS Index',
'KOVMDOMS Index',
'KOVMEXPS Index',
'KOCCCSI Index',
'KOHOINC Index',
'KOHOINCY Index',
'KOHEUINY Index',
'KOHHD Index',
'KOHHDY Index',
'KOHHL Index',
'KOHHLY Index',
'EOKOS002 Index',
'KOBPCB Index',
'EHCAKRY Index',
'KOBPFIN Index',
'KOBPCA Index',
'KODIBAL Index',
'KOBPTB Index',
'KOTRBAL Index',
'KOEXTOT Index',
'KOIMTOT Index',
'KOEXTOTY Index',
'KOIMTOTY Index',
'KOEXPTI Index',
'KOEXPTIY Index',
'KOEXPTIM Index',
'KOIMPTI Index',
'KOIMPTIY Index',
'KOIMPTIM Index',
'KOFDIT Index',
'KOFDITY Index',
'KOELTOT Index',
'KOGFBAL Index',
'KOGFTEXP Index',
'KOGFTR Index',
'G7BBKORE Index',
'GDDBSOKO Index',
'KOMSMBY Index',
'KOMSM1Y Index',
'KOMSM2Y Index',
'KOMSM3Y Index',
'KOMSLY Index',
'KOMSM1FY Index',
'KOFETOT Index',
'KOFETOT% Index',
'KORP7D Index',
'KOCICOBA Index',
'KOCICONF Index',
'KRBO3M Index',
'KWCDC Curncy',
'GVSK10YR Index'], :]

# %%
eco.head()
# Out:
#                 col1  col2        col3  col4
# col0
# GDP CQOQ Index     0     1  03/31/1981   8.1
# GDP CQOQ Index     0     1  06/30/1981  -2.9
# GDP CQOQ Index     0     1  09/30/1981   4.9
# GDP CQOQ Index     0     1  12/31/1981  -4.3
# GDP CQOQ Index     0     1  03/31/1982  -6.1

# %%
eco.set_index('col0', inplace = True)

# %%
eco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 821348 entries, GDP CQOQ Index to IDR Curncy
# Data columns (total 4 columns):
# col1    821348 non-null int64
# col2    821348 non-null int64
# col3    821348 non-null object
# col4    821348 non-null object
# dtypes: int64(2), object(2)
# memory usage: 51.3+ MB

# %%
economic.reset_index()
# Out:
#                   col0  col1  col2        col3   col4
# 0       GDP CQOQ Index     0     1  03/31/1981    8.1
# 1       GDP CQOQ Index     0     1  06/30/1981   -2.9
# 2       GDP CQOQ Index     0     1  09/30/1981    4.9
# 3       GDP CQOQ Index     0     1  12/31/1981   -4.3
# 4       GDP CQOQ Index     0     1  03/31/1982   -6.1
# ...                ...   ...   ...         ...    ...
# 148415  GVSK10YR Index     0     1  10/25/2019  1.685
# 148416  GVSK10YR Index     0     1  10/28/2019  1.777
# 148417  GVSK10YR Index     0     1  10/29/2019  1.766
# 148418  GVSK10YR Index     0     1  10/30/2019  1.744
# 148419  GVSK10YR Index     0     1  10/31/2019   1.73
#
# [148420 rows x 5 columns]

# %%
eco.reset_index(inplace = True)

# %%
eco.to_csv('economic_smc.csv')

# %% [markdown]
# ### --- 여기까지는 Column 뽑아내기 ---

# %%
eco = pd.read_csv('economic_smc.csv')

# %%
len(eco)
# Out:
# 148420

# %%
eco.head()
# Out:
#              col0  col1  col2        col3  col4
# 0  GDP CQOQ Index     0     1  03/31/1981   8.1
# 1  GDP CQOQ Index     0     1  06/30/1981  -2.9
# 2  GDP CQOQ Index     0     1  09/30/1981   4.9
# 3  GDP CQOQ Index     0     1  12/31/1981  -4.3
# 4  GDP CQOQ Index     0     1  03/31/1982  -6.1

# %%
# 일단 m달린 데이터를 제거해버리자
def delete_m(c):
    if c[-1] == 'm':
        c = ' '
    else:
        pass
    return c

# %%
# M달린 데이터도 제거해버리자
def delete_M(c):
    if c[-1] == 'M':
        c = ' '
    else:
        pass
    return c

# %%
eco.head()
# Out:
#              col0  col1  col2        col3  col4
# 0  GDP CQOQ Index     0     1  03/31/1981   8.1
# 1  GDP CQOQ Index     0     1  06/30/1981  -2.9
# 2  GDP CQOQ Index     0     1  09/30/1981   4.9
# 3  GDP CQOQ Index     0     1  12/31/1981  -4.3
# 4  GDP CQOQ Index     0     1  03/31/1982  -6.1

# %%
# map + lambda 콤보로 이거 날리자 m , M 달린건 전부  ' ' 으로 변환
eco['col4'] = eco['col4'].map(lambda x: delete_m(x))

# %%
# ' '으로 만들어진거 전부 드롭
eco.drop(eco[eco['col4'] == ' '].index, axis = 0, inplace = True)

# %%
len(eco[eco['col4'] == ' '])
# Out:
# 0

# %%
eco['col4'] = eco['col4'].map(lambda x: delete_M(x))

# %%
eco.drop(eco[eco['col4'] == ' '].index, axis = 0, inplace = True)

# %%
len(eco[eco['col4'] == ' '])
# Out:
# 0

# %%
# 이상한 거 다빠졌으니까 numeric으로 변환
eco['col4'] = pd.to_numeric(eco['col4'])

# %%
# 애초에 그런게 별로 안되었으므로 빠진 데이터는 몇개 없다. 
len(eco)
# Out:
# 148332

# %%
# col3 type datetime으로 만들기 
eco['col3'] = pd.to_datetime(eco['col3'])

# %%
eco['col4'].unique()
# Out:
# array([ 8.1  , -2.9  ,  4.9  , ...,  1.528,  1.647,  1.744])

# %%
# 변수 종류는 289개
len(eco['col0'].unique())
# Out:
# 289

# %%
# 변수별로 데이터 갯수 확인 필요 뭐야 이거 시박 다 다르네
for i, j in enumerate(eco['col0'].unique()):
    print(i, eco['col0'].unique()[i], len(eco[eco['col0'] == j]))
# Out:
# 0 GDP CQOQ Index 152
# 1 GDP CYOY Index 152
# 2 GDPCTOT% Index 152
# 3 GPDITOC% Index 152
# 4 GPGSTOC% Index 152
# 5 RGCDCIPI Index 80
# 6 GDP CUR$ Index 152
# 7 GDP CURY Index 152
# 8 GDP PIQQ Index 152
# 9 GDPCPCEC Index 152
# 10 CPI YOY Index 455
# 11 CPI XYOY Index 455
# 12 PCE DEFY Index 455
# 13 PCE CYOY Index 455
# 14 CPI CHNG Index 455
# 15 CPUPXCHG Index 455
# 16 FDIDFDMO Index 118
# 17 FDIDSGMO Index 113
# 18 FDIUFDYO Index 107
# 19 FDIUSGYO Index 107
# 20 USURTOT Index 456
# 21 USUDMAER Index 300
# 22 INJCJC Index 1983
# 23 INJCSP Index 1982
# 24 NFP TCH Index 456
# 25 NFP PCH Index 456
# 26 USMMMNCH Index 456
# 27 AWH TOTL Index 164
# 28 USWHTOT Index 456
# 29 USEMTOT Index 912
# 30 USEMNCHG Index 456
# 31 USERTOT Index 456
# 32 EMDINP1M Index 336
# 33 JOLTOPEN Index 215
# 34 JOLTHIRS Index 215
# 35 JOLTSEPS Index 215
# 36 CHALYOY% Index 228
# 37 ADP CHNG Index 210
# 38 USHEYOY Index 456
# 39 USHETOT% Index 456
# 40 ECI YOY Index 72
# 41 COSTNFR% Index 151
# ...
