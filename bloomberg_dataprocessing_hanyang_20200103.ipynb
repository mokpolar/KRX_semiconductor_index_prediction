# %%
# !ls /Users/mokpolar/Downloads/bloomberg_raw/
# Out:
# barclays.csv                   hy_concat2.csv
# bloomberg_dataprocessing.ipynb moneymarket.csv
# commodity.csv                  msci.csv
# data                           sample_description.txt
# economic.csv                   tableColName.xlsx
# future.csv                     world_indices.csv
# hy_concat.csv

# %%
import pandas as pd

# %%
eco = pd.read_csv('/Users/mokpolar/Downloads/bloomberg_raw/economic.csv')
com = pd.read_csv('/Users/mokpolar/Downloads/bloomberg_raw/commodity.csv')
msci = pd.read_csv('/Users/mokpolar/Downloads/bloomberg_raw/msci.csv')
mon = pd.read_csv('/Users/mokpolar/Downloads/bloomberg_raw/moneymarket.csv')

# %%
eco.columns = ['ticker', 'return_code1', 'return_code2', 'date', 'value']

# %%
com.columns = ['ticker', 'req_code1', 'req_code2','date', 'px_open', 'px_high', 'px_low', 'px_last', 'chg_net_10', 'chg_pct_10', 'px_volume']

# %%
msci.columns = ['ticker', 'req_code1', 'req_code2','date', 'px_open', 'px_high', 'px_low', 'px_last', 'chg_net_10', 'chg_pct_10', 'px_volume']

# %%
mon.columns = ['ticker', 'req_code1', 'req_code2','date', 'px_open', 'px_high', 'px_low', 'px_last', 'chg_net_10', 'chg_pct_10', 'px_volume']

# %%
mon.head()
# Out:
#               ticker  req_code1  req_code2        date  px_open  px_high  \
# 0  USDHTG BGN Curncy          0          7  10/16/2000       24  -2.9769
# 1  USDHTG BGN Curncy          0          7  10/17/2000       25        1
# 2  USDHTG BGN Curncy          0          7  10/18/2000       24       -1
# 3  USDHTG BGN Curncy          0          7  10/20/2000  23.5735  -0.4265
# 4  USDHTG BGN Curncy          0          7  10/23/2000  23.8137   0.2402
#
#     px_low  px_last chg_net_10 chg_pct_10 px_volume
# 0  -11.035       24                    24   26.9769
# 1   4.1667       25                    25        24
# 2       -4       24                    24        25
# 3  -1.7771  22.2879     24.859   23.57345        24
# 4   1.0189  23.1017    24.5257    23.8137   23.5735

# %%
com.head()
# Out:
#        ticker  req_code1  req_code2        date px_open px_high px_low  \
# 0  CL1 Comdty          0          7  11/01/2001   21.18   21.45  20.35
# 1  CL1 Comdty          0          7  11/02/2001    20.2   20.25  19.69
# 2  CL1 Comdty          0          7  11/05/2001   20.25   20.45  19.76
# 3  CL1 Comdty          0          7  11/06/2001   19.81   20.03  19.56
# 4  CL1 Comdty          0          7  11/07/2001    20.1   20.35  19.93
#
#   px_last chg_net_10 chg_pct_10 px_volume
# 0   20.39      -0.79      -3.73     82000
# 1   20.18      -0.21      -1.03     84104
# 2   20.02      -0.16      -0.79     54896
# 3   19.92       -0.1       -0.5     63123
# 4   20.09       0.17       0.85     61742

# %%
list = [eco, com, msci, mon]
for i in list:
    i.set_index('ticker', inplace = True)

# %%
commodity = com.loc[["CL1 Comdty",
"CO1 Comdty",
"QS1 Comdty",
"XB1 Comdty",
"HO1 Comdty",
"NG1 Comdty",
"FN1 Comdty",
"LMAHDS03 Comdty",
"LMCADS03 Comdty",
"XAU Curncy",
"IOE1 Comdty",
"LMNIDS03 Comdty",
"XAG Curncy",
"RBT1 Comdty",
"LC1 Comdty",
"KC1 Comdty",
"C 1 Comdty",
"CT1 Comdty",
"S 1 Comdty",
"SB1 Comdty",
"W 1 Comdty"], : ]

# %%
economic = eco.loc[["KOGDPQOQ Index",
"KOECPRCY Index",
"KOECGCPY Index",
"KOECGVTY Index",
"KOECEXPY Index",
"KOECIMPY Index",
"KOECSPRQ Index",
"KOECGCSY Index",
"KOECSGVQ Index",
"KOECSEMQ Index",
"KOECSIMQ Index",
"KOECFCOY Index",
"KOECFCSY Index",
"OEKRN022 Index",
"KOGNICNY Index",
"KOGNICUY Index",
"KOGCGDPY Index",
"KOGCSTOQ Index",
"KODFTOTY Index",
"KOCPI Index",
"KOCPIYOY Index",
"KOCPIMOM Index",
"SKCITTL Index",
"SKCIYOY Index",
"SKCIMOM Index",
"KOCLLNS Index",
"KOPPI Index",
"KOPPIYOY Index",
"KOPPIMOM Index",
"KOEAUERS Index",
"KOEAEMPY Index",
"KOUETTY Index",
"KOEAPY Index",
"KOEAEPR Index",
"KOQEEYOY Index",
"KOWDR Index",
"KOULMGF Index",
"KOULMGFY Index",
"KOLPI Index",
"KOLPIY Index",
"SKLIOTAR Index",
"KOIPISA Index",
"KOIPIY Index",
"KOIPIMOM Index",
"KOIPMS Index",
"KOIPMY Index",
"KOIPMSM Index",
"KOPSIY Index",
"KOPIIY Index",
"KOIPMC Index",
"KOIPMCY Index",
"KOIPOPSM Index",
"KOIVCPEY Index",
"KOIVCCY Index",
"KOIVCONY Index",
"KOCGCGY Index",
"KOCGCGSM Index",
"KOSVTOTY Index",
"KOSVTOTM Index",
"KOVMPROD Index",
"KOBSMC Index",
"KOBSNMC Index",
"SKBSIC Index",
"SKBSICSA Index",
"MPMIKRMA Index",
"OEKRKLAR Index",
"OEKRKLAP Index",
"SKLILI Index",
"SKLILY Index",
"SKLILC Index",
"SKLICI Index",
"SKLIINVC Index",
"SKLICONE Index",
"SKLIMORD Index",
"SKLICONT Index",
"SKLINBAR Index",
"SKLIOTAR Index",
"SKLISPRC Index",
"SKLIINTR Index",
"SKLIIPAL Index",
"SKLICNST Index",
"SKLISVCI Index",
"SKLIWNRS Index",
"SKLISHPP Index",
"SKLIIMPT Index",
"SKLIEMPP Index",
"SKLILAP Index",
"SKLILAI Index",
"SKLINE Index",
"SKLICPY Index",
"KOBONTL Index",
"KOHSTR Index",
"KOHPTTL Index",
"KOHPTYOY Index",
"KOHCTTL Index",
"KOHCTYOY Index",
"KOBLTHML Index",
"KOBLTHMY Index",
"KOUHTTL Index",
"KORST Index",
"KORSTY Index",
"KODSDEPT Index",
"KODSDISC Index",
"KOVMTOTS Index",
"KOVMDOMS Index",
"KOVMEXPS Index",
"KOCCCSI Index",
"KOHOINC Index",
"KOHOINCY Index",
"KOHEUINY Index",
"KOHHD Index",
"KOHHDY Index",
"KOHHL Index",
"KOHHLY Index",
"EOKOS002 Index",
"KOBPCB Index",
"EHCAKRY Index",
"KOBPFIN Index",
"KOBPCA Index",
"KODIBAL Index",
"KOBPTB Index",
"KOTRBAL Index",
"KOEXTOT Index",
"KOIMTOT Index",
"KOEXTOTY Index",
"KOIMTOTY Index",
"KOEXPTI Index",
"KOEXPTIY Index",
"KOEXPTIM Index",
"KOIMPTI Index",
"KOIMPTIY Index",
"KOIMPTIM Index",
"KOFDIT Index",
"KOFDITY Index",
"KOELTOT Index",
"KOGFBAL Index",
"KOGFTEXP Index",
"KOGFTR Index",
"G7BBKORE Index",
"GDDBSOKO Index",
"KOMSMBY Index",
"KOMSM1Y Index",
"KOMSM2Y Index",
"KOMSM3Y Index",
"KOMSLY Index",
"KOMSM1FY Index",
"KOFETOT Index",
"KOFETOT% Index",
"KORP7D Index",
"KOCICOBA Index",
"KOCICONF Index",
"KRBO3M Index",
"KWCDC Curncy",
"GVSK10YR Index",
"WCAUSK Index",
"KRW Curncy",
"ATWIKRW Index"], :]

# %%
msci = msci.loc[["MXWD Index",
"MXWDIM Index",
"MXAS Index",
"MXWDE Index",
"MXWDO Index",
"MXWDJ Index",
"MXWDU Index",
"MXWDMVOL Index",
"MXWDQU Index",
"MXWDHDVD Index",
"MXWOMOM Index",
"MXCNVW Index",
"MXWOUEVR Index",
"MXWOUMOR Index",
"MXWOURWR Index",
"MXWOUNQR Index",
"MXWOUMFR Index",
"MXEFMVOL Index"], :]

# %%
money = mon.loc[["GTKRW1Y Corp",
"GTKRW2Y Corp",
"GTKRW3Y Corp",
"GTKRW5Y Corp",
"GTKRW10Y Corp",
"GTKRW20Y Corp"], :]

# %%
money.tail()
# Out:
#               ticker  req_code1  req_code2        date px_open px_high px_low  \
# 23004  GTKRW20Y Corp          0          7  09/17/2019   1.467   0.048   N.A.
# 23005  GTKRW20Y Corp          0          7  09/18/2019   1.467       0   N.A.
# 23006  GTKRW20Y Corp          0          7  10/28/2019   1.766   0.298   N.A.
# 23007  GTKRW20Y Corp          0          7  10/29/2019   1.762  -0.004   N.A.
# 23008  GTKRW20Y Corp          0          7  10/30/2019    1.74  -0.022   N.A.
#
#       px_last chg_net_10 chg_pct_10 px_volume
# 23004    1.48      1.454      1.467      N.A.
# 23005    1.48      1.454      1.467      N.A.
# 23006   1.779      1.753      1.766      N.A.
# 23007   1.776      1.747      1.762      N.A.
# 23008   1.752      1.728       1.74      N.A.

# %%
money.reset_index(inplace = True)

# %%
economic.tail()
# Out:
#               ticker  return_code1  return_code2        date  value
# 84192  ATWIKRW Index             0             1  10/21/2019  92.71
# 84193  ATWIKRW Index             0             1  10/22/2019   92.9
# 84194  ATWIKRW Index             0             1  10/23/2019  92.66
# 84195  ATWIKRW Index             0             1  10/24/2019  92.69
# 84196  ATWIKRW Index             0             1  10/25/2019  92.69

# %%
eco = economic[['ticker', 'date', 'value']]

# %%
ms = msci[['ticker', 'date', 'px_last']]

# %%
com = commodity[['ticker', 'date', 'px_last']]

# %%
mon = money[['ticker', 'date', 'px_last']]

# %%
for i in [ms, com, mon]:
    i.columns = ['ticker', 'date', 'value']

# %%
con = pd.concat([con, mon], axis = 0)

# %%
# Out:
#                ticker        date  value
# 0      KOGDPQOQ Index  03/31/2000   11.9
# 1      KOGDPQOQ Index  06/30/2000    1.5
# 2      KOGDPQOQ Index  09/30/2000    2.8
# 3      KOGDPQOQ Index  12/31/2000   -0.7
# 4      KOGDPQOQ Index  12/31/2001    1.4
# ...               ...         ...    ...
# 23004   GTKRW20Y Corp  09/17/2019   1.48
# 23005   GTKRW20Y Corp  09/18/2019   1.48
# 23006   GTKRW20Y Corp  10/28/2019  1.779
# 23007   GTKRW20Y Corp  10/29/2019  1.776
# 23008   GTKRW20Y Corp  10/30/2019  1.752
#
# [390617 rows x 3 columns]

# %%
con.to_csv('hanyang_20200103.csv')

# %%
len(con)
# Out:
# 390617

# %%
con = con.dropna()

# %%
len(con)
# Out:
# 390617

# %%
a = pd.read_csv('hanyang_20200103.csv')

# %%
a = a['date'].map(lambda x: '' if ' ')
# Out:
#   File "<ipython-input-140-5d92b9031094>", line 1
#     a = a['date'].map(lambda x: '' if ' ')
#                                          ^
# SyntaxError: invalid syntax

# %%
con.head()
# Out:
#            ticker        date value
# 0  KOGDPQOQ Index  03/31/2000  11.9
# 1  KOGDPQOQ Index  06/30/2000   1.5
# 2  KOGDPQOQ Index  09/30/2000   2.8
# 3  KOGDPQOQ Index  12/31/2000  -0.7
# 4  KOGDPQOQ Index  12/31/2001   1.4

# %%
con = con.replace(' ', '')

# %%
con.dropna()
# Out:
#                ticker        date  value
# 0      KOGDPQOQ Index  03/31/2000   11.9
# 1      KOGDPQOQ Index  06/30/2000    1.5
# 2      KOGDPQOQ Index  09/30/2000    2.8
# 3      KOGDPQOQ Index  12/31/2000   -0.7
# 4      KOGDPQOQ Index  12/31/2001    1.4
# ...               ...         ...    ...
# 23004   GTKRW20Y Corp  09/17/2019   1.48
# 23005   GTKRW20Y Corp  09/18/2019   1.48
# 23006   GTKRW20Y Corp  10/28/2019  1.779
# 23007   GTKRW20Y Corp  10/29/2019  1.776
# 23008   GTKRW20Y Corp  10/30/2019  1.752
#
# [390617 rows x 3 columns]

# %%
con = con.dropna()

# %%
con['date'] = pd.to_datetime(con['date'])

# %%
for i, j in enumerate(con['ticker'].unique()):
    print(i, con['ticker'].unique()[i], len(con[con['ticker'] == j]))
# Out:
# 0 KOGDPQOQ Index 76
# 1 KOECPRCY Index 152
# 2 KOECGCPY Index 152
# 3 KOECGVTY Index 152
# 4 KOECEXPY Index 152
# 5 KOECIMPY Index 152
# 6 KOECSPRQ Index 152
# 7 KOECGCSY Index 152
# 8 KOECSGVQ Index 152
# 9 KOECSEMQ Index 152
# 10 KOECSIMQ Index 152
# 11 KOECFCOY Index 152
# 12 KOECFCSY Index 152
# 13 OEKRN022 Index 152
# 14 KOGNICNY Index 151
# 15 KOGNICUY Index 151
# 16 KOGCGDPY Index 151
# 17 KOGCSTOQ Index 151
# 18 KODFTOTY Index 151
# 19 KOCPI Index 456
# 20 KOCPIYOY Index 456
# 21 KOCPIMOM Index 456
# 22 SKCITTL Index 456
# 23 SKCIYOY Index 456
# 24 SKCIMOM Index 456
# 25 KOCLLNS Index 288
# 26 KOPPI Index 455
# 27 KOPPIYOY Index 455
# 28 KOPPIMOM Index 455
# 29 KOEAUERS Index 234
# 30 KOEAEMPY Index 222
# 31 KOUETTY Index 425
# 32 KOEAPY Index 222
# 33 KOEAEPR Index 234
# 34 KOQEEYOY Index 298
# 35 KOWDR Index 51
# 36 KOULMGF Index 47
# 37 KOULMGFY Index 43
# 38 KOLPI Index 47
# 39 KOLPIY Index 43
# 40 SKLIOTAR Index 618
# 41 KOIPISA Index 455
# 42 KOIPIY Index 455
# 43 KOIPIMOM Index 455
# 44 KOIPMS Index 455
# 45 KOIPMY Index 455
# 46 KOIPMSM Index 455
# 47 KOPSIY Index 455
# 48 KOPIIY Index 455
# 49 KOIPMC Index 455
# 50 KOIPMCY Index 455
# 51 KOIPOPSM Index 455
# 52 KOIVCPEY Index 275
# 53 KOIVCCY Index 245
# 54 KOIVCONY Index 455
# 55 KOCGCGY Index 275
# 56 KOCGCGSM Index 286
# 57 KOSVTOTY Index 227
# 58 KOSVTOTM Index 226
# 59 KOVMPROD Index 276
# 60 KOBSMC Index 203
# 61 KOBSNMC Index 203
# 62 SKBSIC Index 456
# 63 SKBSICSA Index 372
# 64 MPMIKRMA Index 37
# 65 OEKRKLAR Index 344
# 66 OEKRKLAP Index 332
# 67 SKLILI Index 455
# 68 SKLILY Index 455
# 69 SKLILC Index 455
# 70 SKLICI Index 455
# 71 SKLIINVC Index 347
# 72 SKLICONE Index 238
# 73 SKLIMORD Index 239
# 74 SKLICONT Index 347
# 75 SKLINBAR Index 287
# 76 SKLISPRC Index 335
# 77 SKLIINTR Index 287
# 78 SKLIIPAL Index 347
# 79 SKLICNST Index 251
# 80 SKLISVCI Index 239
# 81 SKLIWNRS Index 347
# 82 SKLISHPP Index 347
# 83 SKLIIMPT Index 347
# 84 SKLIEMPP Index 347
# 85 SKLILAP Index 347
# 86 SKLILAI Index 347
# 87 SKLINE Index 202
# 88 SKLICPY Index 202
# 89 KOBONTL Index 216
# 90 KOHSTR Index 14
# 91 KOHPTTL Index 396
# 92 KOHPTYOY Index 384
# 93 KOHCTTL Index 241
# 94 KOHCTYOY Index 229
# 95 KOBLTHML Index 71
# 96 KOBLTHMY Index 59
# 97 KOUHTTL Index 220
# 98 KORST Index 178
# 99 KORSTY Index 166
# 100 KODSDEPT Index 202
# 101 KODSDISC Index 202
# 102 KOVMTOTS Index 276
# 103 KOVMDOMS Index 276
# 104 KOVMEXPS Index 276
# 105 KOCCCSI Index 137
# 106 KOHOINC Index 67
# 107 KOHOINCY Index 63
# 108 KOHEUINY Index 111
# 109 KOHHD Index 68
# 110 KOHHDY Index 64
# 111 KOHHL Index 68
# 112 KOHHLY Index 64
# 113 EOKOS002 Index 38
# 114 KOBPCB Index 454
# 115 EHCAKRY Index 38
# 116 KOBPFIN Index 454
# 117 KOBPCA Index 454
# 118 KODIBAL Index 454
# 119 KOBPTB Index 454
# 120 KOTRBAL Index 350
# 121 KOEXTOT Index 456
# 122 KOIMTOT Index 456
# 123 KOEXTOTY Index 456
# 124 KOIMTOTY Index 456
# 125 KOEXPTI Index 455
# 126 KOEXPTIY Index 455
# 127 KOEXPTIM Index 455
# 128 KOIMPTI Index 455
# 129 KOIMPTIY Index 455
# 130 KOIMPTIM Index 455
# 131 KOFDIT Index 68
# 132 KOFDITY Index 68
# 133 KOELTOT Index 96
# 134 KOGFBAL Index 227
# 135 KOGFTEXP Index 227
# 136 KOGFTR Index 227
# 137 G7BBKORE Index 38
# 138 GDDBSOKO Index 16
# 139 KOMSMBY Index 454
# 140 KOMSM1Y Index 454
# 141 KOMSM2Y Index 382
# 142 KOMSM3Y Index 382
# 143 KOMSLY Index 274
# 144 KOMSM1FY Index 454
# 145 KOFETOT Index 456
# 146 KOFETOT% Index 456
# 147 KORP7D Index 5860
# 148 KOCICOBA Index 118
# 149 KOCICONF Index 118
# 150 KRBO3M Index 3784
# 151 KWCDC Curncy 6229
# 152 GVSK10YR Index 4451
# 153 WCAUSK Index 5860
# 154 KRW Curncy 9836
# 155 ATWIKRW Index 6244
# 156 MXWD Index 8306
# 157 MXWDIM Index 6633
# 158 MXAS Index 8306
# 159 MXWDE Index 8306
# 160 MXWDO Index 8306
# 161 MXWDJ Index 8306
# 162 MXWDU Index 8306
# 163 MXWDMVOL Index 6645
# 164 MXWDQU Index 7155
# 165 MXWDHDVD Index 7332
# 166 MXWOMOM Index 7332
# 167 MXCNVW Index 5977
# 168 MXWOUEVR Index 5720
# 169 MXWOUMOR Index 6372
# 170 MXWOURWR Index 1206
# 171 MXWOUNQR Index 5459
# 172 MXWOUMFR Index 5329
# 173 MXEFMVOL Index 4676
# 174 CL1 Comdty 8961
# 175 CO1 Comdty 7811
# 176 QS1 Comdty 7548
# 177 XB1 Comdty 3547
# 178 HO1 Comdty 8170
# 179 NG1 Comdty 7219
# 180 FN1 Comdty 5573
# 181 LMAHDS03 Comdty 7982
# 182 LMCADS03 Comdty 8266
# 183 XAU Curncy 9763
# 184 IOE1 Comdty 1470
# 185 LMNIDS03 Comdty 8079
# 186 XAG Curncy 9783
# 187 RBT1 Comdty 2578
# 188 LC1 Comdty 9616
# 189 KC1 Comdty 9431
# 190 C 1 Comdty 9600
# 191 CT1 Comdty 9580
# 192 S 1 Comdty 9601
# 193 SB1 Comdty 9575
# 194 W 1 Comdty 9586
# 195 GTKRW1Y Corp 3734
# 196 GTKRW2Y Corp 4046
# 197 GTKRW3Y Corp 4012
# 198 GTKRW5Y Corp 4135
# 199 GTKRW10Y Corp 3930
# 200 GTKRW20Y Corp 3152

# %%
name = con['ticker'].unique()

# %%
name
# Out:
# array(['KOGDPQOQIndex', 'KOECPRCYIndex', 'KOECGCPYIndex', 'KOECGVTYIndex',
#        'KOECEXPYIndex', 'KOECIMPYIndex', 'KOECSPRQIndex', 'KOECGCSYIndex',
#        'KOECSGVQIndex', 'KOECSEMQIndex', 'KOECSIMQIndex', 'KOECFCOYIndex',
#        'KOECFCSYIndex', 'OEKRN022Index', 'KOGNICNYIndex', 'KOGNICUYIndex',
#        'KOGCGDPYIndex', 'KOGCSTOQIndex', 'KODFTOTYIndex', 'KOCPIIndex',
#        'KOCPIYOYIndex', 'KOCPIMOMIndex', 'SKCITTLIndex', 'SKCIYOYIndex',
#        'SKCIMOMIndex', 'KOCLLNSIndex', 'KOPPIIndex', 'KOPPIYOYIndex',
#        'KOPPIMOMIndex', 'KOEAUERSIndex', 'KOEAEMPYIndex', 'KOUETTYIndex',
#        'KOEAPYIndex', 'KOEAEPRIndex', 'KOQEEYOYIndex', 'KOWDRIndex',
#        'KOULMGFIndex', 'KOULMGFYIndex', 'KOLPIIndex', 'KOLPIYIndex',
#        'SKLIOTARIndex', 'KOIPISAIndex', 'KOIPIYIndex', 'KOIPIMOMIndex',
#        'KOIPMSIndex', 'KOIPMYIndex', 'KOIPMSMIndex', 'KOPSIYIndex',
#        'KOPIIYIndex', 'KOIPMCIndex', 'KOIPMCYIndex', 'KOIPOPSMIndex',
#        'KOIVCPEYIndex', 'KOIVCCYIndex', 'KOIVCONYIndex', 'KOCGCGYIndex',
#        'KOCGCGSMIndex', 'KOSVTOTYIndex', 'KOSVTOTMIndex', 'KOVMPRODIndex',
#        'KOBSMCIndex', 'KOBSNMCIndex', 'SKBSICIndex', 'SKBSICSAIndex',
#        'MPMIKRMAIndex', 'OEKRKLARIndex', 'OEKRKLAPIndex', 'SKLILIIndex',
#        'SKLILYIndex', 'SKLILCIndex', 'SKLICIIndex', 'SKLIINVCIndex',
#        'SKLICONEIndex', 'SKLIMORDIndex', 'SKLICONTIndex', 'SKLINBARIndex',
#        'SKLISPRCIndex', 'SKLIINTRIndex', 'SKLIIPALIndex', 'SKLICNSTIndex',
#        'SKLISVCIIndex', 'SKLIWNRSIndex', 'SKLISHPPIndex', 'SKLIIMPTIndex',
#        'SKLIEMPPIndex', 'SKLILAPIndex', 'SKLILAIIndex', 'SKLINEIndex',
#        'SKLICPYIndex', 'KOBONTLIndex', 'KOHSTRIndex', 'KOHPTTLIndex',
#        'KOHPTYOYIndex', 'KOHCTTLIndex', 'KOHCTYOYIndex', 'KOBLTHMLIndex',
#        'KOBLTHMYIndex', 'KOUHTTLIndex', 'KORSTIndex', 'KORSTYIndex',
#        'KODSDEPTIndex', 'KODSDISCIndex', 'KOVMTOTSIndex', 'KOVMDOMSIndex',
#        'KOVMEXPSIndex', 'KOCCCSIIndex', 'KOHOINCIndex', 'KOHOINCYIndex',
#        'KOHEUINYIndex', 'KOHHDIndex', 'KOHHDYIndex', 'KOHHLIndex',
#        'KOHHLYIndex', 'EOKOS002Index', 'KOBPCBIndex', 'EHCAKRYIndex',
#        'KOBPFINIndex', 'KOBPCAIndex', 'KODIBALIndex', 'KOBPTBIndex',
#        'KOTRBALIndex', 'KOEXTOTIndex', 'KOIMTOTIndex', 'KOEXTOTYIndex',
#        'KOIMTOTYIndex', 'KOEXPTIIndex', 'KOEXPTIYIndex', 'KOEXPTIMIndex',
#        'KOIMPTIIndex', 'KOIMPTIYIndex', 'KOIMPTIMIndex', 'KOFDITIndex',
#        'KOFDITYIndex', 'KOELTOTIndex', 'KOGFBALIndex', 'KOGFTEXPIndex',
#        'KOGFTRIndex', 'G7BBKOREIndex', 'GDDBSOKOIndex', 'KOMSMBYIndex',
#        'KOMSM1YIndex', 'KOMSM2YIndex', 'KOMSM3YIndex', 'KOMSLYIndex',
#        'KOMSM1FYIndex', 'KOFETOTIndex', 'KOFETOT%Index', 'KORP7DIndex',
#        'KOCICOBAIndex', 'KOCICONFIndex', 'KRBO3MIndex', 'KWCDCCurncy',
#        'GVSK10YRIndex', 'WCAUSKIndex', 'KRWCurncy', 'ATWIKRWIndex',
#        'MXWDIndex', 'MXWDIMIndex', 'MXASIndex', 'MXWDEIndex',
#        'MXWDOIndex', 'MXWDJIndex', 'MXWDUIndex', 'MXWDMVOLIndex',
#        'MXWDQUIndex', 'MXWDHDVDIndex', 'MXWOMOMIndex', 'MXCNVWIndex',
#        'MXWOUEVRIndex', 'MXWOUMORIndex', 'MXWOURWRIndex', 'MXWOUNQRIndex',
#        'MXWOUMFRIndex', 'MXEFMVOLIndex', 'CL1Comdty', 'CO1Comdty',
#        'QS1Comdty', 'XB1Comdty', 'HO1Comdty', 'NG1Comdty', 'FN1Comdty',
#        'LMAHDS03Comdty', 'LMCADS03Comdty', 'XAUCurncy', 'IOE1Comdty',
#        'LMNIDS03Comdty', 'XAGCurncy', 'RBT1Comdty', 'LC1Comdty',
#        'KC1Comdty', 'C1Comdty', 'CT1Comdty', 'S1Comdty', 'SB1Comdty',
#        'W1Comdty', 'GTKRW1YCorp', 'GTKRW2YCorp', 'GTKRW3YCorp',
#        'GTKRW5YCorp', 'GTKRW10YCorp', 'GTKRW20YCorp'], dtype=object)

# %%
con.to_csv('hanyang_20200103.csv')

# %% [markdown]
# # ticker별 데이터프레임 생성해서 옆으로 붙이기

# %%
con['ticker'] = con['ticker'].map(lambda x: x.replace(' ', ''))

# %%
# 필요 mod 갖고오기
import sys
mod = sys.modules[__name__]

# %%
name = con['ticker'].unique()

# %%
# ticker별 데이터 프레임 생성
for i, j in enumerate(name):
    setattr(mod, name[i], con[con['ticker'] == j])

# %%
# 잘 나오는지 체크
KOGDPQOQIndex
# Out:
#            ticker       date value
# 0   KOGDPQOQIndex 2000-03-31  11.9
# 1   KOGDPQOQIndex 2000-06-30   1.5
# 2   KOGDPQOQIndex 2000-09-30   2.8
# 3   KOGDPQOQIndex 2000-12-31  -0.7
# 4   KOGDPQOQIndex 2001-12-31   1.4
# ..            ...        ...   ...
# 71  KOGDPQOQIndex 2018-09-30   0.5
# 72  KOGDPQOQIndex 2018-12-31   0.9
# 73  KOGDPQOQIndex 2019-03-31  -0.4
# 74  KOGDPQOQIndex 2019-06-30     1
# 75  KOGDPQOQIndex 2019-09-30   0.4
#
# [76 rows x 3 columns]

# %%
# ticker가 value에 들어가게 변경
for i in name:
    globals()[i].columns = ['ticker', 'date', i]

# %%
KOGDPQOQIndex
# Out:
#            ticker       date KOGDPQOQIndex
# 0   KOGDPQOQIndex 2000-03-31          11.9
# 1   KOGDPQOQIndex 2000-06-30           1.5
# 2   KOGDPQOQIndex 2000-09-30           2.8
# 3   KOGDPQOQIndex 2000-12-31          -0.7
# 4   KOGDPQOQIndex 2001-12-31           1.4
# ..            ...        ...           ...
# 71  KOGDPQOQIndex 2018-09-30           0.5
# 72  KOGDPQOQIndex 2018-12-31           0.9
# 73  KOGDPQOQIndex 2019-03-31          -0.4
# 74  KOGDPQOQIndex 2019-06-30             1
# 75  KOGDPQOQIndex 2019-09-30           0.4
#
# [76 rows x 3 columns]

# %%
# 이제 tickers는 날려도 됨
for i in name:
    globals()[i].drop(['ticker'], axis = 1, inplace = True)

# %%
# 제일 데이터가 긴 KRWCurncy로 기준 선정
new_df = KRWCurncy

# %%
# 날짜별로 sorting
new_df = new_df.sort_values(by = 'date')

# %%
# 확인
new_df
# Out:
#             date KRWCurncy
# 68117 1981-04-13     675.4
# 68118 1981-04-14     676.7
# 68119 1981-04-15     676.7
# 68120 1981-04-16     676.7
# 68121 1981-04-17    676.75
# ...          ...       ...
# 77948 2019-10-25   1172.97
# 77949 2019-10-28   1170.53
# 77950 2019-10-29   1163.19
# 77951 2019-10-30   1168.07
# 77952 2019-10-31   1163.72
#
# [9836 rows x 2 columns]

# %%
# 그리고 데이터 프레임 다 합치기 date 기준으로
for i in name:
    new_df = pd.merge(new_df, globals()[i], how = 'outer', on = 'date')

# %%
new_df.head()
# Out:
#         date KRWCurncy_x KOGDPQOQIndex KOECPRCYIndex KOECGCPYIndex  \
# 0 1981-04-13       675.4           NaN           NaN           NaN
# 1 1981-04-14       676.7           NaN           NaN           NaN
# 2 1981-04-15       676.7           NaN           NaN           NaN
# 3 1981-04-16       676.7           NaN           NaN           NaN
# 4 1981-04-17      676.75           NaN           NaN           NaN
#
#   KOECGVTYIndex KOECEXPYIndex KOECIMPYIndex KOECSPRQIndex KOECGCSYIndex  ...  \
# 0           NaN           NaN           NaN           NaN           NaN  ...
# 1           NaN           NaN           NaN           NaN           NaN  ...
# 2           NaN           NaN           NaN           NaN           NaN  ...
# 3           NaN           NaN           NaN           NaN           NaN  ...
# 4           NaN           NaN           NaN           NaN           NaN  ...
#
#   CT1Comdty S1Comdty SB1Comdty W1Comdty GTKRW1YCorp GTKRW2YCorp GTKRW3YCorp  \
# 0     88.29    769.5     18.29   433.25         NaN         NaN         NaN
# 1      87.7    768.5     17.76    432.5         NaN         NaN         NaN
# 2     87.22    772.5     16.78      435         NaN         NaN         NaN
# 3      86.9      780     16.64   438.75         NaN         NaN         NaN
# 4       NaN      NaN       NaN      NaN         NaN         NaN         NaN
#
#   GTKRW5YCorp GTKRW10YCorp GTKRW20YCorp
# 0         NaN          NaN          NaN
# 1         NaN          NaN          NaN
# 2         NaN          NaN          NaN
# 3         NaN          NaN          NaN
# 4         NaN          NaN          NaN
#
# [5 rows x 203 columns]

# %%
# 중복 날려주고
new_df.drop('KRWCurncy_y', axis = 1, inplace = True)

# %%
new_df.columns.to_list()
# Out:
# ['date',
#  'KRWCurncy_x',
#  'KOGDPQOQIndex',
#  'KOECPRCYIndex',
#  'KOECGCPYIndex',
#  'KOECGVTYIndex',
#  'KOECEXPYIndex',
#  'KOECIMPYIndex',
#  'KOECSPRQIndex',
#  'KOECGCSYIndex',
#  'KOECSGVQIndex',
#  'KOECSEMQIndex',
#  'KOECSIMQIndex',
#  'KOECFCOYIndex',
#  'KOECFCSYIndex',
#  'OEKRN022Index',
#  'KOGNICNYIndex',
#  'KOGNICUYIndex',
#  'KOGCGDPYIndex',
#  'KOGCSTOQIndex',
#  'KODFTOTYIndex',
#  'KOCPIIndex',
#  'KOCPIYOYIndex',
#  'KOCPIMOMIndex',
#  'SKCITTLIndex',
#  'SKCIYOYIndex',
#  'SKCIMOMIndex',
#  'KOCLLNSIndex',
#  'KOPPIIndex',
#  'KOPPIYOYIndex',
#  'KOPPIMOMIndex',
#  'KOEAUERSIndex',
#  'KOEAEMPYIndex',
#  'KOUETTYIndex',
#  'KOEAPYIndex',
#  'KOEAEPRIndex',
#  'KOQEEYOYIndex',
#  'KOWDRIndex',
#  'KOULMGFIndex',
#  'KOULMGFYIndex',
#  'KOLPIIndex',
#  'KOLPIYIndex',
#  'SKLIOTARIndex',
#  'KOIPISAIndex',
#  'KOIPIYIndex',
#  'KOIPIMOMIndex',
#  'KOIPMSIndex',
#  'KOIPMYIndex',
#  'KOIPMSMIndex',
#  'KOPSIYIndex',
#  'KOPIIYIndex',
#  'KOIPMCIndex',
#  'KOIPMCYIndex',
#  'KOIPOPSMIndex',
#  'KOIVCPEYIndex',
#  'KOIVCCYIndex',
#  'KOIVCONYIndex',
#  'KOCGCGYIndex',
#  'KOCGCGSMIndex',
#  'KOSVTOTYIndex',
#  'KOSVTOTMIndex',
#  'KOVMPRODIndex',
#  'KOBSMCIndex',
#  'KOBSNMCIndex',
#  'SKBSICIndex',
#  'SKBSICSAIndex',
#  'MPMIKRMAIndex',
#  'OEKRKLARIndex',
#  'OEKRKLAPIndex',
#  'SKLILIIndex',
#  'SKLILYIndex',
#  'SKLILCIndex',
#  'SKLICIIndex',
#  'SKLIINVCIndex',
#  'SKLICONEIndex',
#  'SKLIMORDIndex',
#  'SKLICONTIndex',
#  'SKLINBARIndex',
#  'SKLISPRCIndex',
#  'SKLIINTRIndex',
#  'SKLIIPALIndex',
#  'SKLICNSTIndex',
#  'SKLISVCIIndex',
#  'SKLIWNRSIndex',
#  'SKLISHPPIndex',
#  'SKLIIMPTIndex',
#  'SKLIEMPPIndex',
#  'SKLILAPIndex',
#  'SKLILAIIndex',
#  'SKLINEIndex',
#  'SKLICPYIndex',
#  'KOBONTLIndex',
#  'KOHSTRIndex',
#  'KOHPTTLIndex',
#  'KOHPTYOYIndex',
#  'KOHCTTLIndex',
#  'KOHCTYOYIndex',
#  'KOBLTHMLIndex',
#  'KOBLTHMYIndex',
#  'KOUHTTLIndex',
#  'KORSTIndex',
#  'KORSTYIndex',
#  'KODSDEPTIndex',
#  'KODSDISCIndex',
#  'KOVMTOTSIndex',
#  'KOVMDOMSIndex',
#  'KOVMEXPSIndex',
#  'KOCCCSIIndex',
#  'KOHOINCIndex',
#  'KOHOINCYIndex',
#  'KOHEUINYIndex',
#  'KOHHDIndex',
#  'KOHHDYIndex',
#  'KOHHLIndex',
#  'KOHHLYIndex',
#  'EOKOS002Index',
#  'KOBPCBIndex',
#  'EHCAKRYIndex',
#  'KOBPFINIndex',
#  'KOBPCAIndex',
#  'KODIBALIndex',
#  'KOBPTBIndex',
#  'KOTRBALIndex',
#  'KOEXTOTIndex',
#  'KOIMTOTIndex',
#  'KOEXTOTYIndex',
#  'KOIMTOTYIndex',
#  'KOEXPTIIndex',
#  'KOEXPTIYIndex',
#  'KOEXPTIMIndex',
#  'KOIMPTIIndex',
#  'KOIMPTIYIndex',
#  'KOIMPTIMIndex',
#  'KOFDITIndex',
#  'KOFDITYIndex',
#  'KOELTOTIndex',
#  'KOGFBALIndex',
#  'KOGFTEXPIndex',
#  'KOGFTRIndex',
#  'G7BBKOREIndex',
#  'GDDBSOKOIndex',
#  'KOMSMBYIndex',
#  'KOMSM1YIndex',
#  'KOMSM2YIndex',
#  'KOMSM3YIndex',
#  'KOMSLYIndex',
#  'KOMSM1FYIndex',
#  'KOFETOTIndex',
#  'KOFETOT%Index',
#  'KORP7DIndex',
#  'KOCICOBAIndex',
#  'KOCICONFIndex',
#  'KRBO3MIndex',
#  'KWCDCCurncy',
#  'GVSK10YRIndex',
#  'WCAUSKIndex',
#  'ATWIKRWIndex',
#  'MXWDIndex',
#  'MXWDIMIndex',
#  'MXASIndex',
#  'MXWDEIndex',
#  'MXWDOIndex',
#  'MXWDJIndex',
#  'MXWDUIndex',
#  'MXWDMVOLIndex',
#  'MXWDQUIndex',
#  'MXWDHDVDIndex',
#  'MXWOMOMIndex',
#  'MXCNVWIndex',
#  'MXWOUEVRIndex',
#  'MXWOUMORIndex',
#  'MXWOURWRIndex',
#  'MXWOUNQRIndex',
#  'MXWOUMFRIndex',
#  'MXEFMVOLIndex',
#  'CL1Comdty',
#  'CO1Comdty',
#  'QS1Comdty',
#  'XB1Comdty',
#  'HO1Comdty',
#  'NG1Comdty',
#  'FN1Comdty',
#  'LMAHDS03Comdty',
#  'LMCADS03Comdty',
#  'XAUCurncy',
#  'IOE1Comdty',
#  'LMNIDS03Comdty',
#  'XAGCurncy',
#  'RBT1Comdty',
#  'LC1Comdty',
#  'KC1Comdty',
#  'C1Comdty',
#  'CT1Comdty',
#  'S1Comdty',
#  'SB1Comdty',
#  'W1Comdty',
#  'GTKRW1YCorp',
#  'GTKRW2YCorp',
#  'GTKRW3YCorp',
#  'GTKRW5YCorp',
#  'GTKRW10YCorp',
#  'GTKRW20YCorp']

# %%
# 컬럼명 변경
new_df.columns = ['date',
 'KRWCurncy',
 'KOGDPQOQIndex',
 'KOECPRCYIndex',
 'KOECGCPYIndex',
 'KOECGVTYIndex',
 'KOECEXPYIndex',
 'KOECIMPYIndex',
 'KOECSPRQIndex',
 'KOECGCSYIndex',
 'KOECSGVQIndex',
 'KOECSEMQIndex',
 'KOECSIMQIndex',
 'KOECFCOYIndex',
 'KOECFCSYIndex',
 'OEKRN022Index',
 'KOGNICNYIndex',
 'KOGNICUYIndex',
 'KOGCGDPYIndex',
 'KOGCSTOQIndex',
 'KODFTOTYIndex',
 'KOCPIIndex',
 'KOCPIYOYIndex',
 'KOCPIMOMIndex',
 'SKCITTLIndex',
 'SKCIYOYIndex',
 'SKCIMOMIndex',
 'KOCLLNSIndex',
 'KOPPIIndex',
 'KOPPIYOYIndex',
 'KOPPIMOMIndex',
 'KOEAUERSIndex',
 'KOEAEMPYIndex',
 'KOUETTYIndex',
 'KOEAPYIndex',
 'KOEAEPRIndex',
 'KOQEEYOYIndex',
 'KOWDRIndex',
 'KOULMGFIndex',
 'KOULMGFYIndex',
 'KOLPIIndex',
 'KOLPIYIndex',
 'SKLIOTARIndex',
 'KOIPISAIndex',
 'KOIPIYIndex',
 'KOIPIMOMIndex',
 'KOIPMSIndex',
 'KOIPMYIndex',
 'KOIPMSMIndex',
 'KOPSIYIndex',
 'KOPIIYIndex',
 'KOIPMCIndex',
 'KOIPMCYIndex',
 'KOIPOPSMIndex',
 'KOIVCPEYIndex',
 'KOIVCCYIndex',
 'KOIVCONYIndex',
 'KOCGCGYIndex',
 'KOCGCGSMIndex',
 'KOSVTOTYIndex',
 'KOSVTOTMIndex',
 'KOVMPRODIndex',
 'KOBSMCIndex',
 'KOBSNMCIndex',
 'SKBSICIndex',
 'SKBSICSAIndex',
 'MPMIKRMAIndex',
 'OEKRKLARIndex',
 'OEKRKLAPIndex',
 'SKLILIIndex',
 'SKLILYIndex',
 'SKLILCIndex',
 'SKLICIIndex',
 'SKLIINVCIndex',
 'SKLICONEIndex',
 'SKLIMORDIndex',
 'SKLICONTIndex',
 'SKLINBARIndex',
 'SKLISPRCIndex',
 'SKLIINTRIndex',
 'SKLIIPALIndex',
 'SKLICNSTIndex',
 'SKLISVCIIndex',
 'SKLIWNRSIndex',
 'SKLISHPPIndex',
 'SKLIIMPTIndex',
 'SKLIEMPPIndex',
 'SKLILAPIndex',
 'SKLILAIIndex',
 'SKLINEIndex',
 'SKLICPYIndex',
 'KOBONTLIndex',
 'KOHSTRIndex',
 'KOHPTTLIndex',
 'KOHPTYOYIndex',
 'KOHCTTLIndex',
 'KOHCTYOYIndex',
 'KOBLTHMLIndex',
 'KOBLTHMYIndex',
 'KOUHTTLIndex',
 'KORSTIndex',
 'KORSTYIndex',
 'KODSDEPTIndex',
 'KODSDISCIndex',
 'KOVMTOTSIndex',
 'KOVMDOMSIndex',
 'KOVMEXPSIndex',
 'KOCCCSIIndex',
 'KOHOINCIndex',
 'KOHOINCYIndex',
 'KOHEUINYIndex',
 'KOHHDIndex',
 'KOHHDYIndex',
 'KOHHLIndex',
 'KOHHLYIndex',
 'EOKOS002Index',
 'KOBPCBIndex',
 'EHCAKRYIndex',
 'KOBPFINIndex',
 'KOBPCAIndex',
 'KODIBALIndex',
 'KOBPTBIndex',
 'KOTRBALIndex',
 'KOEXTOTIndex',
 'KOIMTOTIndex',
 'KOEXTOTYIndex',
 'KOIMTOTYIndex',
 'KOEXPTIIndex',
 'KOEXPTIYIndex',
 'KOEXPTIMIndex',
 'KOIMPTIIndex',
 'KOIMPTIYIndex',
 'KOIMPTIMIndex',
 'KOFDITIndex',
 'KOFDITYIndex',
 'KOELTOTIndex',
 'KOGFBALIndex',
 'KOGFTEXPIndex',
 'KOGFTRIndex',
 'G7BBKOREIndex',
 'GDDBSOKOIndex',
 'KOMSMBYIndex',
 'KOMSM1YIndex',
 'KOMSM2YIndex',
 'KOMSM3YIndex',
 'KOMSLYIndex',
 'KOMSM1FYIndex',
 'KOFETOTIndex',
 'KOFETOT%Index',
 'KORP7DIndex',
 'KOCICOBAIndex',
 'KOCICONFIndex',
 'KRBO3MIndex',
 'KWCDCCurncy',
 'GVSK10YRIndex',
 'WCAUSKIndex',
 'ATWIKRWIndex',
 'MXWDIndex',
 'MXWDIMIndex',
 'MXASIndex',
 'MXWDEIndex',
 'MXWDOIndex',
 'MXWDJIndex',
 'MXWDUIndex',
 'MXWDMVOLIndex',
 'MXWDQUIndex',
 'MXWDHDVDIndex',
 'MXWOMOMIndex',
 'MXCNVWIndex',
 'MXWOUEVRIndex',
 'MXWOUMORIndex',
 'MXWOURWRIndex',
 'MXWOUNQRIndex',
 'MXWOUMFRIndex',
 'MXEFMVOLIndex',
 'CL1Comdty',
 'CO1Comdty',
 'QS1Comdty',
 'XB1Comdty',
 'HO1Comdty',
 'NG1Comdty',
 'FN1Comdty',
 'LMAHDS03Comdty',
 'LMCADS03Comdty',
 'XAUCurncy',
 'IOE1Comdty',
 'LMNIDS03Comdty',
 'XAGCurncy',
 'RBT1Comdty',
 'LC1Comdty',
 'KC1Comdty',
 'C1Comdty',
 'CT1Comdty',
 'S1Comdty',
 'SB1Comdty',
 'W1Comdty',
 'GTKRW1YCorp',
 'GTKRW2YCorp',
 'GTKRW3YCorp',
 'GTKRW5YCorp',
 'GTKRW10YCorp',
 'GTKRW20YCorp']

# %%
new_df.head()
# Out:
#         date KRWCurncy KOGDPQOQIndex KOECPRCYIndex KOECGCPYIndex  \
# 0 1981-04-13     675.4           NaN           NaN           NaN
# 1 1981-04-14     676.7           NaN           NaN           NaN
# 2 1981-04-15     676.7           NaN           NaN           NaN
# 3 1981-04-16     676.7           NaN           NaN           NaN
# 4 1981-04-17    676.75           NaN           NaN           NaN
#
#   KOECGVTYIndex KOECEXPYIndex KOECIMPYIndex KOECSPRQIndex KOECGCSYIndex  ...  \
# 0           NaN           NaN           NaN           NaN           NaN  ...
# 1           NaN           NaN           NaN           NaN           NaN  ...
# 2           NaN           NaN           NaN           NaN           NaN  ...
# 3           NaN           NaN           NaN           NaN           NaN  ...
# 4           NaN           NaN           NaN           NaN           NaN  ...
#
#   CT1Comdty S1Comdty SB1Comdty W1Comdty GTKRW1YCorp GTKRW2YCorp GTKRW3YCorp  \
# 0     88.29    769.5     18.29   433.25         NaN         NaN         NaN
# 1      87.7    768.5     17.76    432.5         NaN         NaN         NaN
# 2     87.22    772.5     16.78      435         NaN         NaN         NaN
# 3      86.9      780     16.64   438.75         NaN         NaN         NaN
# 4       NaN      NaN       NaN      NaN         NaN         NaN         NaN
#
#   GTKRW5YCorp GTKRW10YCorp GTKRW20YCorp
# 0         NaN          NaN          NaN
# 1         NaN          NaN          NaN
# 2         NaN          NaN          NaN
# 3         NaN          NaN          NaN
# 4         NaN          NaN          NaN
#
# [5 rows x 202 columns]

# %%
new_df.to_csv('sk_hy_20200103.csv')

# %%
new_df.sort_values(by = 'date')
# Out:
#             date KRWCurncy KOGDPQOQIndex KOECPRCYIndex KOECGCPYIndex  \
# 12182 1981-01-02       NaN           NaN           NaN           NaN
# 12115 1981-01-05       NaN           NaN           NaN           NaN
# 12116 1981-01-06       NaN           NaN           NaN           NaN
# 12117 1981-01-07       NaN           NaN           NaN           NaN
# 12118 1981-01-08       NaN           NaN           NaN           NaN
# ...          ...       ...           ...           ...           ...
# 10053 2019-10-28   1170.53           NaN           NaN           NaN
# 10054 2019-10-29   1163.19           NaN           NaN           NaN
# 10055 2019-10-30   1168.07           NaN           NaN           NaN
# 10056 2019-10-31   1163.72           NaN           NaN           NaN
# 10277        NaT       NaN           NaN           NaN           NaN
#
#       KOECGVTYIndex KOECEXPYIndex KOECIMPYIndex KOECSPRQIndex KOECGCSYIndex  \
# 12182           NaN           NaN           NaN           NaN           NaN
# 12115           NaN           NaN           NaN           NaN           NaN
# 12116           NaN           NaN           NaN           NaN           NaN
# 12117           NaN           NaN           NaN           NaN           NaN
# 12118           NaN           NaN           NaN           NaN           NaN
# ...             ...           ...           ...           ...           ...
# 10053           NaN           NaN           NaN           NaN           NaN
# 10054           NaN           NaN           NaN           NaN           NaN
# 10055           NaN           NaN           NaN           NaN           NaN
# 10056           NaN           NaN           NaN           NaN           NaN
# 10277           NaN           NaN           NaN           NaN           NaN
#
#        ... CT1Comdty S1Comdty SB1Comdty W1Comdty GTKRW1YCorp GTKRW2YCorp  \
# 12182  ...     94.65      813       NaN    508.5         NaN         NaN
# 12115  ...      95.5      808     33.23    505.5         NaN         NaN
# 12116  ...      94.6   818.75     33.78   506.75         NaN         NaN
# 12117  ...     93.28      806     33.26   506.25         NaN         NaN
# 12118  ...     93.88      798      31.8   497.25         NaN         NaN
# ...    ...       ...      ...       ...      ...         ...         ...
# 10053  ...     64.79   920.75     12.54   511.75       1.445       1.502
# 10054  ...     64.72   918.25     12.34    511.5       1.385       1.503
# 10055  ...      65.7      916     12.41   509.25       1.383       1.465
# 10056  ...     64.44   916.75     12.48   508.75       1.384       1.467
# 10277  ...       NaN      NaN       NaN      NaN         NaN         NaN
#
#       GTKRW3YCorp GTKRW5YCorp GTKRW10YCorp GTKRW20YCorp
# 12182         NaN         NaN          NaN          NaN
# 12115         NaN         NaN          NaN          NaN
# 12116         NaN         NaN          NaN          NaN
# 12117         NaN         NaN          NaN          NaN
# 12118         NaN         NaN          NaN          NaN
# ...           ...         ...          ...          ...
# 10053       1.563       1.625        1.769        1.779
# 10054       1.561       1.638        1.787        1.776
# 10055       1.533       1.602        1.755        1.752
# 10056         NaN       1.601        1.739          NaN
# 10277         NaN         NaN          NaN          NaN
#
# [12183 rows x 202 columns]

# %%
new_df.head()
# Out:
#             date KRWCurncy KOGDPQOQIndex KOECPRCYIndex KOECGCPYIndex  \
# 12182 1981-01-02       NaN           NaN           NaN           NaN
# 12115 1981-01-05       NaN           NaN           NaN           NaN
# 12116 1981-01-06       NaN           NaN           NaN           NaN
# 12117 1981-01-07       NaN           NaN           NaN           NaN
# 12118 1981-01-08       NaN           NaN           NaN           NaN
#
#       KOECGVTYIndex KOECEXPYIndex KOECIMPYIndex KOECSPRQIndex KOECGCSYIndex  \
# 12182           NaN           NaN           NaN           NaN           NaN
# 12115           NaN           NaN           NaN           NaN           NaN
# 12116           NaN           NaN           NaN           NaN           NaN
# 12117           NaN           NaN           NaN           NaN           NaN
# 12118           NaN           NaN           NaN           NaN           NaN
#
#        ... CT1Comdty S1Comdty SB1Comdty W1Comdty GTKRW1YCorp GTKRW2YCorp  \
# 12182  ...     94.65      813       NaN    508.5         NaN         NaN
# 12115  ...      95.5      808     33.23    505.5         NaN         NaN
# 12116  ...      94.6   818.75     33.78   506.75         NaN         NaN
# 12117  ...     93.28      806     33.26   506.25         NaN         NaN
# 12118  ...     93.88      798      31.8   497.25         NaN         NaN
#
#       GTKRW3YCorp GTKRW5YCorp GTKRW10YCorp GTKRW20YCorp
# 12182         NaN         NaN          NaN          NaN
# 12115         NaN         NaN          NaN          NaN
# 12116         NaN         NaN          NaN          NaN
# 12117         NaN         NaN          NaN          NaN
# 12118         NaN         NaN          NaN          NaN
#
# [5 rows x 202 columns]

# %%
new_df.tail()
# Out:
#             date KRWCurncy KOGDPQOQIndex KOECPRCYIndex KOECGCPYIndex  \
# 11893 2019-10-27       NaN           NaN           NaN           NaN
# 10053 2019-10-28   1170.53           NaN           NaN           NaN
# 10054 2019-10-29   1163.19           NaN           NaN           NaN
# 10055 2019-10-30   1168.07           NaN           NaN           NaN
# 10056 2019-10-31   1163.72           NaN           NaN           NaN
#
#       KOECGVTYIndex KOECEXPYIndex KOECIMPYIndex KOECSPRQIndex KOECGCSYIndex  \
# 11893           NaN           NaN           NaN           NaN           NaN
# 10053           NaN           NaN           NaN           NaN           NaN
# 10054           NaN           NaN           NaN           NaN           NaN
# 10055           NaN           NaN           NaN           NaN           NaN
# 10056           NaN           NaN           NaN           NaN           NaN
#
#        ... CT1Comdty S1Comdty SB1Comdty W1Comdty GTKRW1YCorp GTKRW2YCorp  \
# 11893  ...       NaN      NaN       NaN      NaN         NaN         NaN
# 10053  ...     64.79   920.75     12.54   511.75       1.445       1.502
# 10054  ...     64.72   918.25     12.34    511.5       1.385       1.503
# 10055  ...      65.7      916     12.41   509.25       1.383       1.465
# 10056  ...     64.44   916.75     12.48   508.75       1.384       1.467
#
#       GTKRW3YCorp GTKRW5YCorp GTKRW10YCorp GTKRW20YCorp
# 11893         NaN         NaN          NaN          NaN
# 10053       1.563       1.625        1.769        1.779
# 10054       1.561       1.638        1.787        1.776
# 10055       1.533       1.602        1.755        1.752
# 10056         NaN       1.601        1.739          NaN
#
# [5 rows x 202 columns]

# %%
b = pd.read_csv('sk_hy_20200104.csv')

# %%
b.head()
# Out:
#        date  KRWCurncy  KOGDPQOQIndex  KOECPRCYIndex  KOECGCPYIndex  \
# 0  1981.1.2        NaN            NaN            NaN            NaN
# 1  1981.1.5        NaN            NaN            NaN            NaN
# 2  1981.1.6        NaN            NaN            NaN            NaN
# 3  1981.1.7        NaN            NaN            NaN            NaN
# 4  1981.1.8        NaN            NaN            NaN            NaN
#
#    KOECGVTYIndex  KOECEXPYIndex  KOECIMPYIndex  KOECSPRQIndex  KOECGCSYIndex  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    ...  CT1Comdty  S1Comdty  SB1Comdty  W1Comdty  GTKRW1YCorp  GTKRW2YCorp  \
# 0  ...      94.65    813.00        NaN    508.50          NaN          NaN
# 1  ...      95.50    808.00      33.23    505.50          NaN          NaN
# 2  ...      94.60    818.75      33.78    506.75          NaN          NaN
# 3  ...      93.28    806.00      33.26    506.25          NaN          NaN
# 4  ...      93.88    798.00      31.80    497.25          NaN          NaN
#
#    GTKRW3YCorp  GTKRW5YCorp  GTKRW10YCorp  GTKRW20YCorp
# 0          NaN          NaN           NaN           NaN
# 1          NaN          NaN           NaN           NaN
# 2          NaN          NaN           NaN           NaN
# 3          NaN          NaN           NaN           NaN
# 4          NaN          NaN           NaN           NaN
#
# [5 rows x 202 columns]

# %%
b.tail()
# Out:
#              date  KRWCurncy  KOGDPQOQIndex  KOECPRCYIndex  KOECGCPYIndex  \
# 12177  2019.10.27        NaN            NaN            NaN            NaN
# 12178  2019.10.28    1170.53            NaN            NaN            NaN
# 12179  2019.10.29    1163.19            NaN            NaN            NaN
# 12180  2019.10.30    1168.07            NaN            NaN            NaN
# 12181  2019.10.31    1163.72            NaN            NaN            NaN
#
#        KOECGVTYIndex  KOECEXPYIndex  KOECIMPYIndex  KOECSPRQIndex  \
# 12177            NaN            NaN            NaN            NaN
# 12178            NaN            NaN            NaN            NaN
# 12179            NaN            NaN            NaN            NaN
# 12180            NaN            NaN            NaN            NaN
# 12181            NaN            NaN            NaN            NaN
#
#        KOECGCSYIndex  ...  CT1Comdty  S1Comdty  SB1Comdty  W1Comdty  \
# 12177            NaN  ...        NaN       NaN        NaN       NaN
# 12178            NaN  ...      64.79    920.75      12.54    511.75
# 12179            NaN  ...      64.72    918.25      12.34    511.50
# 12180            NaN  ...      65.70    916.00      12.41    509.25
# 12181            NaN  ...      64.44    916.75      12.48    508.75
#
#        GTKRW1YCorp  GTKRW2YCorp  GTKRW3YCorp  GTKRW5YCorp  GTKRW10YCorp  \
# 12177          NaN          NaN          NaN          NaN           NaN
# 12178        1.445        1.502        1.563        1.625         1.769
# 12179        1.385        1.503        1.561        1.638         1.787
# 12180        1.383        1.465        1.533        1.602         1.755
# 12181        1.384        1.467          NaN        1.601         1.739
#
#        GTKRW20YCorp
# 12177           NaN
# 12178         1.779
# 12179         1.776
# 12180         1.752
# 12181           NaN
#
# [5 rows x 202 columns]

# %%
b.to_csv('hy_20200103.csv')

# %%
k = pd.read_csv('hy_20200103.csv')

# %% [markdown]
# # Step으로 채우기

# %%
# 결측치 채우기
# step은 ffill > bfill
k.fillna(method = 'ffill', inplace = True)
k.fillna(method = 'bfill', inplace = True)

# %%
k.to_csv('hy_20200103_step.csv')

# %% [markdown]
# # Linear 채우기

# %%
m = pd.read_csv('hy_20200103.csv')

# %%
m = m.interpolate()
# 못채우는 사잇값을 채우기 위해서는 bfill로 
m = m.fillna(method = 'bfill')

# %%
m.to_csv('hy_20200103_linear.csv')

# %% [markdown]
# # Spline 채우기

# %%
n = pd.read_csv('hy_20200103.csv')

# %%
n['KOECIMPYIndex'][2950:3000].plot()

# %%
n = n.interpolate(method = 'cubic', limit_area = 'inside')
n = n.fillna(method = 'bfill')
n = n.fillna(method = 'ffill')

# %%
n.to_csv('hy_20200103_spline.csv')

# %%
# %matplotlib inline

# %%
b['KOECPRCYIndex'][60:120].plot()

# %%
k['KOECPRCYIndex'][60:120].plot()

# %%
m['KOECPRCYIndex'][60:120].plot()

# %%
n['KOECPRCYIndex'][60:120].plot()
