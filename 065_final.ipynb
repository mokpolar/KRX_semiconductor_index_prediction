# %%
import s3fs
import warnings
import time
import re
import pandas as pd
import numpy as np
import os
import itertools
import multiprocessing
import pickle
import tensorflow as tf
import matplotlib
import matplotlib.pylab as plt
from sklearn import tree
from tensorflow import keras
from functools import partial
from itertools import repeat
from datetime import datetime
from sagemaker import get_execution_role
from dataHandling import dataHandling
from batchTools import batchTools
from gruDataReshaper import gruDataReshaper
# Out:
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow_core/__init__.py:1467: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
#
# WARNING:tensorflow:From /home/ec2-user/SageMaker/ver6.1/psc/dataHandling.py:20: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /home/ec2-user/SageMaker/ver6.1/psc/dataHandling.py:20: The name tf.logging.ERROR is deprecated. Please use tf.compat.v1.logging.ERROR instead.

# %%
# PARAMETERS
DIRHOME = "s3://sagemaker-begas-upload/marketCaster/ver2.4.3"
DAILY_DATE = "2019-10-31"
BATCH_DATE = "2020-01-07"

# %%
def correctDate(DF, nAhead):
    tmpDATEDF = DF.copy()
    tmpDATEDF['train_end']=tmpDATEDF['train_end'].apply(lambda x: pd.date_range(x, periods=2, freq='-{}B'.format(nAhead)).strftime('%Y-%m-%d')[1])
    tmpDATEDF['train_start']=tmpDATEDF['train_start'].apply(lambda x: pd.date_range(x, periods=2, freq='-{}B'.format(nAhead)).strftime('%Y-%m-%d')[1])
    tmpDATEDF['valid_end']=tmpDATEDF['valid_end'].apply(lambda x: pd.date_range(x, periods=2, freq='-{}B'.format(nAhead)).strftime('%Y-%m-%d')[1])
    tmpDATEDF['valid_start']=tmpDATEDF['valid_start'].apply(lambda x: pd.date_range(x, periods=2, freq='-{}B'.format(nAhead)).strftime('%Y-%m-%d')[1])
    return tmpDATEDF

# %%
def customLoss(y_true, y_pred):
    mean_true = tf.math.reduce_mean(y_true)
    mean_pred = tf.math.reduce_mean(y_pred)
    
    std_true = tf.math.reduce_std(y_true)
    std_pred = tf.math.reduce_std(y_pred)
    
    up = tf.reduce_mean(tf.math.multiply((y_true-mean_true), (y_pred-mean_pred)))
    down = std_true * std_pred
    corr = 1.0-tf.compat.v1.where(tf.math.is_nan(up/down),0.0,up/down)
    
    mserr = tf.math.sqrt(tf.math.reduce_mean(tf.math.square(y_true-y_pred)))
    signerr = 1-tf.math.reduce_mean(tf.math.multiply(tf.math.sign(y_true), tf.math.sign(y_pred)))
    
    return mserr + corr/2 + signerr/2

# %%
def modelgen(nTimeSteps, nFeature):
    layer_input = keras.Input(shape=(nTimeSteps, nFeature), name='input')
    layer_state = keras.layers.CuDNNGRU(units=100, return_state=True, name='gru_cell_0')(layer_input)[1]
    layer_gru = keras.layers.CuDNNGRU(units=100, return_sequences=True, name='gru_cell_1')(layer_input, initial_state=layer_state)
    layer_gru = keras.layers.CuDNNGRU(units=100, return_sequences=True, name='gru_cell_2')(layer_gru)
    layer_output = keras.layers.TimeDistributed(
        keras.layers.Dense(units=1, activation='linear',
                          kernel_regularizer=keras.regularizers.l2(l=0.01),
                          kernel_initializer=tf.keras.initializers.Orthogonal(seed=925)), name='output')(layer_gru) 
    gru_model = keras.Model(layer_input, layer_output)
    gru_model.compile(loss=customLoss, optimizer=keras.optimizers.Adam())
    return gru_model

# %%
detailDir = '/out/performance_ver2.0/2020-03-03/{}/{:03}/final'
GPUDEVICE = 2

# %%
DATEDF = pd.read_csv(os.path.join(os.path.dirname(os.getcwd()), 'out/dateDF.csv'))
DATEDF.sort_values(by='test_end', inplace=True)
DATEDF.reset_index(drop=True, inplace=True)
AHEAD=65
TOTFEATURE = 50
SELFEATURE = 45
TIMESTEPS = 10
TIMEUNIT = 10
NTREE = 10
DATEDF = correctDate(DATEDF, AHEAD)

# %%
def dowork(stage):
    VALID_START = DATEDF.iloc[stage,0]
    VALID_END = DATEDF.iloc[stage,1]
    TRAIN_START = DATEDF.iloc[stage,2]
    TRAIN_END = DATEDF.iloc[stage,3]
    TEST_START = DATEDF.iloc[stage,4]
    TEST_END = DATEDF.iloc[stage,5]

    # Read Data
    dataHandler = dataHandling(DIRHOME, MARKET, AHEAD)
    dataHandler.readConvertedData(TEST_END)
    dataHandler.readVarImpData(1000, TEST_END)
    dataHandler.readRawData(DAILY_DATE)
    dataHandler.readEDAData(DAILY_DATE)
    dataHandler.slicingData()
    dataHandler.naRemover()

    # Variable Selection
    varImpDF = dataHandler.varImpDF.copy()
    varImpDF = varImpDF[['var_name', 'correlation','impurity', 'SSE', 'matching_score', 'non_zero_number', 'rank_total']]
    varImpDF['score_1'] = (abs(varImpDF[['correlation']])-abs(varImpDF[['correlation']]).mean())/abs(varImpDF[['correlation']]).std()
    varImpDF['score_2'] = (varImpDF[['impurity']]-varImpDF[['impurity']].mean())/varImpDF[['impurity']].std()
    varImpDF['score_3'] = -(varImpDF[['SSE']]-varImpDF[['SSE']].mean())/(varImpDF[['SSE']].std())
    varImpDF['score_4'] = -(varImpDF[['matching_score']]-varImpDF[['matching_score']].mean())/varImpDF[['matching_score']].std()
    varImpDF['score_5'] = (varImpDF[['non_zero_number']]-varImpDF[['non_zero_number']].mean())/varImpDF[['non_zero_number']].std()
    varImpDF['score'] = varImpDF[['score_1','score_2','score_3','score_4','score_5']].mean(1)
    varImpDF.sort_values('score', ascending=False, inplace=True)
    xVarsNew = varImpDF['var_name'][:TOTFEATURE].tolist()

    # To Numpy
    grudatareshaper = gruDataReshaper(dataHandler.convertedDF, 
                              AHEAD, 
                              dataHandler.yVar, 
                              xVarsNew, 
                              pd.date_range(TRAIN_START, periods=2, freq='-{}B'.format(TIMESTEPS*TIMEUNIT)).strftime('%Y-%m-%d')[1], 
                              TRAIN_END)
    grudatareshaper.minmaxNormalization()
    grudatareshaper.normalizedDF = grudatareshaper.normalizedDF.loc[grudatareshaper.normalizedDF.date_frct<=TEST_END]
    grudatareshaper.normalizedDF.reset_index(drop=True, inplace=True)
    dateDF, xNP, yNP = grudatareshaper.toNumpy(TIMEUNIT, TIMESTEPS, bNormal=True, bYOn=True)
    print(xNP.shape)
    # Seperate Data
    trainXNP = xNP[(dateDF['date_frct']>=TRAIN_START)&(dateDF['date_frct']<=TRAIN_END),:,:]
    trainYNP = yNP[(dateDF['date_frct']>=TRAIN_START)&(dateDF['date_frct']<=TRAIN_END),:,:]
    validXNP = xNP[(dateDF['date_frct']>=VALID_START)&(dateDF['date_frct']<=VALID_END),:,:]
    validYNP = yNP[(dateDF['date_frct']>=VALID_START)&(dateDF['date_frct']<=VALID_END),:,:]
    testXNP = xNP[(dateDF['date_frct']>=TEST_START)&(dateDF['date_frct']<=TEST_END),:,:]
    testYNP = yNP[(dateDF['date_frct']>=TEST_START)&(dateDF['date_frct']<=TEST_END),:,:]
    flagDateDF = dateDF.loc[(dateDF['date_frct']>=TEST_START)&(dateDF['date_frct']<=TEST_END)]
    dateDF = dateDF.loc[(dateDF['date_frct']>=VALID_START)]

    # Random Forest (Variable Sampling)
    colNumLT = [np.random.choice(TOTFEATURE, SELFEATURE, replace=False) for x in range(NTREE)]

    with tf.device('/gpu:{}'.format(GPUDEVICE)):
        # gpu setting
        config = tf.ConfigProto()
        config.gpu_options.allow_growth=True
        sess = tf.Session(config=config)  
        tf.keras.backend.set_session(sess)
        tf.set_random_seed(925)
        # Model + Training
        modelLT = [modelgen(TIMESTEPS, SELFEATURE) for x in range(NTREE)]
        earlyStop = keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=30)
        tf.set_random_seed(925)
        for x in range(NTREE):
            print('[ Model {:02} ]'.format(x))
            modelLT[x].fit(trainXNP[:,:,colNumLT[x]], trainYNP,
                           validation_data = (validXNP[:,:,colNumLT[x]], validYNP),
                           batch_size=20,
                           epochs=200,
                           callbacks=[earlyStop],
                           verbose=0)
            print('  - complete!\n')    

        # Compute Training Error
        err = [((modelLT[x].predict(trainXNP[:,:,colNumLT[x]])[:,-1,-1]-trainYNP[:,-1,-1])**2).sum() for x in range(10)]
        weight = (1-np.array(err))/(1-np.array(err)).sum()

        for x in range(10):
            inputs = np.where(testXNP[:,:,colNumLT[x]]>1,1,testXNP[:,:,colNumLT[x]])
            inputs = np.where(inputs<0, 0, inputs)
            if x==0:
                prediction0 = modelLT[x].predict(inputs)[:,-1,-1] * weight[x]
                prediction1 = modelLT[x].predict(testXNP[:,:,colNumLT[x]])[:,-1,-1] * weight[x]
            else:
                prediction0 += modelLT[x].predict(inputs)[:,-1,-1] * weight[x]
                prediction1 += modelLT[x].predict(testXNP[:,:,colNumLT[x]])[:,-1,-1] * weight[x]

        prediction = prediction0*0.8 + prediction1*0.2
        #tf.keras.backend.clear_session()

    ## Save
    predDF = flagDateDF.copy()
    predDF['prediction'] = prediction
    tmpY = re.sub('_last_[0-9]{3}$|_last_[0-9]{2}$|_last_[0-9]{1}$','_last', dataHandler.yVar[0])
    predDF = predDF.merge(dataHandler.rawDF.rename(columns={'date':'date_base',
                                                           tmpY:'y_base'}), 'left')
    tmp = dataHandler.rawDF.rename(columns={'date':'date_frct',tmpY:'y_frct'})
    tmp['moving_std'] = tmp['y_frct'].rolling(window=int(np.where(AHEAD==1, 5, AHEAD))).std()
    tmp['lower_bound_accuracy'] = tmp['y_frct'] - 1.644854*tmp['moving_std']
    tmp['upper_bound_accuracy'] = tmp['y_frct'] + 1.644854*tmp['moving_std']
    tmp = tmp[['date_frct', 'y_frct', 'lower_bound_accuracy', 'upper_bound_accuracy']]
    predDF = predDF.merge(tmp, 'left')

    batchtools = batchTools('2020-01-16')
    predDF = batchtools.reconvertData(tmpY, predDF, dataHandler.edaDF)
    ## Save - Path
    saveDir = os.path.dirname(os.getcwd()) + detailDir.format(MARKET,AHEAD) 
    if not os.path.isdir(saveDir):
        os.makedirs(saveDir)
    predDF.sort_values(by=['date_frct'], inplace=True)
    predDF.to_csv(saveDir+'/stage_{:03}.csv'.format(stage),index=False)
    print('    - Complete!\n ')

# %%
for MARKET in ['kospi_index','spx_index','shcomp_index',
               'gtkrw10y_corp','gtusd10y_govt','gtcny10y_corp',
               'dxy_curncy','cl1_comdty','xau_curncy']:
    print(MARKET)
    pool = multiprocessing.Pool(processes=8)
    pool.map(dowork, np.arange(15))
    pool.close()
    pool.join()
    end_time = time.time()
# Out:
# kospi_index
# (2020-03-04 12:05:21) [ Read Converted Data ]
# (2020-03-04 12:05:21) [ Read Converted Data ]
# (2020-03-04 12:05:21) [ Read Converted Data ]
# (2020-03-04 12:05:21) [ Read Converted Data ]
# (2020-03-04 12:05:21) [ Read Converted Data ]
# (2020-03-04 12:05:21) [ Read Converted Data ]
# (2020-03-04 12:05:21) [ Read Converted Data ]
# (2020-03-04 12:05:21) [ Read Converted Data ]
# (2020-03-04 12:05:25) [ Read Variables Importance Data ]
# (2020-03-04 12:05:25) [ Read Raw Data ]
# (2020-03-04 12:05:25) [ Read EDA Data ]
# (2020-03-04 12:05:25) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
# (2020-03-04 12:05:26) [ Read Variables Importance Data ]
# (2020-03-04 12:05:26) [ Read Variables Importance Data ]
# (2020-03-04 12:05:26) [ Read Raw Data ]
# (2020-03-04 12:05:26) [ Read Variables Importance Data ]
# (2020-03-04 12:05:26) [ Read EDA Data ]
# (2020-03-04 12:05:26) [ Read Variables Importance Data ]
# (2020-03-04 12:05:26) [ Read Raw Data ]
# (2020-03-04 12:05:26) [ Read Raw Data ]
# (2020-03-04 12:05:26) [ Remove Non-Available Data ]
# (2020-03-04 12:05:26) [ Read EDA Data ]
# (2020-03-04 12:05:26) [ Read EDA Data ]
# (2020-03-04 12:05:26) [ Read Raw Data ]
# (2020-03-04 12:05:26) [ Read Variables Importance Data ]
# (2020-03-04 12:05:26) [ Remove Non-Available Data ]
# (2020-03-04 12:05:26) [ Read EDA Data ]
# (2020-03-04 12:05:26) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
# (2020-03-04 12:05:26) [ Read Raw Data ]
# (2020-03-04 12:05:26) [ Remove Non-Available Data ]
# (2020-03-04 12:05:26) [ Read EDA Data ]
#                         * 65 rows are removed!
#
#                         * 65 rows are removed!
#
# (2020-03-04 12:05:26) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
# (2020-03-04 12:05:27) [ Read Variables Importance Data ]
# (2020-03-04 12:05:27) [ Read Variables Importance Data ]
# (2020-03-04 12:05:27) [ Read Raw Data ]
#                         * 65 rows are removed!
#
# (2020-03-04 12:05:27) [ Read EDA Data ]
# (2020-03-04 12:05:27) [ Read Raw Data ]
# (2020-03-04 12:05:27) [ Read EDA Data ]
# (2020-03-04 12:05:27) [ Remove Non-Available Data ]
# (2020-03-04 12:05:27) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#                         * 65 rows are removed!
#
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
# (4044, 10, 50)
# (4239, 10, 50)
# (4109, 10, 50)
# (4174, 10, 50)
# (4369, 10, 50)
# (4434, 10, 50)
# (4499, 10, 50)
# (4304, 10, 50)
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
#     - Complete!
#
# (2020-03-04 12:12:22) [ Read Converted Data ]
#   - complete!
#
# [ Model 08 ]
# (2020-03-04 12:12:27) [ Read Variables Importance Data ]
# (2020-03-04 12:12:27) [ Read Raw Data ]
# (2020-03-04 12:12:27) [ Read EDA Data ]
# (2020-03-04 12:12:28) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
#     - Reshape Data (converting data frame to numpy.)
# (4564, 10, 50)
# [ Model 00 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 08 ]
#     - Complete!
#
# (2020-03-04 12:13:08) [ Read Converted Data ]
# (2020-03-04 12:13:13) [ Read Variables Importance Data ]
# (2020-03-04 12:13:13) [ Read Raw Data ]
# (2020-03-04 12:13:13) [ Read EDA Data ]
# (2020-03-04 12:13:13) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 01 ]
#     - Reshape Data (converting data frame to numpy.)
#     - Complete!
#
# (2020-03-04 12:13:21) [ Read Converted Data ]
# (2020-03-04 12:13:27) [ Read Variables Importance Data ]
# (2020-03-04 12:13:27) [ Read Raw Data ]
# (2020-03-04 12:13:27) [ Read EDA Data ]
# (2020-03-04 12:13:27) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
# (4629, 10, 50)
#     - Reshape Data (converting data frame to numpy.)
# [ Model 00 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
#   - complete!
#
# [ Model 09 ]
# (4694, 10, 50)
# [ Model 00 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 02 ]
#     - Complete!
#
# (2020-03-04 12:14:05) [ Read Converted Data ]
#   - complete!
#
# (2020-03-04 12:14:10) [ Read Variables Importance Data ]
# (2020-03-04 12:14:10) [ Read Raw Data ]
# (2020-03-04 12:14:10) [ Read EDA Data ]
# (2020-03-04 12:14:10) [ Remove Non-Available Data ]
#   - complete!
#
# [ Model 01 ]
#                         * 65 rows are removed!
#
#   - complete!
#
# [ Model 03 ]
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
#     - Complete!
#
# (2020-03-04 12:14:25) [ Read Converted Data ]
# (4759, 10, 50)
# [ Model 00 ]
# (2020-03-04 12:14:31) [ Read Variables Importance Data ]
# (2020-03-04 12:14:31) [ Read Raw Data ]
# (2020-03-04 12:14:31) [ Read EDA Data ]
# (2020-03-04 12:14:31) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 02 ]
# (4824, 10, 50)
#   - complete!
#
# [ Model 04 ]
# [ Model 00 ]
#   - complete!
#
# [ Model 01 ]
#     - Complete!
#
# (2020-03-04 12:14:56) [ Read Converted Data ]
# (2020-03-04 12:15:01) [ Read Variables Importance Data ]
# (2020-03-04 12:15:02) [ Read Raw Data ]
# (2020-03-04 12:15:02) [ Read EDA Data ]
# (2020-03-04 12:15:02) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#   - complete!
#
# [ Model 03 ]
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 09 ]
#     - Complete!
#
# (2020-03-04 12:15:14) [ Read Converted Data ]
# (4889, 10, 50)
# (2020-03-04 12:15:20) [ Read Variables Importance Data ]
# (2020-03-04 12:15:20) [ Read Raw Data ]
# (2020-03-04 12:15:20) [ Read EDA Data ]
# (2020-03-04 12:15:20) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#   - complete!
#
# [ Model 03 ]
# [ Model 00 ]
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 05 ]
# (4954, 10, 50)
#   - complete!
#
# [ Model 04 ]
# [ Model 00 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 04 ]
#     - Complete!
#
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 07 ]
#     - Complete!
#
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 09 ]
#     - Complete!
#
#   - complete!
#
#   - complete!
#
#   - complete!
#
#   - complete!
#
# [ Model 07 ]
#     - Complete!
#
#     - Complete!
#
#     - Complete!
#
#   - complete!
#
# [ Model 08 ]
#     - Complete!
#
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
#     - Complete!
#
# spx_index
# (2020-03-04 12:23:15) [ Read Converted Data ]
# (2020-03-04 12:23:15) [ Read Converted Data ]
# (2020-03-04 12:23:15) [ Read Converted Data ]
# (2020-03-04 12:23:15) [ Read Converted Data ]
# (2020-03-04 12:23:15) [ Read Converted Data ]
# (2020-03-04 12:23:15) [ Read Converted Data ]
# (2020-03-04 12:23:15) [ Read Converted Data ]
# (2020-03-04 12:23:15) [ Read Converted Data ]
# (2020-03-04 12:23:19) [ Read Variables Importance Data ]
# (2020-03-04 12:23:19) [ Read Raw Data ]
# (2020-03-04 12:23:19) [ Read EDA Data ]
# (2020-03-04 12:23:19) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
# (2020-03-04 12:23:19) [ Read Variables Importance Data ]
# (2020-03-04 12:23:19) [ Read Raw Data ]
# (2020-03-04 12:23:19) [ Read EDA Data ]
# (2020-03-04 12:23:19) [ Remove Non-Available Data ]
# (2020-03-04 12:23:19) [ Read Variables Importance Data ]
#                         * 65 rows are removed!
#
# (2020-03-04 12:23:20) [ Read Raw Data ]
# (2020-03-04 12:23:20) [ Read EDA Data ]
# (2020-03-04 12:23:20) [ Remove Non-Available Data ]
# (2020-03-04 12:23:20) [ Read Variables Importance Data ]
#                         * 65 rows are removed!
#
# (2020-03-04 12:23:20) [ Read Variables Importance Data ]
# (2020-03-04 12:23:20) [ Read Raw Data ]
# (2020-03-04 12:23:20) [ Read EDA Data ]
# (2020-03-04 12:23:20) [ Read Raw Data ]
# (2020-03-04 12:23:20) [ Remove Non-Available Data ]
# (2020-03-04 12:23:20) [ Read EDA Data ]
# (2020-03-04 12:23:20) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#                         * 65 rows are removed!
#
# (2020-03-04 12:23:20) [ Read Variables Importance Data ]
# (2020-03-04 12:23:21) [ Read Variables Importance Data ]
# (2020-03-04 12:23:21) [ Read Raw Data ]
# (2020-03-04 12:23:21) [ Read EDA Data ]
# (2020-03-04 12:23:21) [ Read Raw Data ]
# (2020-03-04 12:23:21) [ Read EDA Data ]
# (2020-03-04 12:23:21) [ Remove Non-Available Data ]
# (2020-03-04 12:23:21) [ Remove Non-Available Data ]
# (2020-03-04 12:23:21) [ Read Variables Importance Data ]
# (2020-03-04 12:23:21) [ Read Raw Data ]
#                         * 65 rows are removed!
#
#                         * 65 rows are removed!
#
# (2020-03-04 12:23:21) [ Read EDA Data ]
# (2020-03-04 12:23:21) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
# (4044, 10, 50)
# (4239, 10, 50)
# (4304, 10, 50)
# (4174, 10, 50)
# (4369, 10, 50)
# (4109, 10, 50)
# (4434, 10, 50)
# (4499, 10, 50)
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 09 ]
#     - Complete!
#
# (2020-03-04 12:30:01) [ Read Converted Data ]
# (2020-03-04 12:30:07) [ Read Variables Importance Data ]
# (2020-03-04 12:30:07) [ Read Raw Data ]
# (2020-03-04 12:30:07) [ Read EDA Data ]
# (2020-03-04 12:30:07) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 06 ]
#     - Complete!
#
# (2020-03-04 12:30:20) [ Read Converted Data ]
# (4564, 10, 50)
#   - complete!
#
# [ Model 00 ]
# (2020-03-04 12:30:27) [ Read Variables Importance Data ]
# (2020-03-04 12:30:27) [ Read Raw Data ]
# (2020-03-04 12:30:27) [ Read EDA Data ]
# (2020-03-04 12:30:27) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#   - complete!
#
# [ Model 06 ]
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 04 ]
# (4629, 10, 50)
# [ Model 00 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 01 ]
#     - Complete!
#
# (2020-03-04 12:31:17) [ Read Converted Data ]
# (2020-03-04 12:31:23) [ Read Variables Importance Data ]
# (2020-03-04 12:31:23) [ Read Raw Data ]
# (2020-03-04 12:31:23) [ Read EDA Data ]
# (2020-03-04 12:31:23) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#   - complete!
#
# [ Model 02 ]
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 07 ]
# (4694, 10, 50)
#   - complete!
#
# [ Model 08 ]
# [ Model 00 ]
#     - Complete!
#
# (2020-03-04 12:31:47) [ Read Converted Data ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 06 ]
# (2020-03-04 12:31:53) [ Read Variables Importance Data ]
# (2020-03-04 12:31:53) [ Read Raw Data ]
# (2020-03-04 12:31:53) [ Read EDA Data ]
# (2020-03-04 12:31:53) [ Remove Non-Available Data ]
#   - complete!
#
# [ Model 08 ]
#                         * 65 rows are removed!
#
#     - Reshape Data (converting data frame to numpy.)
# (4759, 10, 50)
# [ Model 00 ]
#   - complete!
#
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 06 ]
#     - Complete!
#
# (2020-03-04 12:33:03) [ Read Converted Data ]
#   - complete!
#
# [ Model 02 ]
# (2020-03-04 12:33:08) [ Read Variables Importance Data ]
# (2020-03-04 12:33:09) [ Read Raw Data ]
# (2020-03-04 12:33:09) [ Read EDA Data ]
# (2020-03-04 12:33:09) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 03 ]
# (4824, 10, 50)
#   - complete!
#
# [ Model 06 ]
# [ Model 00 ]
#   - complete!
#
#     - Complete!
#
# (2020-03-04 12:33:47) [ Read Converted Data ]
# (2020-03-04 12:33:52) [ Read Variables Importance Data ]
# (2020-03-04 12:33:52) [ Read Raw Data ]
# (2020-03-04 12:33:52) [ Read EDA Data ]
# (2020-03-04 12:33:52) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 01 ]
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 08 ]
# (4889, 10, 50)
#   - complete!
#
# [ Model 08 ]
# [ Model 00 ]
#   - complete!
#
# [ Model 02 ]
#     - Complete!
#
# (2020-03-04 12:34:21) [ Read Converted Data ]
#   - complete!
#
# [ Model 08 ]
# (2020-03-04 12:34:26) [ Read Variables Importance Data ]
# (2020-03-04 12:34:26) [ Read Raw Data ]
# (2020-03-04 12:34:26) [ Read EDA Data ]
# (2020-03-04 12:34:26) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 03 ]
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 01 ]
# (4954, 10, 50)
# [ Model 00 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 05 ]
#     - Complete!
#
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 05 ]
#     - Complete!
#
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 08 ]
#     - Complete!
#
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 06 ]
#     - Complete!
#
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 08 ]
#     - Complete!
#
#     - Complete!
#
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
#   - complete!
#
# [ Model 06 ]
#     - Complete!
#
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
#     - Complete!
#
# shcomp_index
# (2020-03-04 12:42:19) [ Read Converted Data ]
# (2020-03-04 12:42:19) [ Read Converted Data ]
# (2020-03-04 12:42:19) [ Read Converted Data ]
# (2020-03-04 12:42:19) [ Read Converted Data ]
# (2020-03-04 12:42:19) [ Read Converted Data ]
# (2020-03-04 12:42:19) [ Read Converted Data ]
# (2020-03-04 12:42:19) [ Read Converted Data ]
# (2020-03-04 12:42:19) [ Read Converted Data ]
# (2020-03-04 12:42:23) [ Read Variables Importance Data ]
# (2020-03-04 12:42:24) [ Read Raw Data ]
# (2020-03-04 12:42:24) [ Read EDA Data ]
# (2020-03-04 12:42:24) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
# (2020-03-04 12:42:25) [ Read Variables Importance Data ]
# (2020-03-04 12:42:25) [ Read Variables Importance Data ]
# (2020-03-04 12:42:25) [ Read Variables Importance Data ]
# (2020-03-04 12:42:25) [ Read Variables Importance Data ]
# (2020-03-04 12:42:25) [ Read Variables Importance Data ]
# (2020-03-04 12:42:25) [ Read Raw Data ]
# (2020-03-04 12:42:25) [ Read Raw Data ]
# (2020-03-04 12:42:25) [ Read EDA Data ]
# (2020-03-04 12:42:25) [ Read Raw Data ]
# (2020-03-04 12:42:25) [ Read Raw Data ]
# (2020-03-04 12:42:25) [ Read Raw Data ]
# (2020-03-04 12:42:25) [ Read EDA Data ]
# (2020-03-04 12:42:25) [ Read EDA Data ]
# (2020-03-04 12:42:25) [ Read EDA Data ]
# (2020-03-04 12:42:25) [ Remove Non-Available Data ]
# (2020-03-04 12:42:25) [ Read EDA Data ]
# (2020-03-04 12:42:25) [ Remove Non-Available Data ]
# (2020-03-04 12:42:25) [ Remove Non-Available Data ]
# (2020-03-04 12:42:25) [ Remove Non-Available Data ]
# (2020-03-04 12:42:25) [ Read Variables Importance Data ]
# (2020-03-04 12:42:25) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#                         * 65 rows are removed!
#
#                         * 65 rows are removed!
#
#                         * 65 rows are removed!
#
# (2020-03-04 12:42:25) [ Read Raw Data ]
#                         * 65 rows are removed!
#
# (2020-03-04 12:42:25) [ Read EDA Data ]
# (2020-03-04 12:42:25) [ Remove Non-Available Data ]
# (2020-03-04 12:42:25) [ Read Variables Importance Data ]
#                         * 65 rows are removed!
#
# (2020-03-04 12:42:25) [ Read Raw Data ]
# (2020-03-04 12:42:25) [ Read EDA Data ]
# (2020-03-04 12:42:25) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
# (4044, 10, 50)
# (4239, 10, 50)
# (4109, 10, 50)
# (4304, 10, 50)
# (4174, 10, 50)
# (4434, 10, 50)
# (4499, 10, 50)
# (4369, 10, 50)
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 07 ]
#     - Complete!
#
# (2020-03-04 12:48:47) [ Read Converted Data ]
# (2020-03-04 12:48:52) [ Read Variables Importance Data ]
# (2020-03-04 12:48:52) [ Read Raw Data ]
# (2020-03-04 12:48:52) [ Read EDA Data ]
# (2020-03-04 12:48:52) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 05 ]
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 05 ]
# (4564, 10, 50)
#   - complete!
#
# [ Model 08 ]
# [ Model 00 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 02 ]
#     - Complete!
#
# (2020-03-04 12:50:35) [ Read Converted Data ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 09 ]
# (2020-03-04 12:50:41) [ Read Variables Importance Data ]
# (2020-03-04 12:50:41) [ Read Raw Data ]
# (2020-03-04 12:50:41) [ Read EDA Data ]
# (2020-03-04 12:50:41) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#   - complete!
#
#   - complete!
#
# [ Model 05 ]
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 07 ]
# (4629, 10, 50)
#   - complete!
#
# [ Model 03 ]
# [ Model 00 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 04 ]
#     - Complete!
#
# (2020-03-04 12:51:33) [ Read Converted Data ]
# (2020-03-04 12:51:38) [ Read Variables Importance Data ]
# (2020-03-04 12:51:38) [ Read Raw Data ]
# (2020-03-04 12:51:38) [ Read EDA Data ]
# (2020-03-04 12:51:38) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 01 ]
# (4694, 10, 50)
#   - complete!
#
# [ Model 05 ]
# [ Model 00 ]
#     - Complete!
#
# (2020-03-04 12:51:59) [ Read Converted Data ]
# (2020-03-04 12:52:03) [ Read Variables Importance Data ]
# (2020-03-04 12:52:04) [ Read Raw Data ]
# (2020-03-04 12:52:04) [ Read EDA Data ]
# (2020-03-04 12:52:04) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 09 ]
# (4759, 10, 50)
#   - complete!
#
# [ Model 02 ]
# [ Model 00 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 01 ]
#     - Complete!
#
# (2020-03-04 12:52:33) [ Read Converted Data ]
#   - complete!
#
# [ Model 07 ]
# (2020-03-04 12:52:38) [ Read Variables Importance Data ]
# (2020-03-04 12:52:38) [ Read Raw Data ]
# (2020-03-04 12:52:38) [ Read EDA Data ]
# (2020-03-04 12:52:38) [ Remove Non-Available Data ]
#   - complete!
#
#                         * 65 rows are removed!
#
#     - Reshape Data (converting data frame to numpy.)
# (4824, 10, 50)
# [ Model 00 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 01 ]
#     - Complete!
#
# (2020-03-04 12:53:29) [ Read Converted Data ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 04 ]
# (2020-03-04 12:53:34) [ Read Variables Importance Data ]
# (2020-03-04 12:53:34) [ Read Raw Data ]
# (2020-03-04 12:53:34) [ Read EDA Data ]
# (2020-03-04 12:53:34) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#   - complete!
#
# [ Model 01 ]
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 08 ]
# (4889, 10, 50)
# [ Model 00 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
#   - complete!
#
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
#     - Complete!
#
# (2020-03-04 12:55:37) [ Read Converted Data ]
# (2020-03-04 12:55:42) [ Read Variables Importance Data ]
# (2020-03-04 12:55:42) [ Read Raw Data ]
# (2020-03-04 12:55:42) [ Read EDA Data ]
# (2020-03-04 12:55:42) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 07 ]
#     - Complete!
#
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 02 ]
# (4954, 10, 50)
# [ Model 00 ]
#   - complete!
#
# [ Model 05 ]
#     - Complete!
#
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 04 ]
#     - Complete!
#
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 09 ]
#     - Complete!
#
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
#   - complete!
#
# [ Model 07 ]
#     - Complete!
#
#   - complete!
#
# [ Model 09 ]
#     - Complete!
#
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
#   - complete!
#
# [ Model 09 ]
#     - Complete!
#
#   - complete!
#
#     - Complete!
#
# gtkrw10y_corp
# (2020-03-04 13:02:46) [ Read Converted Data ]
# (2020-03-04 13:02:46) [ Read Converted Data ]
# (2020-03-04 13:02:46) [ Read Converted Data ]
# (2020-03-04 13:02:46) [ Read Converted Data ]
# (2020-03-04 13:02:46) [ Read Converted Data ]
# (2020-03-04 13:02:46) [ Read Converted Data ]
# (2020-03-04 13:02:46) [ Read Converted Data ]
# (2020-03-04 13:02:46) [ Read Converted Data ]
# (2020-03-04 13:02:51) [ Read Variables Importance Data ]
# (2020-03-04 13:02:51) [ Read Raw Data ]
# (2020-03-04 13:02:51) [ Read EDA Data ]
# (2020-03-04 13:02:51) [ Remove Non-Available Data ]
#                         * 280 rows are removed!
#
# (2020-03-04 13:02:52) [ Read Variables Importance Data ]
# (2020-03-04 13:02:52) [ Read Raw Data ]
# (2020-03-04 13:02:52) [ Read Variables Importance Data ]
# (2020-03-04 13:02:52) [ Read EDA Data ]
# (2020-03-04 13:02:52) [ Read Variables Importance Data ]
# (2020-03-04 13:02:52) [ Read Raw Data ]
# (2020-03-04 13:02:52) [ Read Variables Importance Data ]
# (2020-03-04 13:02:52) [ Remove Non-Available Data ]
# (2020-03-04 13:02:52) [ Read EDA Data ]
# (2020-03-04 13:02:52) [ Read Raw Data ]
# (2020-03-04 13:02:52) [ Remove Non-Available Data ]
# (2020-03-04 13:02:52) [ Read EDA Data ]
# (2020-03-04 13:02:52) [ Read Raw Data ]
#                         * 280 rows are removed!
#
# (2020-03-04 13:02:52) [ Read EDA Data ]
# (2020-03-04 13:02:52) [ Remove Non-Available Data ]
# (2020-03-04 13:02:52) [ Read Variables Importance Data ]
# (2020-03-04 13:02:52) [ Remove Non-Available Data ]
#                         * 280 rows are removed!
#
#                         * 280 rows are removed!
#
# (2020-03-04 13:02:52) [ Read Raw Data ]
#                         * 280 rows are removed!
#
# (2020-03-04 13:02:52) [ Read EDA Data ]
# (2020-03-04 13:02:52) [ Read Variables Importance Data ]
# (2020-03-04 13:02:52) [ Remove Non-Available Data ]
# (2020-03-04 13:02:52) [ Read Raw Data ]
# (2020-03-04 13:02:52) [ Read Variables Importance Data ]
# (2020-03-04 13:02:52) [ Read EDA Data ]
#                         * 280 rows are removed!
#
# (2020-03-04 13:02:52) [ Remove Non-Available Data ]
# (2020-03-04 13:02:52) [ Read Raw Data ]
# (2020-03-04 13:02:53) [ Read EDA Data ]
# (2020-03-04 13:02:53) [ Remove Non-Available Data ]
#                         * 280 rows are removed!
#
#                         * 280 rows are removed!
#
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
# (3829, 10, 50)
# (3894, 10, 50)
# (3959, 10, 50)
# (4089, 10, 50)
# (4154, 10, 50)
# (4284, 10, 50)
# (4024, 10, 50)
# (4219, 10, 50)
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
# [ Model 03 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 07 ]
#     - Complete!
#
# (2020-03-04 13:10:44) [ Read Converted Data ]
# (2020-03-04 13:10:49) [ Read Variables Importance Data ]
# (2020-03-04 13:10:49) [ Read Raw Data ]
# (2020-03-04 13:10:49) [ Read EDA Data ]
# (2020-03-04 13:10:49) [ Remove Non-Available Data ]
#                         * 280 rows are removed!
#
#   - complete!
#
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 08 ]
# (4349, 10, 50)
# [ Model 00 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 08 ]
#     - Complete!
#
# (2020-03-04 13:11:40) [ Read Converted Data ]
# (2020-03-04 13:11:46) [ Read Variables Importance Data ]
# (2020-03-04 13:11:46) [ Read Raw Data ]
# (2020-03-04 13:11:46) [ Read EDA Data ]
# (2020-03-04 13:11:46) [ Remove Non-Available Data ]
#                         * 280 rows are removed!
#
#   - complete!
#
# [ Model 09 ]
#     - Reshape Data (converting data frame to numpy.)
# (4414, 10, 50)
# [ Model 00 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
#   - complete!
#
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 06 ]
#     - Complete!
#
# (2020-03-04 13:13:59) [ Read Converted Data ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 06 ]
# (2020-03-04 13:14:04) [ Read Variables Importance Data ]
# (2020-03-04 13:14:05) [ Read Raw Data ]
# (2020-03-04 13:14:05) [ Read EDA Data ]
# (2020-03-04 13:14:05) [ Remove Non-Available Data ]
#                         * 280 rows are removed!
#
#     - Complete!
#
# (2020-03-04 13:14:05) [ Read Converted Data ]
#     - Reshape Data (converting data frame to numpy.)
# (2020-03-04 13:14:10) [ Read Variables Importance Data ]
# (2020-03-04 13:14:10) [ Read Raw Data ]
# (2020-03-04 13:14:10) [ Read EDA Data ]
# (2020-03-04 13:14:10) [ Remove Non-Available Data ]
#                         * 280 rows are removed!
#
#     - Reshape Data (converting data frame to numpy.)
#     - Complete!
#
# (2020-03-04 13:14:16) [ Read Converted Data ]
#   - complete!
#
# [ Model 05 ]
# (4479, 10, 50)
#   - complete!
#
# [ Model 05 ]
# (2020-03-04 13:14:21) [ Read Variables Importance Data ]
# (2020-03-04 13:14:21) [ Read Raw Data ]
# (2020-03-04 13:14:22) [ Read EDA Data ]
# (2020-03-04 13:14:22) [ Remove Non-Available Data ]
#                         * 280 rows are removed!
#
# [ Model 00 ]
# (4544, 10, 50)
#   - complete!
#
# [ Model 07 ]
#     - Reshape Data (converting data frame to numpy.)
# [ Model 00 ]
# (4609, 10, 50)
# [ Model 00 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 04 ]
#     - Complete!
#
# (2020-03-04 13:18:10) [ Read Converted Data ]
#   - complete!
#
# (2020-03-04 13:18:16) [ Read Variables Importance Data ]
# (2020-03-04 13:18:16) [ Read Raw Data ]
# (2020-03-04 13:18:16) [ Read EDA Data ]
# (2020-03-04 13:18:16) [ Remove Non-Available Data ]
#                         * 280 rows are removed!
#
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 09 ]
#     - Reshape Data (converting data frame to numpy.)
# (4674, 10, 50)
# [ Model 00 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 08 ]
#     - Complete!
#
# (2020-03-04 13:18:47) [ Read Converted Data ]
# (2020-03-04 13:18:51) [ Read Variables Importance Data ]
# (2020-03-04 13:18:52) [ Read Raw Data ]
# (2020-03-04 13:18:52) [ Read EDA Data ]
# (2020-03-04 13:18:52) [ Remove Non-Available Data ]
#                         * 280 rows are removed!
#
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
#   - complete!
#
# [ Model 01 ]
#     - Complete!
#
#   - complete!
#
# [ Model 08 ]
# (4739, 10, 50)
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 09 ]
# [ Model 00 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
#   - complete!
#
#     - Complete!
#
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
#   - complete!
#
# [ Model 04 ]
#     - Complete!
#
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 08 ]
#     - Complete!
#
#   - complete!
#
# [ Model 05 ]
#     - Complete!
#
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 05 ]
#     - Complete!
#
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 07 ]
#     - Complete!
#
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
#     - Complete!
#
# gtusd10y_govt
# (2020-03-04 13:24:48) [ Read Converted Data ]
# (2020-03-04 13:24:48) [ Read Converted Data ]
# (2020-03-04 13:24:48) [ Read Converted Data ]
# (2020-03-04 13:24:48) [ Read Converted Data ]
# (2020-03-04 13:24:48) [ Read Converted Data ]
# (2020-03-04 13:24:48) [ Read Converted Data ]
# (2020-03-04 13:24:48) [ Read Converted Data ]
# (2020-03-04 13:24:48) [ Read Converted Data ]
# (2020-03-04 13:24:52) [ Read Variables Importance Data ]
# (2020-03-04 13:24:52) [ Read Raw Data ]
# (2020-03-04 13:24:52) [ Read EDA Data ]
# (2020-03-04 13:24:52) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
# (2020-03-04 13:24:53) [ Read Variables Importance Data ]
# (2020-03-04 13:24:53) [ Read Raw Data ]
# (2020-03-04 13:24:53) [ Read EDA Data ]
# (2020-03-04 13:24:53) [ Remove Non-Available Data ]
# (2020-03-04 13:24:53) [ Read Variables Importance Data ]
#                         * 65 rows are removed!
#
# (2020-03-04 13:24:54) [ Read Variables Importance Data ]
# (2020-03-04 13:24:54) [ Read Raw Data ]
# (2020-03-04 13:24:54) [ Read EDA Data ]
# (2020-03-04 13:24:54) [ Read Raw Data ]
# (2020-03-04 13:24:54) [ Read Variables Importance Data ]
# (2020-03-04 13:24:54) [ Read EDA Data ]
# (2020-03-04 13:24:54) [ Remove Non-Available Data ]
# (2020-03-04 13:24:54) [ Read Raw Data ]
# (2020-03-04 13:24:54) [ Remove Non-Available Data ]
# (2020-03-04 13:24:54) [ Read EDA Data ]
# (2020-03-04 13:24:54) [ Read Variables Importance Data ]
# (2020-03-04 13:24:54) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#                         * 65 rows are removed!
#
#
# (2020-03-04 13:24:54) [ Read Variables Importance Data ]
# (2020-03-04 13:24:54) [ Read Raw Data ]
# (2020-03-04 13:24:54) [ Read EDA Data ]
#                         * 65 rows are removed!
#
# (2020-03-04 13:24:54) [ Read Raw Data ]
# (2020-03-04 13:24:54) [ Read EDA Data ]
# (2020-03-04 13:24:54) [ Remove Non-Available Data ]
# (2020-03-04 13:24:54) [ Remove Non-Available Data ]
# (2020-03-04 13:24:54) [ Read Variables Importance Data ]
#                         * 65 rows are removed!
#
# (2020-03-04 13:24:54) [ Read Raw Data ]
#                         * 65 rows are removed!
#
# (2020-03-04 13:24:54) [ Read EDA Data ]
# (2020-03-04 13:24:54) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
# (4044, 10, 50)
# (4109, 10, 50)
# (4434, 10, 50)
# (4239, 10, 50)
# (4499, 10, 50)
# (4174, 10, 50)
# (4304, 10, 50)
# (4369, 10, 50)
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
#   - complete!
#
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 07 ]
#     - Complete!
#
# (2020-03-04 13:31:09) [ Read Converted Data ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 06 ]
# (2020-03-04 13:31:14) [ Read Variables Importance Data ]
# (2020-03-04 13:31:14) [ Read Raw Data ]
# (2020-03-04 13:31:14) [ Read EDA Data ]
# (2020-03-04 13:31:14) [ Remove Non-Available Data ]
#     - Complete!
#
# (2020-03-04 13:31:14) [ Read Converted Data ]
#                         * 65 rows are removed!
#
#     - Reshape Data (converting data frame to numpy.)
# (2020-03-04 13:31:20) [ Read Variables Importance Data ]
# (2020-03-04 13:31:20) [ Read Raw Data ]
# (2020-03-04 13:31:20) [ Read EDA Data ]
# (2020-03-04 13:31:20) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 08 ]
# (4564, 10, 50)
#   - complete!
#
# [ Model 08 ]
# [ Model 00 ]
# (4629, 10, 50)
# [ Model 00 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
#   - complete!
#
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 08 ]
#     - Complete!
#
# (2020-03-04 13:33:54) [ Read Converted Data ]
# (2020-03-04 13:33:59) [ Read Variables Importance Data ]
# (2020-03-04 13:34:00) [ Read Raw Data ]
# (2020-03-04 13:34:00) [ Read EDA Data ]
# (2020-03-04 13:34:00) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# (4694, 10, 50)
# [ Model 00 ]
#     - Complete!
#
# (2020-03-04 13:34:20) [ Read Converted Data ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 06 ]
#     - Complete!
#
# (2020-03-04 13:34:25) [ Read Converted Data ]
# (2020-03-04 13:34:26) [ Read Variables Importance Data ]
# (2020-03-04 13:34:26) [ Read Raw Data ]
# (2020-03-04 13:34:26) [ Read EDA Data ]
# (2020-03-04 13:34:26) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
# (2020-03-04 13:34:31) [ Read Variables Importance Data ]
# (2020-03-04 13:34:31) [ Read Raw Data ]
# (2020-03-04 13:34:31) [ Read EDA Data ]
# (2020-03-04 13:34:31) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
#   - complete!
#
# [ Model 04 ]
#     - Reshape Data (converting data frame to numpy.)
# (4759, 10, 50)
# [ Model 00 ]
# (4824, 10, 50)
#   - complete!
#
# [ Model 07 ]
# [ Model 00 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 05 ]
#     - Complete!
#
# (2020-03-04 13:35:03) [ Read Converted Data ]
# (2020-03-04 13:35:08) [ Read Variables Importance Data ]
# (2020-03-04 13:35:08) [ Read Raw Data ]
# (2020-03-04 13:35:08) [ Read EDA Data ]
# (2020-03-04 13:35:08) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#   - complete!
#
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 01 ]
#     - Complete!
#
# (2020-03-04 13:35:22) [ Read Converted Data ]
# (4889, 10, 50)
# (2020-03-04 13:35:27) [ Read Variables Importance Data ]
# (2020-03-04 13:35:27) [ Read Raw Data ]
# (2020-03-04 13:35:27) [ Read EDA Data ]
# (2020-03-04 13:35:27) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
# [ Model 00 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 09 ]
#     - Reshape Data (converting data frame to numpy.)
# (4954, 10, 50)
# [ Model 00 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 07 ]
#     - Complete!
#
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 04 ]
#     - Complete!
#
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# ...
#
# [ Model 03 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
#   - complete!
#
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 06 ]
#     - Complete!
#
# (2020-03-04 14:20:50) [ Read Converted Data ]
# (2020-03-04 14:20:55) [ Read Variables Importance Data ]
# (2020-03-04 14:20:55) [ Read Raw Data ]
# (2020-03-04 14:20:55) [ Read EDA Data ]
# (2020-03-04 14:20:55) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 08 ]
# (4564, 10, 50)
# [ Model 00 ]
#     - Complete!
#
# (2020-03-04 14:21:26) [ Read Converted Data ]
#   - complete!
#
# (2020-03-04 14:21:32) [ Read Variables Importance Data ]
# (2020-03-04 14:21:32) [ Read Raw Data ]
# (2020-03-04 14:21:32) [ Read EDA Data ]
# (2020-03-04 14:21:32) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 09 ]
#     - Complete!
#
# (2020-03-04 14:21:46) [ Read Converted Data ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 06 ]
# (4629, 10, 50)
#   - complete!
#
# [ Model 07 ]
# [ Model 00 ]
# (2020-03-04 14:21:52) [ Read Variables Importance Data ]
# (2020-03-04 14:21:52) [ Read Raw Data ]
# (2020-03-04 14:21:52) [ Read EDA Data ]
# (2020-03-04 14:21:52) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# (4694, 10, 50)
# [ Model 00 ]
#     - Complete!
#
# (2020-03-04 14:22:18) [ Read Converted Data ]
# (2020-03-04 14:22:23) [ Read Variables Importance Data ]
# (2020-03-04 14:22:24) [ Read Raw Data ]
# (2020-03-04 14:22:24) [ Read EDA Data ]
# (2020-03-04 14:22:24) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#   - complete!
#
# [ Model 07 ]
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 01 ]
# (4759, 10, 50)
# [ Model 00 ]
#   - complete!
#
# [ Model 04 ]
#     - Complete!
#
# (2020-03-04 14:22:59) [ Read Converted Data ]
# (2020-03-04 14:23:05) [ Read Variables Importance Data ]
# (2020-03-04 14:23:05) [ Read Raw Data ]
# (2020-03-04 14:23:05) [ Read EDA Data ]
# (2020-03-04 14:23:05) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 05 ]
# (4824, 10, 50)
# [ Model 00 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
#   - complete!
#
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 09 ]
#     - Complete!
#
# (2020-03-04 14:25:52) [ Read Converted Data ]
#   - complete!
#
# [ Model 02 ]
# (2020-03-04 14:25:57) [ Read Variables Importance Data ]
# (2020-03-04 14:25:58) [ Read Raw Data ]
# (2020-03-04 14:25:58) [ Read EDA Data ]
# (2020-03-04 14:25:58) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#   - complete!
#
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 05 ]
#     - Complete!
#
# (2020-03-04 14:26:10) [ Read Converted Data ]
# (4889, 10, 50)
# (2020-03-04 14:26:16) [ Read Variables Importance Data ]
# (2020-03-04 14:26:16) [ Read Raw Data ]
# (2020-03-04 14:26:16) [ Read EDA Data ]
# (2020-03-04 14:26:16) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
# [ Model 00 ]
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 04 ]
#     - Complete!
#
# (4954, 10, 50)
#   - complete!
#
# [ Model 06 ]
# [ Model 00 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 01 ]
#     - Complete!
#
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 06 ]
#     - Complete!
#
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 07 ]
#     - Complete!
#
#     - Complete!
#
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
#   - complete!
#
#   - complete!
#
# [ Model 09 ]
#     - Complete!
#
#     - Complete!
#
#   - complete!
#
#     - Complete!
#
# xau_curncy
# (2020-03-04 14:35:15) [ Read Converted Data ]
# (2020-03-04 14:35:15) [ Read Converted Data ]
# (2020-03-04 14:35:15) [ Read Converted Data ]
# (2020-03-04 14:35:15) [ Read Converted Data ]
# (2020-03-04 14:35:15) [ Read Converted Data ]
# (2020-03-04 14:35:15) [ Read Converted Data ]
# (2020-03-04 14:35:15) [ Read Converted Data ]
# (2020-03-04 14:35:15) [ Read Converted Data ]
# (2020-03-04 14:35:19) [ Read Variables Importance Data ]
# (2020-03-04 14:35:19) [ Read Raw Data ]
# (2020-03-04 14:35:19) [ Read EDA Data ]
# (2020-03-04 14:35:19) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
# (2020-03-04 14:35:20) [ Read Variables Importance Data ]
# (2020-03-04 14:35:20) [ Read Variables Importance Data ]
# (2020-03-04 14:35:20) [ Read Variables Importance Data ]
# (2020-03-04 14:35:20) [ Read Variables Importance Data ]
# (2020-03-04 14:35:20) [ Read Raw Data ]
# (2020-03-04 14:35:20) [ Read Raw Data ]
# (2020-03-04 14:35:20) [ Read Variables Importance Data ]
# (2020-03-04 14:35:20) [ Read EDA Data ]
# (2020-03-04 14:35:20) [ Read Raw Data ]
# (2020-03-04 14:35:20) [ Read EDA Data ]
# (2020-03-04 14:35:20) [ Read Raw Data ]
# (2020-03-04 14:35:20) [ Read EDA Data ]
# (2020-03-04 14:35:20) [ Read Raw Data ]
# (2020-03-04 14:35:20) [ Remove Non-Available Data ]
# (2020-03-04 14:35:20) [ Read EDA Data ]
# (2020-03-04 14:35:20) [ Remove Non-Available Data ]
# (2020-03-04 14:35:20) [ Read EDA Data ]
# (2020-03-04 14:35:20) [ Remove Non-Available Data ]
# (2020-03-04 14:35:20) [ Remove Non-Available Data ]
# (2020-03-04 14:35:20) [ Read Variables Importance Data ]
# (2020-03-04 14:35:20) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#                         * 65 rows are removed!
#
# (2020-03-04 14:35:20) [ Read Raw Data ]
#                         * 65 rows are removed!
#
#                         * 65 rows are removed!
#
# (2020-03-04 14:35:20) [ Read EDA Data ]
#                         * 65 rows are removed!
#
# (2020-03-04 14:35:20) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
# (2020-03-04 14:35:20) [ Read Variables Importance Data ]
# (2020-03-04 14:35:20) [ Read Raw Data ]
# (2020-03-04 14:35:21) [ Read EDA Data ]
# (2020-03-04 14:35:21) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
# (4044, 10, 50)
# (4109, 10, 50)
# (4174, 10, 50)
# (4304, 10, 50)
# (4369, 10, 50)
# (4239, 10, 50)
# (4499, 10, 50)
# (4434, 10, 50)
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
# [ Model 00 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
# [ Model 05 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
#     - Complete!
#
# (2020-03-04 14:41:36) [ Read Converted Data ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 07 ]
# (2020-03-04 14:41:42) [ Read Variables Importance Data ]
# (2020-03-04 14:41:42) [ Read Raw Data ]
# (2020-03-04 14:41:42) [ Read EDA Data ]
# (2020-03-04 14:41:42) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#   - complete!
#
#   - complete!
#
# [ Model 08 ]
#     - Reshape Data (converting data frame to numpy.)
#     - Complete!
#
# (2020-03-04 14:41:48) [ Read Converted Data ]
# (2020-03-04 14:41:53) [ Read Variables Importance Data ]
# (2020-03-04 14:41:54) [ Read Raw Data ]
# (2020-03-04 14:41:54) [ Read EDA Data ]
# (2020-03-04 14:41:54) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#   - complete!
#
# [ Model 06 ]
# (4564, 10, 50)
#   - complete!
#
# [ Model 09 ]
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 08 ]
# [ Model 00 ]
#   - complete!
#
# [ Model 09 ]
# (4629, 10, 50)
# [ Model 00 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
#     - Complete!
#
# (2020-03-04 14:42:32) [ Read Converted Data ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 01 ]
#     - Complete!
#
# (2020-03-04 14:42:36) [ Read Converted Data ]
# (2020-03-04 14:42:38) [ Read Variables Importance Data ]
# (2020-03-04 14:42:38) [ Read Raw Data ]
# (2020-03-04 14:42:38) [ Read EDA Data ]
# (2020-03-04 14:42:38) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
# (2020-03-04 14:42:42) [ Read Variables Importance Data ]
# (2020-03-04 14:42:42) [ Read Raw Data ]
# (2020-03-04 14:42:42) [ Read EDA Data ]
# (2020-03-04 14:42:42) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#     - Reshape Data (converting data frame to numpy.)
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 02 ]
# (4694, 10, 50)
#   - complete!
#
# [ Model 02 ]
# (4759, 10, 50)
# [ Model 00 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
#     - Complete!
#
# (2020-03-04 14:43:01) [ Read Converted Data ]
# [ Model 00 ]
#   - complete!
#
# (2020-03-04 14:43:08) [ Read Variables Importance Data ]
# (2020-03-04 14:43:08) [ Read Raw Data ]
# (2020-03-04 14:43:08) [ Read EDA Data ]
# (2020-03-04 14:43:09) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#   - complete!
#
# [ Model 03 ]
#     - Reshape Data (converting data frame to numpy.)
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 01 ]
# (4824, 10, 50)
# [ Model 00 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 04 ]
#     - Complete!
#
# (2020-03-04 14:43:51) [ Read Converted Data ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 05 ]
# (2020-03-04 14:43:56) [ Read Variables Importance Data ]
# (2020-03-04 14:43:56) [ Read Raw Data ]
# (2020-03-04 14:43:56) [ Read EDA Data ]
# (2020-03-04 14:43:56) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
#   - complete!
#
# [ Model 09 ]
#     - Reshape Data (converting data frame to numpy.)
#     - Complete!
#
# (2020-03-04 14:44:05) [ Read Converted Data ]
# (2020-03-04 14:44:10) [ Read Variables Importance Data ]
# (2020-03-04 14:44:10) [ Read Raw Data ]
# (2020-03-04 14:44:11) [ Read EDA Data ]
# (2020-03-04 14:44:11) [ Remove Non-Available Data ]
#                         * 65 rows are removed!
#
# (4889, 10, 50)
#     - Reshape Data (converting data frame to numpy.)
# [ Model 00 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# (4954, 10, 50)
# [ Model 00 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 01 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 05 ]
#     - Complete!
#
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 02 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
#   - complete!
#
# [ Model 03 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 04 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 07 ]
#     - Complete!
#
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 07 ]
#     - Complete!
#
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 05 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
#   - complete!
#
# [ Model 06 ]
#   - complete!
#
#     - Complete!
#
#   - complete!
#
# [ Model 07 ]
#   - complete!
#
# [ Model 07 ]
#     - Complete!
#
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 08 ]
#   - complete!
#
# [ Model 09 ]
#     - Complete!
#
#   - complete!
#
# [ Model 09 ]
#   - complete!
#
#   - complete!
#
#     - Complete!
#
#     - Complete!
